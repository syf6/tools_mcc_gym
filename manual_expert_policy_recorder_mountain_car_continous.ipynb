# %%
import numpy as np
import gymnasium as gym
import pygame
import csv
import time

# %% [markdown]
# Fixed Initial Position and Speed, not robust for expert policy

# %%
def run_continuous_action_test_with_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()

    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 手动设置小车的初始状态为底部，位置接近 -1.2，速度为 0
            env.reset()
            env.env.state = np.array([-1.2, 0.0]) # not correct, has already reseted in the env.reset()
            
            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_initial_state(10, render=True)
# Out:
# Initialized Joystick: Logicool Dual Action
# Number of axes: 4
# Episode 1, Action: 0.0000
# New State: Position = -0.4498, Velocity = -0.0006
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4509, Velocity = -0.0011
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4525, Velocity = -0.0016
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4547, Velocity = -0.0022
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4574, Velocity = -0.0027
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4605, Velocity = -0.0032
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4642, Velocity = -0.0036
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4683, Velocity = -0.0041
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4728, Velocity = -0.0045
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4777, Velocity = -0.0049
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4829, Velocity = -0.0052
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4884, Velocity = -0.0055
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4942, Velocity = -0.0058
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5003, Velocity = -0.0060
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5064, Velocity = -0.0062
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5128, Velocity = -0.0063
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5192, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5256, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5320, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5384, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5446, Velocity = -0.0062
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5507, Velocity = -0.0061
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5566, Velocity = -0.0059
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5622, Velocity = -0.0056
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5676, Velocity = -0.0053
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5726, Velocity = -0.0050
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5773, Velocity = -0.0047
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5815, Velocity = -0.0043
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5853, Velocity = -0.0038
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5887, Velocity = -0.0034
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5916, Velocity = -0.0029
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5939, Velocity = -0.0024
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5958, Velocity = -0.0018
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5971, Velocity = -0.0013
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5978, Velocity = -0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5981, Velocity = -0.0002
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5977, Velocity = 0.0003
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5968, Velocity = 0.0009
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5954, Velocity = 0.0014
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5934, Velocity = 0.0020
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5909, Velocity = 0.0025
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5879, Velocity = 0.0030
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5844, Velocity = 0.0035
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5805, Velocity = 0.0039
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5762, Velocity = 0.0044
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5714, Velocity = 0.0047
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5663, Velocity = 0.0051
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5609, Velocity = 0.0054
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5552, Velocity = 0.0057
#
# Episode 1, Action: 0.0397
# New State: Position = -0.5492, Velocity = 0.0060
#
# Episode 1, Action: 0.2937
# New State: Position = -0.5426, Velocity = 0.0066
#
# Episode 1, Action: 0.7698
# New State: Position = -0.5346, Velocity = 0.0079
#
# Episode 1, Action: 0.9682
# New State: Position = -0.5252, Velocity = 0.0095
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5142, Velocity = 0.0110
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5018, Velocity = 0.0124
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4880, Velocity = 0.0137
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4731, Velocity = 0.0150
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4570, Velocity = 0.0161
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4399, Velocity = 0.0171
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4219, Velocity = 0.0180
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4032, Velocity = 0.0187
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3838, Velocity = 0.0193
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3640, Velocity = 0.0198
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3438, Velocity = 0.0202
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3234, Velocity = 0.0204
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3030, Velocity = 0.0205
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2825, Velocity = 0.0204
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2622, Velocity = 0.0203
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2422, Velocity = 0.0200
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2226, Velocity = 0.0197
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2034, Velocity = 0.0192
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1847, Velocity = 0.0186
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1667, Velocity = 0.0180
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1494, Velocity = 0.0173
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1328, Velocity = 0.0166
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1171, Velocity = 0.0158
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1022, Velocity = 0.0149
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0881, Velocity = 0.0140
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0750, Velocity = 0.0131
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0628, Velocity = 0.0122
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0516, Velocity = 0.0112
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0413, Velocity = 0.0103
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0321, Velocity = 0.0093
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0238, Velocity = 0.0083
#
# Episode 1, Action: 0.6190
# New State: Position = -0.0171, Velocity = 0.0067
#
# Episode 1, Action: 0.1588
# New State: Position = -0.0126, Velocity = 0.0045
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0106, Velocity = 0.0020
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0112, Velocity = -0.0005
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0142, Velocity = -0.0030
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0197, Velocity = -0.0055
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0278, Velocity = -0.0080
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0383, Velocity = -0.0105
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0513, Velocity = -0.0130
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0667, Velocity = -0.0155
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0847, Velocity = -0.0179
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1050, Velocity = -0.0203
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1277, Velocity = -0.0227
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1528, Velocity = -0.0250
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1800, Velocity = -0.0273
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2095, Velocity = -0.0294
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2409, Velocity = -0.0314
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2742, Velocity = -0.0333
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3093, Velocity = -0.0350
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3458, Velocity = -0.0365
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3836, Velocity = -0.0378
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4224, Velocity = -0.0388
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4619, Velocity = -0.0396
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5020, Velocity = -0.0400
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5421, Velocity = -0.0402
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5822, Velocity = -0.0400
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6218, Velocity = -0.0396
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6607, Velocity = -0.0389
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6985, Velocity = -0.0379
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7352, Velocity = -0.0366
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7703, Velocity = -0.0351
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8038, Velocity = -0.0335
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8354, Velocity = -0.0316
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8650, Velocity = -0.0296
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8924, Velocity = -0.0274
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9176, Velocity = -0.0252
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9405, Velocity = -0.0229
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9610, Velocity = -0.0205
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9791, Velocity = -0.0181
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9948, Velocity = -0.0157
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0080, Velocity = -0.0132
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0187, Velocity = -0.0107
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0269, Velocity = -0.0082
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0327, Velocity = -0.0057
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0359, Velocity = -0.0032
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0366, Velocity = -0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0348, Velocity = 0.0018
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0306, Velocity = 0.0043
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0238, Velocity = 0.0068
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0145, Velocity = 0.0093
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0028, Velocity = 0.0117
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9886, Velocity = 0.0142
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9719, Velocity = 0.0167
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9528, Velocity = 0.0191
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9312, Velocity = 0.0215
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9074, Velocity = 0.0239
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8812, Velocity = 0.0262
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8528, Velocity = 0.0284
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8224, Velocity = 0.0304
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7900, Velocity = 0.0324
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7558, Velocity = 0.0342
#
# Episode 1, Action: 0.3651
# New State: Position = -0.7195, Velocity = 0.0363
#
# Episode 1, Action: 0.9127
# New State: Position = -0.6804, Velocity = 0.0391
#
# Episode 1, Action: 1.0000
# New State: Position = -0.6387, Velocity = 0.0417
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5946, Velocity = 0.0441
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5485, Velocity = 0.0461
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5007, Velocity = 0.0478
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4516, Velocity = 0.0491
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4015, Velocity = 0.0501
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3508, Velocity = 0.0507
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2999, Velocity = 0.0509
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2490, Velocity = 0.0509
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1984, Velocity = 0.0506
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1485, Velocity = 0.0500
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0992, Velocity = 0.0492
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0509, Velocity = 0.0483
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0035, Velocity = 0.0474
#
# Episode 1, Action: 1.0000
# New State: Position = 0.0429, Velocity = 0.0464
#
# Episode 1, Action: 1.0000
# New State: Position = 0.0882, Velocity = 0.0454
#
# Episode 1, Action: 1.0000
# New State: Position = 0.1327, Velocity = 0.0445
#
# Episode 1, Action: 1.0000
# New State: Position = 0.1764, Velocity = 0.0437
#
# Episode 1, Action: 1.0000
# New State: Position = 0.2194, Velocity = 0.0430
#
# Episode 1, Action: 1.0000
# New State: Position = 0.2619, Velocity = 0.0425
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3042, Velocity = 0.0423
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3465, Velocity = 0.0422
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3889, Velocity = 0.0425
#
# Episode 1, Action: 1.0000
# New State: Position = 0.4319, Velocity = 0.0430
#
# Episode 1, Action: 1.0000
# New State: Position = 0.4757, Velocity = 0.0438
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4774, Velocity = 0.0012
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4751, Velocity = 0.0023
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4717, Velocity = 0.0035
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4671, Velocity = 0.0046
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4614, Velocity = 0.0056
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4548, Velocity = 0.0067
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4471, Velocity = 0.0077
#
# Episode 2, Action: 0.6190
# New State: Position = -0.4391, Velocity = 0.0080
#
# Episode 2, Action: 0.1270
# New State: Position = -0.4315, Velocity = 0.0076
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4246, Velocity = 0.0069
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4184, Velocity = 0.0062
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4130, Velocity = 0.0054
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4084, Velocity = 0.0046
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4046, Velocity = 0.0037
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4018, Velocity = 0.0029
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3998, Velocity = 0.0020
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3987, Velocity = 0.0011
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3986, Velocity = 0.0002
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3993, Velocity = -0.0008
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4010, Velocity = -0.0017
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4036, Velocity = -0.0026
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4070, Velocity = -0.0035
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4114, Velocity = -0.0043
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4165, Velocity = -0.0051
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4224, Velocity = -0.0059
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4291, Velocity = -0.0067
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4365, Velocity = -0.0074
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4445, Velocity = -0.0080
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4531, Velocity = -0.0086
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4622, Velocity = -0.0091
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4718, Velocity = -0.0096
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4818, Velocity = -0.0100
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4921, Velocity = -0.0103
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5026, Velocity = -0.0105
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5133, Velocity = -0.0107
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5240, Velocity = -0.0108
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5348, Velocity = -0.0108
#
# Episode 2, Action: -0.0625
# New State: Position = -0.5456, Velocity = -0.0108
#
# Episode 2, Action: -0.3203
# New State: Position = -0.5566, Velocity = -0.0111
#
# Episode 2, Action: -0.6484
# New State: Position = -0.5684, Velocity = -0.0118
#
# Episode 2, Action: -0.9219
# New State: Position = -0.5813, Velocity = -0.0129
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5952, Velocity = -0.0139
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6101, Velocity = -0.0149
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6259, Velocity = -0.0157
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6424, Velocity = -0.0165
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6595, Velocity = -0.0171
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6771, Velocity = -0.0176
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6951, Velocity = -0.0180
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7134, Velocity = -0.0183
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7319, Velocity = -0.0184
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7503, Velocity = -0.0185
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7687, Velocity = -0.0184
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7870, Velocity = -0.0182
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8049, Velocity = -0.0180
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8225, Velocity = -0.0176
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8396, Velocity = -0.0171
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8562, Velocity = -0.0166
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8722, Velocity = -0.0160
#
# Episode 2, Action: -0.7500
# New State: Position = -0.8872, Velocity = -0.0150
#
# Episode 2, Action: -0.3438
# New State: Position = -0.9005, Velocity = -0.0133
#
# Episode 2, Action: -0.0938
# New State: Position = -0.9116, Velocity = -0.0111
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9204, Velocity = -0.0088
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9270, Velocity = -0.0065
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9312, Velocity = -0.0042
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9330, Velocity = -0.0018
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9325, Velocity = 0.0005
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9296, Velocity = 0.0029
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9244, Velocity = 0.0052
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9168, Velocity = 0.0076
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9069, Velocity = 0.0099
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8948, Velocity = 0.0121
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8804, Velocity = 0.0144
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8638, Velocity = 0.0166
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8451, Velocity = 0.0187
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8243, Velocity = 0.0208
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8016, Velocity = 0.0227
#
# Episode 2, Action: 0.0000
# New State: Position = -0.7770, Velocity = 0.0246
#
# Episode 2, Action: 0.1111
# New State: Position = -0.7506, Velocity = 0.0265
#
# Episode 2, Action: 0.3651
# New State: Position = -0.7220, Velocity = 0.0286
#
# Episode 2, Action: 0.6587
# New State: Position = -0.6910, Velocity = 0.0310
#
# Episode 2, Action: 0.8571
# New State: Position = -0.6575, Velocity = 0.0335
#
# Episode 2, Action: 0.9841
# New State: Position = -0.6216, Velocity = 0.0359
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5834, Velocity = 0.0382
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5433, Velocity = 0.0401
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5016, Velocity = 0.0417
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4585, Velocity = 0.0431
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4144, Velocity = 0.0441
#
# Episode 2, Action: 1.0000
# New State: Position = -0.3696, Velocity = 0.0448
#
# Episode 2, Action: 1.0000
# New State: Position = -0.3244, Velocity = 0.0452
#
# Episode 2, Action: 1.0000
# New State: Position = -0.2792, Velocity = 0.0453
#
# Episode 2, Action: 1.0000
# New State: Position = -0.2341, Velocity = 0.0451
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1894, Velocity = 0.0447
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1453, Velocity = 0.0441
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1020, Velocity = 0.0433
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0596, Velocity = 0.0424
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0181, Velocity = 0.0415
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0224, Velocity = 0.0405
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0618, Velocity = 0.0395
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1004, Velocity = 0.0385
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1380, Velocity = 0.0376
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1749, Velocity = 0.0368
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2110, Velocity = 0.0362
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2467, Velocity = 0.0357
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2820, Velocity = 0.0353
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3172, Velocity = 0.0352
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3524, Velocity = 0.0352
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3879, Velocity = 0.0355
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4239, Velocity = 0.0360
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4606, Velocity = 0.0368
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4462, Velocity = 0.0009
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4443, Velocity = 0.0019
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4416, Velocity = 0.0028
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4379, Velocity = 0.0037
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4334, Velocity = 0.0045
#
# Episode 3, Action: 0.9286
# New State: Position = -0.4281, Velocity = 0.0052
#
# Episode 3, Action: 0.7698
# New State: Position = -0.4224, Velocity = 0.0057
#
# Episode 3, Action: 0.6270
# New State: Position = -0.4165, Velocity = 0.0059
#
# Episode 3, Action: 0.3254
# New State: Position = -0.4110, Velocity = 0.0056
#
# Episode 3, Action: 0.0476
# New State: Position = -0.4061, Velocity = 0.0048
#
# Episode 3, Action: 0.0000
# New State: Position = -0.4022, Velocity = 0.0040
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3991, Velocity = 0.0031
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3969, Velocity = 0.0022
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3957, Velocity = 0.0012
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3954, Velocity = 0.0003
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3960, Velocity = -0.0006
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3976, Velocity = -0.0016
#
# Episode 3, Action: -0.0703
# New State: Position = -0.4002, Velocity = -0.0026
#
# Episode 3, Action: -0.2031
# New State: Position = -0.4040, Velocity = -0.0038
#
# Episode 3, Action: -0.3438
# New State: Position = -0.4092, Velocity = -0.0052
#
# Episode 3, Action: -0.4219
# New State: Position = -0.4159, Velocity = -0.0067
#
# Episode 3, Action: -0.5312
# New State: Position = -0.4241, Velocity = -0.0083
#
# Episode 3, Action: -0.6562
# New State: Position = -0.4341, Velocity = -0.0100
#
# Episode 3, Action: -0.8359
# New State: Position = -0.4460, Velocity = -0.0119
#
# Episode 3, Action: -0.9609
# New State: Position = -0.4600, Velocity = -0.0139
#
# Episode 3, Action: -1.0000
# New State: Position = -0.4759, Velocity = -0.0159
#
# Episode 3, Action: -1.0000
# New State: Position = -0.4936, Velocity = -0.0178
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5131, Velocity = -0.0195
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5341, Velocity = -0.0211
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5566, Velocity = -0.0225
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5803, Velocity = -0.0237
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6052, Velocity = -0.0248
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6309, Velocity = -0.0257
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6573, Velocity = -0.0264
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6842, Velocity = -0.0269
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7115, Velocity = -0.0273
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7389, Velocity = -0.0274
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7663, Velocity = -0.0274
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7936, Velocity = -0.0273
#
# Episode 3, Action: -1.0000
# New State: Position = -0.8206, Velocity = -0.0270
#
# Episode 3, Action: -1.0000
# New State: Position = -0.8471, Velocity = -0.0265
#
# Episode 3, Action: -0.7344
# New State: Position = -0.8726, Velocity = -0.0256
#
# Episode 3, Action: -0.2812
# New State: Position = -0.8965, Velocity = -0.0238
#
# Episode 3, Action: -0.0078
# New State: Position = -0.9180, Velocity = -0.0216
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9373, Velocity = -0.0193
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9542, Velocity = -0.0169
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9687, Velocity = -0.0145
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9807, Velocity = -0.0121
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9904, Velocity = -0.0096
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9975, Velocity = -0.0071
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0022, Velocity = -0.0047
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0044, Velocity = -0.0022
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0041, Velocity = 0.0003
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0013, Velocity = 0.0028
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9961, Velocity = 0.0052
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0077
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9782, Velocity = 0.0102
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9656, Velocity = 0.0126
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9505, Velocity = 0.0150
#
# Episode 3, Action: 0.0714
# New State: Position = -0.9330, Velocity = 0.0175
#
# Episode 3, Action: 0.3730
# New State: Position = -0.9125, Velocity = 0.0205
#
# Episode 3, Action: 0.7698
# New State: Position = -0.8886, Velocity = 0.0239
#
# Episode 3, Action: 0.9920
# New State: Position = -0.8610, Velocity = 0.0276
#
# Episode 3, Action: 1.0000
# New State: Position = -0.8298, Velocity = 0.0312
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7950, Velocity = 0.0347
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7570, Velocity = 0.0380
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7158, Velocity = 0.0412
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6718, Velocity = 0.0440
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6252, Velocity = 0.0466
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5764, Velocity = 0.0488
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5256, Velocity = 0.0507
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4734, Velocity = 0.0523
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4200, Velocity = 0.0534
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3659, Velocity = 0.0541
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3114, Velocity = 0.0545
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2569, Velocity = 0.0545
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2027, Velocity = 0.0542
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1491, Velocity = 0.0536
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0962, Velocity = 0.0529
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0442, Velocity = 0.0520
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0068, Velocity = 0.0510
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0569, Velocity = 0.0500
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1059, Velocity = 0.0491
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1541, Velocity = 0.0482
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2015, Velocity = 0.0474
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2484, Velocity = 0.0469
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2950, Velocity = 0.0465
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3414, Velocity = 0.0465
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3881, Velocity = 0.0467
#
# Episode 3, Action: 1.0000
# New State: Position = 0.4353, Velocity = 0.0472
#
# Episode 3, Action: 1.0000
# New State: Position = 0.4833, Velocity = 0.0480
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5842, Velocity = 0.0020
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5803, Velocity = 0.0039
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5745, Velocity = 0.0058
#
# Episode 4, Action: 0.5476
# New State: Position = -0.5674, Velocity = 0.0070
#
# Episode 4, Action: 0.0635
# New State: Position = -0.5599, Velocity = 0.0075
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5522, Velocity = 0.0077
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5443, Velocity = 0.0080
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5361, Velocity = 0.0081
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5279, Velocity = 0.0082
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5197, Velocity = 0.0082
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5115, Velocity = 0.0082
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5034, Velocity = 0.0081
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4954, Velocity = 0.0080
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4877, Velocity = 0.0078
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4802, Velocity = 0.0075
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4730, Velocity = 0.0072
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4663, Velocity = 0.0068
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4599, Velocity = 0.0064
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4540, Velocity = 0.0059
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4487, Velocity = 0.0054
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4439, Velocity = 0.0048
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4397, Velocity = 0.0042
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4361, Velocity = 0.0036
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4331, Velocity = 0.0029
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4309, Velocity = 0.0023
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4293, Velocity = 0.0016
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4284, Velocity = 0.0009
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4282, Velocity = 0.0002
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4287, Velocity = -0.0005
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4300, Velocity = -0.0012
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4319, Velocity = -0.0019
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4345, Velocity = -0.0026
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4378, Velocity = -0.0033
#
# Episode 4, Action: 0.2460
# New State: Position = -0.4413, Velocity = -0.0035
#
# Episode 4, Action: 0.7301
# New State: Position = -0.4443, Velocity = -0.0030
#
# Episode 4, Action: 0.9920
# New State: Position = -0.4465, Velocity = -0.0021
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4477, Velocity = -0.0012
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4480, Velocity = -0.0003
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4473, Velocity = 0.0007
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4457, Velocity = 0.0016
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4432, Velocity = 0.0025
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4398, Velocity = 0.0034
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4355, Velocity = 0.0043
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4304, Velocity = 0.0051
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4244, Velocity = 0.0059
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4177, Velocity = 0.0067
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4103, Velocity = 0.0074
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4022, Velocity = 0.0081
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3935, Velocity = 0.0087
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3842, Velocity = 0.0093
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3745, Velocity = 0.0097
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3643, Velocity = 0.0102
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3538, Velocity = 0.0105
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3430, Velocity = 0.0108
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3320, Velocity = 0.0110
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3209, Velocity = 0.0111
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3097, Velocity = 0.0112
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2984, Velocity = 0.0112
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2873, Velocity = 0.0112
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2763, Velocity = 0.0110
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2654, Velocity = 0.0108
#
# Episode 4, Action: 0.9127
# New State: Position = -0.2550, Velocity = 0.0105
#
# Episode 4, Action: 0.4524
# New State: Position = -0.2456, Velocity = 0.0093
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2381, Velocity = 0.0075
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2325, Velocity = 0.0056
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2289, Velocity = 0.0037
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2271, Velocity = 0.0017
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2273, Velocity = -0.0002
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2295, Velocity = -0.0021
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2335, Velocity = -0.0041
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2395, Velocity = -0.0060
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2474, Velocity = -0.0079
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2571, Velocity = -0.0097
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2686, Velocity = -0.0115
#
# Episode 4, Action: -0.0078
# New State: Position = -0.2818, Velocity = -0.0132
#
# Episode 4, Action: -0.0938
# New State: Position = -0.2968, Velocity = -0.0150
#
# Episode 4, Action: -0.3984
# New State: Position = -0.3141, Velocity = -0.0172
#
# Episode 4, Action: -0.7031
# New State: Position = -0.3338, Velocity = -0.0197
#
# Episode 4, Action: -0.9609
# New State: Position = -0.3563, Velocity = -0.0225
#
# Episode 4, Action: -1.0000
# New State: Position = -0.3815, Velocity = -0.0252
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4093, Velocity = -0.0278
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4394, Velocity = -0.0301
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4716, Velocity = -0.0322
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5057, Velocity = -0.0341
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5415, Velocity = -0.0357
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5786, Velocity = -0.0371
#
# Episode 4, Action: -0.5859
# New State: Position = -0.6162, Velocity = -0.0376
#
# Episode 4, Action: -0.0312
# New State: Position = -0.6531, Velocity = -0.0369
#
# Episode 4, Action: 0.0000
# New State: Position = -0.6891, Velocity = -0.0360
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7239, Velocity = -0.0348
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7573, Velocity = -0.0334
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7891, Velocity = -0.0318
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8191, Velocity = -0.0300
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8471, Velocity = -0.0281
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8731, Velocity = -0.0260
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8970, Velocity = -0.0238
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9185, Velocity = -0.0216
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9378, Velocity = -0.0193
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9547, Velocity = -0.0169
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9692, Velocity = -0.0145
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9812, Velocity = -0.0121
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9908, Velocity = -0.0096
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9980, Velocity = -0.0071
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0026, Velocity = -0.0047
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0048, Velocity = -0.0022
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0045, Velocity = 0.0003
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0018, Velocity = 0.0028
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9965, Velocity = 0.0052
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9888, Velocity = 0.0077
#
# Episode 4, Action: 0.0080
# New State: Position = -0.9786, Velocity = 0.0102
#
# Episode 4, Action: 0.1508
# New State: Position = -0.9657, Velocity = 0.0129
#
# Episode 4, Action: 0.3968
# New State: Position = -0.9498, Velocity = 0.0159
#
# Episode 4, Action: 0.5079
# New State: Position = -0.9308, Velocity = 0.0190
#
# Episode 4, Action: 0.7540
# New State: Position = -0.9083, Velocity = 0.0225
#
# Episode 4, Action: 0.9444
# New State: Position = -0.8821, Velocity = 0.0262
#
# Episode 4, Action: 1.0000
# New State: Position = -0.8521, Velocity = 0.0299
#
# Episode 4, Action: 1.0000
# New State: Position = -0.8186, Velocity = 0.0335
#
# Episode 4, Action: 1.0000
# New State: Position = -0.7817, Velocity = 0.0369
#
# Episode 4, Action: 1.0000
# New State: Position = -0.7415, Velocity = 0.0402
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6983, Velocity = 0.0432
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6523, Velocity = 0.0460
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6039, Velocity = 0.0484
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5534, Velocity = 0.0505
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5012, Velocity = 0.0522
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4476, Velocity = 0.0536
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3931, Velocity = 0.0545
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3381, Velocity = 0.0550
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2829, Velocity = 0.0552
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2278, Velocity = 0.0551
#
# Episode 4, Action: 1.0000
# New State: Position = -0.1732, Velocity = 0.0546
#
# Episode 4, Action: 1.0000
# New State: Position = -0.1192, Velocity = 0.0540
#
# Episode 4, Action: 1.0000
# New State: Position = -0.0661, Velocity = 0.0531
#
# Episode 4, Action: 1.0000
# New State: Position = -0.0140, Velocity = 0.0522
#
# Episode 4, Action: 1.0000
# New State: Position = 0.0372, Velocity = 0.0512
#
# Episode 4, Action: 1.0000
# New State: Position = 0.0874, Velocity = 0.0502
#
# Episode 4, Action: 1.0000
# New State: Position = 0.1366, Velocity = 0.0493
#
# Episode 4, Action: 1.0000
# New State: Position = 0.1851, Velocity = 0.0485
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2330, Velocity = 0.0478
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2804, Velocity = 0.0474
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3277, Velocity = 0.0473
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3750, Velocity = 0.0474
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4229, Velocity = 0.0478
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4714, Velocity = 0.0486
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5491, Velocity = 0.0002
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5487, Velocity = 0.0004
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5482, Velocity = 0.0006
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5474, Velocity = 0.0008
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5465, Velocity = 0.0009
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5454, Velocity = 0.0011
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5441, Velocity = 0.0013
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5427, Velocity = 0.0014
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5411, Velocity = 0.0016
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5394, Velocity = 0.0017
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5376, Velocity = 0.0018
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5357, Velocity = 0.0019
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5337, Velocity = 0.0020
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5316, Velocity = 0.0021
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5294, Velocity = 0.0021
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5272, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5250, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5228, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5206, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5184, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5162, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5141, Velocity = 0.0021
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5121, Velocity = 0.0020
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5101, Velocity = 0.0019
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5083, Velocity = 0.0018
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5066, Velocity = 0.0017
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5050, Velocity = 0.0016
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5035, Velocity = 0.0015
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5022, Velocity = 0.0013
#
# Episode 5, Action: 0.0873
# New State: Position = -0.5009, Velocity = 0.0013
#
# Episode 5, Action: 0.5952
# New State: Position = -0.4989, Velocity = 0.0020
#
# Episode 5, Action: 0.9286
# New State: Position = -0.4957, Velocity = 0.0032
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4912, Velocity = 0.0045
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4854, Velocity = 0.0058
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4784, Velocity = 0.0070
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4703, Velocity = 0.0081
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4611, Velocity = 0.0092
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4508, Velocity = 0.0103
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4396, Velocity = 0.0112
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4274, Velocity = 0.0121
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4146, Velocity = 0.0129
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4010, Velocity = 0.0136
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3868, Velocity = 0.0142
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3721, Velocity = 0.0147
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3570, Velocity = 0.0151
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3416, Velocity = 0.0154
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3260, Velocity = 0.0156
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3103, Velocity = 0.0157
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2946, Velocity = 0.0157
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2789, Velocity = 0.0156
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2635, Velocity = 0.0155
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2483, Velocity = 0.0152
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2334, Velocity = 0.0149
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2190, Velocity = 0.0144
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2050, Velocity = 0.0140
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1916, Velocity = 0.0134
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1788, Velocity = 0.0128
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1666, Velocity = 0.0122
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1551, Velocity = 0.0115
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1444, Velocity = 0.0107
#
# Episode 5, Action: 0.8492
# New State: Position = -0.1346, Velocity = 0.0097
#
# Episode 5, Action: 0.5873
# New State: Position = -0.1263, Velocity = 0.0083
#
# Episode 5, Action: 0.1429
# New State: Position = -0.1201, Velocity = 0.0062
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1162, Velocity = 0.0039
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1147, Velocity = 0.0015
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1155, Velocity = -0.0008
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1186, Velocity = -0.0032
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1242, Velocity = -0.0055
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1320, Velocity = -0.0078
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1422, Velocity = -0.0101
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1546, Velocity = -0.0124
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1692, Velocity = -0.0147
#
# Episode 5, Action: -0.0391
# New State: Position = -0.1861, Velocity = -0.0169
#
# Episode 5, Action: -0.2188
# New State: Position = -0.2055, Velocity = -0.0194
#
# Episode 5, Action: -0.4297
# New State: Position = -0.2275, Velocity = -0.0220
#
# Episode 5, Action: -0.6719
# New State: Position = -0.2525, Velocity = -0.0250
#
# Episode 5, Action: -0.9141
# New State: Position = -0.2807, Velocity = -0.0282
#
# Episode 5, Action: -1.0000
# New State: Position = -0.3120, Velocity = -0.0313
#
# Episode 5, Action: -1.0000
# New State: Position = -0.3463, Velocity = -0.0343
#
# Episode 5, Action: -1.0000
# New State: Position = -0.3834, Velocity = -0.0371
#
# Episode 5, Action: -1.0000
# New State: Position = -0.4230, Velocity = -0.0396
#
# Episode 5, Action: -1.0000
# New State: Position = -0.4649, Velocity = -0.0419
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5087, Velocity = -0.0438
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5541, Velocity = -0.0454
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6008, Velocity = -0.0467
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6483, Velocity = -0.0476
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6965, Velocity = -0.0482
#
# Episode 5, Action: -0.8125
# New State: Position = -0.7447, Velocity = -0.0482
#
# Episode 5, Action: -0.2344
# New State: Position = -0.7917, Velocity = -0.0470
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8368, Velocity = -0.0452
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8800, Velocity = -0.0432
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9210, Velocity = -0.0410
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9596, Velocity = -0.0386
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9958, Velocity = -0.0362
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0296, Velocity = -0.0338
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0609, Velocity = -0.0313
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0896, Velocity = -0.0288
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1159, Velocity = -0.0263
#
# Episode 5, Action: 0.2460
# New State: Position = -1.1394, Velocity = -0.0235
#
# Episode 5, Action: 0.7460
# New State: Position = -1.1593, Velocity = -0.0199
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1754, Velocity = -0.0161
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1877, Velocity = -0.0123
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1961, Velocity = -0.0085
#
# Episode 5, Action: 1.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1963, Velocity = 0.0037
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1888, Velocity = 0.0075
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1775, Velocity = 0.0113
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1624, Velocity = 0.0151
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1435, Velocity = 0.0189
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1206, Velocity = 0.0228
#
# Episode 5, Action: 1.0000
# New State: Position = -1.0939, Velocity = 0.0268
#
# Episode 5, Action: 1.0000
# New State: Position = -1.0631, Velocity = 0.0307
#
# ...
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5574, Velocity = 0.0233
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5339, Velocity = 0.0235
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5103, Velocity = 0.0236
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4868, Velocity = 0.0235
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4636, Velocity = 0.0232
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4409, Velocity = 0.0228
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4187, Velocity = 0.0222
#
# Episode 9, Action: 0.0000
# New State: Position = -0.3973, Velocity = 0.0214
#
# Episode 9, Action: 0.1191
# New State: Position = -0.3767, Velocity = 0.0206
#
# Episode 9, Action: 0.4762
# New State: Position = -0.3564, Velocity = 0.0203
#
# Episode 9, Action: 0.8412
# New State: Position = -0.3361, Velocity = 0.0203
#
# Episode 9, Action: 1.0000
# New State: Position = -0.3156, Velocity = 0.0205
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2950, Velocity = 0.0205
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2746, Velocity = 0.0205
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2543, Velocity = 0.0203
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2343, Velocity = 0.0200
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2148, Velocity = 0.0196
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1957, Velocity = 0.0191
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1773, Velocity = 0.0185
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1594, Velocity = 0.0178
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1423, Velocity = 0.0171
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1260, Velocity = 0.0163
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1105, Velocity = 0.0155
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0959, Velocity = 0.0146
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0822, Velocity = 0.0137
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0693, Velocity = 0.0128
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0575, Velocity = 0.0119
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0466, Velocity = 0.0109
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0366, Velocity = 0.0099
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0277, Velocity = 0.0089
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0198, Velocity = 0.0080
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0128, Velocity = 0.0070
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0068, Velocity = 0.0060
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0019, Velocity = 0.0050
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0021, Velocity = 0.0040
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0050, Velocity = 0.0030
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0070, Velocity = 0.0020
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0079, Velocity = 0.0010
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0079, Velocity = -0.0000
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0069, Velocity = -0.0010
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0048, Velocity = -0.0020
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0018, Velocity = -0.0030
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0023, Velocity = -0.0040
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0073, Velocity = -0.0050
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0133, Velocity = -0.0060
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0204, Velocity = -0.0070
#
# Episode 9, Action: 0.6825
# New State: Position = -0.0289, Velocity = -0.0085
#
# Episode 9, Action: 0.1429
# New State: Position = -0.0397, Velocity = -0.0108
#
# Episode 9, Action: 0.0000
# New State: Position = -0.0529, Velocity = -0.0133
#
# Episode 9, Action: 0.0000
# New State: Position = -0.0687, Velocity = -0.0157
#
# Episode 9, Action: -0.0156
# New State: Position = -0.0869, Velocity = -0.0182
#
# Episode 9, Action: -0.0938
# New State: Position = -0.1076, Velocity = -0.0208
#
# Episode 9, Action: -0.2812
# New State: Position = -0.1312, Velocity = -0.0236
#
# Episode 9, Action: -0.6484
# New State: Position = -0.1580, Velocity = -0.0268
#
# Episode 9, Action: -0.9141
# New State: Position = -0.1885, Velocity = -0.0304
#
# Episode 9, Action: -1.0000
# New State: Position = -0.2225, Velocity = -0.0340
#
# Episode 9, Action: -1.0000
# New State: Position = -0.2600, Velocity = -0.0375
#
# Episode 9, Action: -1.0000
# New State: Position = -0.3008, Velocity = -0.0408
#
# Episode 9, Action: -1.0000
# New State: Position = -0.3446, Velocity = -0.0438
#
# Episode 9, Action: -1.0000
# New State: Position = -0.3912, Velocity = -0.0466
#
# Episode 9, Action: -0.8906
# New State: Position = -0.4402, Velocity = -0.0489
#
# Episode 9, Action: -0.4922
# New State: Position = -0.4904, Velocity = -0.0503
#
# Episode 9, Action: -0.0469
# New State: Position = -0.5410, Velocity = -0.0506
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5915, Velocity = -0.0505
#
# Episode 9, Action: 0.0000
# New State: Position = -0.6414, Velocity = -0.0500
#
# Episode 9, Action: 0.0000
# New State: Position = -0.6905, Velocity = -0.0491
#
# Episode 9, Action: 0.0000
# New State: Position = -0.7384, Velocity = -0.0479
#
# Episode 9, Action: 0.0000
# New State: Position = -0.7848, Velocity = -0.0464
#
# Episode 9, Action: 0.0000
# New State: Position = -0.8294, Velocity = -0.0446
#
# Episode 9, Action: 0.0000
# New State: Position = -0.8721, Velocity = -0.0426
#
# Episode 9, Action: 0.0000
# New State: Position = -0.9125, Velocity = -0.0405
#
# Episode 9, Action: 0.0000
# New State: Position = -0.9507, Velocity = -0.0382
#
# Episode 9, Action: 0.0000
# New State: Position = -0.9865, Velocity = -0.0358
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0198, Velocity = -0.0333
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0506, Velocity = -0.0308
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0790, Velocity = -0.0283
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1048, Velocity = -0.0258
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1282, Velocity = -0.0234
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1491, Velocity = -0.0210
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1677, Velocity = -0.0186
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1839, Velocity = -0.0162
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1979, Velocity = -0.0139
#
# Episode 9, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 9, Action: 0.1349
# New State: Position = -0.9882, Velocity = 0.0311
#
# Episode 9, Action: 0.6270
# New State: Position = -0.9537, Velocity = 0.0345
#
# Episode 9, Action: 0.9286
# New State: Position = -0.9154, Velocity = 0.0383
#
# Episode 9, Action: 1.0000
# New State: Position = -0.8733, Velocity = 0.0421
#
# Episode 9, Action: 1.0000
# New State: Position = -0.8276, Velocity = 0.0458
#
# Episode 9, Action: 1.0000
# New State: Position = -0.7784, Velocity = 0.0492
#
# Episode 9, Action: 1.0000
# New State: Position = -0.7259, Velocity = 0.0525
#
# Episode 9, Action: 1.0000
# New State: Position = -0.6705, Velocity = 0.0554
#
# Episode 9, Action: 1.0000
# New State: Position = -0.6125, Velocity = 0.0580
#
# Episode 9, Action: 1.0000
# New State: Position = -0.5524, Velocity = 0.0601
#
# Episode 9, Action: 1.0000
# New State: Position = -0.4906, Velocity = 0.0618
#
# Episode 9, Action: 1.0000
# New State: Position = -0.4275, Velocity = 0.0631
#
# Episode 9, Action: 1.0000
# New State: Position = -0.3637, Velocity = 0.0639
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2994, Velocity = 0.0642
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2353, Velocity = 0.0642
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1715, Velocity = 0.0638
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1084, Velocity = 0.0631
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0462, Velocity = 0.0622
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0150, Velocity = 0.0612
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0752, Velocity = 0.0602
#
# Episode 9, Action: 1.0000
# New State: Position = 0.1345, Velocity = 0.0593
#
# Episode 9, Action: 1.0000
# New State: Position = 0.1930, Velocity = 0.0585
#
# Episode 9, Action: 1.0000
# New State: Position = 0.2510, Velocity = 0.0579
#
# Episode 9, Action: 1.0000
# New State: Position = 0.3085, Velocity = 0.0576
#
# Episode 9, Action: 1.0000
# New State: Position = 0.3661, Velocity = 0.0576
#
# Episode 9, Action: 1.0000
# New State: Position = 0.4241, Velocity = 0.0579
#
# Episode 9, Action: 1.0000
# New State: Position = 0.4828, Velocity = 0.0587
#
# Episode 10, Action: 0.0159
# New State: Position = -0.4097, Velocity = -0.0008
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4114, Velocity = -0.0017
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4138, Velocity = -0.0025
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4171, Velocity = -0.0033
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4212, Velocity = -0.0041
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4260, Velocity = -0.0048
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4316, Velocity = -0.0056
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4378, Velocity = -0.0062
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4447, Velocity = -0.0069
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4522, Velocity = -0.0075
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4601, Velocity = -0.0080
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4686, Velocity = -0.0085
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4775, Velocity = -0.0089
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4867, Velocity = -0.0092
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4962, Velocity = -0.0095
#
# Episode 10, Action: 0.0000
# New State: Position = -0.5059, Velocity = -0.0097
#
# Episode 10, Action: -0.1406
# New State: Position = -0.5159, Velocity = -0.0100
#
# Episode 10, Action: -0.4688
# New State: Position = -0.5267, Velocity = -0.0108
#
# Episode 10, Action: -0.8984
# New State: Position = -0.5389, Velocity = -0.0121
#
# Episode 10, Action: -1.0000
# New State: Position = -0.5524, Velocity = -0.0135
#
# Episode 10, Action: -1.0000
# New State: Position = -0.5672, Velocity = -0.0148
#
# Episode 10, Action: -1.0000
# New State: Position = -0.5832, Velocity = -0.0160
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6002, Velocity = -0.0170
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6181, Velocity = -0.0180
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6369, Velocity = -0.0188
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6563, Velocity = -0.0194
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6763, Velocity = -0.0200
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6966, Velocity = -0.0204
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7172, Velocity = -0.0206
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7380, Velocity = -0.0207
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7587, Velocity = -0.0207
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7793, Velocity = -0.0206
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7997, Velocity = -0.0204
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8198, Velocity = -0.0200
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8394, Velocity = -0.0196
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8584, Velocity = -0.0191
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8769, Velocity = -0.0185
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8947, Velocity = -0.0178
#
# Episode 10, Action: -0.7266
# New State: Position = -0.9113, Velocity = -0.0166
#
# Episode 10, Action: -0.1562
# New State: Position = -0.9259, Velocity = -0.0146
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9381, Velocity = -0.0122
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9480, Velocity = -0.0099
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9554, Velocity = -0.0075
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9605, Velocity = -0.0051
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9631, Velocity = -0.0027
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9634, Velocity = -0.0002
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9612, Velocity = 0.0022
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9566, Velocity = 0.0046
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9496, Velocity = 0.0070
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9402, Velocity = 0.0094
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9284, Velocity = 0.0118
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9142, Velocity = 0.0141
#
# Episode 10, Action: 0.0000
# New State: Position = -0.8978, Velocity = 0.0164
#
# Episode 10, Action: 0.0000
# New State: Position = -0.8791, Velocity = 0.0187
#
# Episode 10, Action: 0.1032
# New State: Position = -0.8581, Velocity = 0.0210
#
# Episode 10, Action: 0.4207
# New State: Position = -0.8343, Velocity = 0.0238
#
# Episode 10, Action: 0.8492
# New State: Position = -0.8073, Velocity = 0.0270
#
# Episode 10, Action: 0.9920
# New State: Position = -0.7769, Velocity = 0.0304
#
# Episode 10, Action: 1.0000
# New State: Position = -0.7433, Velocity = 0.0336
#
# Episode 10, Action: 1.0000
# New State: Position = -0.7066, Velocity = 0.0367
#
# Episode 10, Action: 1.0000
# New State: Position = -0.6671, Velocity = 0.0395
#
# Episode 10, Action: 1.0000
# New State: Position = -0.6251, Velocity = 0.0420
#
# Episode 10, Action: 1.0000
# New State: Position = -0.5808, Velocity = 0.0443
#
# Episode 10, Action: 1.0000
# New State: Position = -0.5346, Velocity = 0.0462
#
# Episode 10, Action: 1.0000
# New State: Position = -0.4869, Velocity = 0.0478
#
# Episode 10, Action: 1.0000
# New State: Position = -0.4379, Velocity = 0.0490
#
# Episode 10, Action: 1.0000
# New State: Position = -0.3880, Velocity = 0.0499
#
# Episode 10, Action: 1.0000
# New State: Position = -0.3376, Velocity = 0.0504
#
# Episode 10, Action: 1.0000
# New State: Position = -0.2871, Velocity = 0.0506
#
# Episode 10, Action: 1.0000
# New State: Position = -0.2367, Velocity = 0.0504
#
# Episode 10, Action: 1.0000
# New State: Position = -0.1866, Velocity = 0.0500
#
# Episode 10, Action: 1.0000
# New State: Position = -0.1372, Velocity = 0.0494
#
# Episode 10, Action: 1.0000
# New State: Position = -0.0886, Velocity = 0.0486
#
# Episode 10, Action: 1.0000
# New State: Position = -0.0409, Velocity = 0.0477
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0058, Velocity = 0.0467
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0515, Velocity = 0.0457
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0963, Velocity = 0.0448
#
# Episode 10, Action: 1.0000
# New State: Position = 0.1401, Velocity = 0.0439
#
# Episode 10, Action: 1.0000
# New State: Position = 0.1832, Velocity = 0.0431
#
# Episode 10, Action: 1.0000
# New State: Position = 0.2257, Velocity = 0.0424
#
# Episode 10, Action: 1.0000
# New State: Position = 0.2677, Velocity = 0.0420
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3094, Velocity = 0.0418
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3512, Velocity = 0.0418
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3932, Velocity = 0.0420
#
# Episode 10, Action: 1.0000
# New State: Position = 0.4358, Velocity = 0.0426
#
# Episode 10, Action: 1.0000
# New State: Position = 0.4792, Velocity = 0.0434

# %% [markdown]
# Random Inital Position and Speed, Robust for expert policy, 2 failed versions, cannot set initial state to the car and environment

# %% [markdown]
# To deal with this problem, 2 trials are proposed:
#
# ## delete some datas manually -- > failed ?
#
# ## find the set function in gymnasium mountain car continous --> found and success

# %% [markdown]
# this one good random, but not very big difference

# %%
def run_continuous_action_test_with_random_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()

    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 显示倒数和回合开始信息
            print("Episode {} start in: ".format(i+1), end="")
            for countdown in range(2, 0, -1):
                print("{} ".format(countdown), end="", flush=True)
                time.sleep(1)
            print("\nEpisode {} start!".format(i+1))

            # 随机设置小车的初始状态
            initial_position = np.random.uniform(-1.2, 0.6)
            initial_velocity = np.random.uniform(0.07,0.6)
            env.reset()
            # env.env.state = np.array([initial_position, initial_velocity])

            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_random_initial_state(50, render=True)

# %% [markdown]
# This script has not been verified, do not use

# %%
def run_continuous_action_test_with_random_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()

    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 显示倒数和回合开始信息
            print("Episode {} start in: ".format(i+1), end="")
            for countdown in range(2, 0, -1):
                print("{} ".format(countdown), end="", flush=True)
                time.sleep(1)
            print("\nEpisode {} start!".format(i+1))

            # 随机设置小车的初始状态
            initial_position = np.random.uniform(-1.2, 0.6)
            initial_velocity = np.random.uniform(-0.07, 0.07)  # 速度允许范围

            # 使用 reset 并传递随机初始化位置和速度
            env.reset(options={"state": [initial_position, initial_velocity]})

            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_random_initial_state(30, render=True)

# %% [markdown]
# ### Finally, the initial position and velocity can be set correctly, but need to be limited before the goal (before 0.45)

# %%
def run_continuous_action_test_with_random_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()

    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 显示倒数和回合开始信息
            print("Episode {} start in: ".format(i+1), end="")
            for countdown in range(2, 0, -1):
                print("{} ".format(countdown), end="", flush=True)
                time.sleep(1)
            print("\nEpisode {} start!".format(i+1))

            # 随机设置小车的初始状态
            initial_position = np.random.uniform(-1.2, 0.44)
            initial_velocity = np.random.uniform(-0.07, 0.07)  # 速度允许范围

            # 重置环境，并手动设置小车的初始状态
            env.reset()  # 重置环境
            env.unwrapped.state = np.array([initial_position, initial_velocity])  # 手动修改状态

            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_random_initial_state(10, render=True)
