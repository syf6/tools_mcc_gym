# %%
import numpy as np
import gymnasium as gym
import pygame
import csv
import time

# %% [markdown]
# Fixed Initial Position and Speed, not robust for expert policy

# %%
def run_continuous_action_test_with_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()
    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 手动设置小车的初始状态为底部，位置接近 -1.2，速度为 0
            env.reset()
            env.env.state = np.array([-1.2, 0.0]) # not correct, has already reseted in the env.reset()
            
            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_initial_state(10, render=True)
# Out:
# Initialized Joystick: Logicool Dual Action
# Number of axes: 4
# Episode 1, Action: 0.0000
# New State: Position = -0.4498, Velocity = -0.0006
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4509, Velocity = -0.0011
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4525, Velocity = -0.0016
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4547, Velocity = -0.0022
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4574, Velocity = -0.0027
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4605, Velocity = -0.0032
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4642, Velocity = -0.0036
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4683, Velocity = -0.0041
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4728, Velocity = -0.0045
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4777, Velocity = -0.0049
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4829, Velocity = -0.0052
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4884, Velocity = -0.0055
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4942, Velocity = -0.0058
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5003, Velocity = -0.0060
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5064, Velocity = -0.0062
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5128, Velocity = -0.0063
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5192, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5256, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5320, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5384, Velocity = -0.0064
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5446, Velocity = -0.0062
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5507, Velocity = -0.0061
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5566, Velocity = -0.0059
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5622, Velocity = -0.0056
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5676, Velocity = -0.0053
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5726, Velocity = -0.0050
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5773, Velocity = -0.0047
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5815, Velocity = -0.0043
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5853, Velocity = -0.0038
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5887, Velocity = -0.0034
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5916, Velocity = -0.0029
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5939, Velocity = -0.0024
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5958, Velocity = -0.0018
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5971, Velocity = -0.0013
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5978, Velocity = -0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5981, Velocity = -0.0002
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5977, Velocity = 0.0003
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5968, Velocity = 0.0009
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5954, Velocity = 0.0014
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5934, Velocity = 0.0020
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5909, Velocity = 0.0025
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5879, Velocity = 0.0030
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5844, Velocity = 0.0035
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5805, Velocity = 0.0039
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5762, Velocity = 0.0044
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5714, Velocity = 0.0047
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5663, Velocity = 0.0051
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5609, Velocity = 0.0054
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5552, Velocity = 0.0057
#
# Episode 1, Action: 0.0397
# New State: Position = -0.5492, Velocity = 0.0060
#
# Episode 1, Action: 0.2937
# New State: Position = -0.5426, Velocity = 0.0066
#
# Episode 1, Action: 0.7698
# New State: Position = -0.5346, Velocity = 0.0079
#
# Episode 1, Action: 0.9682
# New State: Position = -0.5252, Velocity = 0.0095
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5142, Velocity = 0.0110
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5018, Velocity = 0.0124
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4880, Velocity = 0.0137
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4731, Velocity = 0.0150
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4570, Velocity = 0.0161
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4399, Velocity = 0.0171
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4219, Velocity = 0.0180
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4032, Velocity = 0.0187
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3838, Velocity = 0.0193
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3640, Velocity = 0.0198
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3438, Velocity = 0.0202
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3234, Velocity = 0.0204
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3030, Velocity = 0.0205
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2825, Velocity = 0.0204
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2622, Velocity = 0.0203
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2422, Velocity = 0.0200
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2226, Velocity = 0.0197
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2034, Velocity = 0.0192
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1847, Velocity = 0.0186
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1667, Velocity = 0.0180
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1494, Velocity = 0.0173
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1328, Velocity = 0.0166
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1171, Velocity = 0.0158
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1022, Velocity = 0.0149
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0881, Velocity = 0.0140
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0750, Velocity = 0.0131
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0628, Velocity = 0.0122
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0516, Velocity = 0.0112
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0413, Velocity = 0.0103
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0321, Velocity = 0.0093
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0238, Velocity = 0.0083
#
# Episode 1, Action: 0.6190
# New State: Position = -0.0171, Velocity = 0.0067
#
# Episode 1, Action: 0.1588
# New State: Position = -0.0126, Velocity = 0.0045
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0106, Velocity = 0.0020
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0112, Velocity = -0.0005
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0142, Velocity = -0.0030
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0197, Velocity = -0.0055
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0278, Velocity = -0.0080
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0383, Velocity = -0.0105
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0513, Velocity = -0.0130
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0667, Velocity = -0.0155
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0847, Velocity = -0.0179
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1050, Velocity = -0.0203
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1277, Velocity = -0.0227
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1528, Velocity = -0.0250
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1800, Velocity = -0.0273
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2095, Velocity = -0.0294
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2409, Velocity = -0.0314
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2742, Velocity = -0.0333
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3093, Velocity = -0.0350
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3458, Velocity = -0.0365
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3836, Velocity = -0.0378
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4224, Velocity = -0.0388
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4619, Velocity = -0.0396
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5020, Velocity = -0.0400
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5421, Velocity = -0.0402
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5822, Velocity = -0.0400
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6218, Velocity = -0.0396
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6607, Velocity = -0.0389
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6985, Velocity = -0.0379
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7352, Velocity = -0.0366
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7703, Velocity = -0.0351
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8038, Velocity = -0.0335
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8354, Velocity = -0.0316
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8650, Velocity = -0.0296
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8924, Velocity = -0.0274
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9176, Velocity = -0.0252
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9405, Velocity = -0.0229
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9610, Velocity = -0.0205
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9791, Velocity = -0.0181
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9948, Velocity = -0.0157
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0080, Velocity = -0.0132
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0187, Velocity = -0.0107
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0269, Velocity = -0.0082
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0327, Velocity = -0.0057
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0359, Velocity = -0.0032
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0366, Velocity = -0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0348, Velocity = 0.0018
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0306, Velocity = 0.0043
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0238, Velocity = 0.0068
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0145, Velocity = 0.0093
#
# Episode 1, Action: 0.0000
# New State: Position = -1.0028, Velocity = 0.0117
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9886, Velocity = 0.0142
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9719, Velocity = 0.0167
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9528, Velocity = 0.0191
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9312, Velocity = 0.0215
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9074, Velocity = 0.0239
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8812, Velocity = 0.0262
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8528, Velocity = 0.0284
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8224, Velocity = 0.0304
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7900, Velocity = 0.0324
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7558, Velocity = 0.0342
#
# Episode 1, Action: 0.3651
# New State: Position = -0.7195, Velocity = 0.0363
#
# Episode 1, Action: 0.9127
# New State: Position = -0.6804, Velocity = 0.0391
#
# Episode 1, Action: 1.0000
# New State: Position = -0.6387, Velocity = 0.0417
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5946, Velocity = 0.0441
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5485, Velocity = 0.0461
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5007, Velocity = 0.0478
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4516, Velocity = 0.0491
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4015, Velocity = 0.0501
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3508, Velocity = 0.0507
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2999, Velocity = 0.0509
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2490, Velocity = 0.0509
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1984, Velocity = 0.0506
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1485, Velocity = 0.0500
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0992, Velocity = 0.0492
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0509, Velocity = 0.0483
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0035, Velocity = 0.0474
#
# Episode 1, Action: 1.0000
# New State: Position = 0.0429, Velocity = 0.0464
#
# Episode 1, Action: 1.0000
# New State: Position = 0.0882, Velocity = 0.0454
#
# Episode 1, Action: 1.0000
# New State: Position = 0.1327, Velocity = 0.0445
#
# Episode 1, Action: 1.0000
# New State: Position = 0.1764, Velocity = 0.0437
#
# Episode 1, Action: 1.0000
# New State: Position = 0.2194, Velocity = 0.0430
#
# Episode 1, Action: 1.0000
# New State: Position = 0.2619, Velocity = 0.0425
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3042, Velocity = 0.0423
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3465, Velocity = 0.0422
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3889, Velocity = 0.0425
#
# Episode 1, Action: 1.0000
# New State: Position = 0.4319, Velocity = 0.0430
#
# Episode 1, Action: 1.0000
# New State: Position = 0.4757, Velocity = 0.0438
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4774, Velocity = 0.0012
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4751, Velocity = 0.0023
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4717, Velocity = 0.0035
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4671, Velocity = 0.0046
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4614, Velocity = 0.0056
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4548, Velocity = 0.0067
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4471, Velocity = 0.0077
#
# Episode 2, Action: 0.6190
# New State: Position = -0.4391, Velocity = 0.0080
#
# Episode 2, Action: 0.1270
# New State: Position = -0.4315, Velocity = 0.0076
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4246, Velocity = 0.0069
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4184, Velocity = 0.0062
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4130, Velocity = 0.0054
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4084, Velocity = 0.0046
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4046, Velocity = 0.0037
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4018, Velocity = 0.0029
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3998, Velocity = 0.0020
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3987, Velocity = 0.0011
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3986, Velocity = 0.0002
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3993, Velocity = -0.0008
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4010, Velocity = -0.0017
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4036, Velocity = -0.0026
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4070, Velocity = -0.0035
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4114, Velocity = -0.0043
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4165, Velocity = -0.0051
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4224, Velocity = -0.0059
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4291, Velocity = -0.0067
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4365, Velocity = -0.0074
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4445, Velocity = -0.0080
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4531, Velocity = -0.0086
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4622, Velocity = -0.0091
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4718, Velocity = -0.0096
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4818, Velocity = -0.0100
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4921, Velocity = -0.0103
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5026, Velocity = -0.0105
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5133, Velocity = -0.0107
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5240, Velocity = -0.0108
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5348, Velocity = -0.0108
#
# Episode 2, Action: -0.0625
# New State: Position = -0.5456, Velocity = -0.0108
#
# Episode 2, Action: -0.3203
# New State: Position = -0.5566, Velocity = -0.0111
#
# Episode 2, Action: -0.6484
# New State: Position = -0.5684, Velocity = -0.0118
#
# Episode 2, Action: -0.9219
# New State: Position = -0.5813, Velocity = -0.0129
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5952, Velocity = -0.0139
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6101, Velocity = -0.0149
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6259, Velocity = -0.0157
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6424, Velocity = -0.0165
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6595, Velocity = -0.0171
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6771, Velocity = -0.0176
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6951, Velocity = -0.0180
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7134, Velocity = -0.0183
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7319, Velocity = -0.0184
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7503, Velocity = -0.0185
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7687, Velocity = -0.0184
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7870, Velocity = -0.0182
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8049, Velocity = -0.0180
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8225, Velocity = -0.0176
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8396, Velocity = -0.0171
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8562, Velocity = -0.0166
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8722, Velocity = -0.0160
#
# Episode 2, Action: -0.7500
# New State: Position = -0.8872, Velocity = -0.0150
#
# Episode 2, Action: -0.3438
# New State: Position = -0.9005, Velocity = -0.0133
#
# Episode 2, Action: -0.0938
# New State: Position = -0.9116, Velocity = -0.0111
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9204, Velocity = -0.0088
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9270, Velocity = -0.0065
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9312, Velocity = -0.0042
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9330, Velocity = -0.0018
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9325, Velocity = 0.0005
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9296, Velocity = 0.0029
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9244, Velocity = 0.0052
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9168, Velocity = 0.0076
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9069, Velocity = 0.0099
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8948, Velocity = 0.0121
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8804, Velocity = 0.0144
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8638, Velocity = 0.0166
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8451, Velocity = 0.0187
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8243, Velocity = 0.0208
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8016, Velocity = 0.0227
#
# Episode 2, Action: 0.0000
# New State: Position = -0.7770, Velocity = 0.0246
#
# Episode 2, Action: 0.1111
# New State: Position = -0.7506, Velocity = 0.0265
#
# Episode 2, Action: 0.3651
# New State: Position = -0.7220, Velocity = 0.0286
#
# Episode 2, Action: 0.6587
# New State: Position = -0.6910, Velocity = 0.0310
#
# Episode 2, Action: 0.8571
# New State: Position = -0.6575, Velocity = 0.0335
#
# Episode 2, Action: 0.9841
# New State: Position = -0.6216, Velocity = 0.0359
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5834, Velocity = 0.0382
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5433, Velocity = 0.0401
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5016, Velocity = 0.0417
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4585, Velocity = 0.0431
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4144, Velocity = 0.0441
#
# Episode 2, Action: 1.0000
# New State: Position = -0.3696, Velocity = 0.0448
#
# Episode 2, Action: 1.0000
# New State: Position = -0.3244, Velocity = 0.0452
#
# Episode 2, Action: 1.0000
# New State: Position = -0.2792, Velocity = 0.0453
#
# Episode 2, Action: 1.0000
# New State: Position = -0.2341, Velocity = 0.0451
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1894, Velocity = 0.0447
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1453, Velocity = 0.0441
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1020, Velocity = 0.0433
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0596, Velocity = 0.0424
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0181, Velocity = 0.0415
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0224, Velocity = 0.0405
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0618, Velocity = 0.0395
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1004, Velocity = 0.0385
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1380, Velocity = 0.0376
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1749, Velocity = 0.0368
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2110, Velocity = 0.0362
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2467, Velocity = 0.0357
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2820, Velocity = 0.0353
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3172, Velocity = 0.0352
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3524, Velocity = 0.0352
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3879, Velocity = 0.0355
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4239, Velocity = 0.0360
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4606, Velocity = 0.0368
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4462, Velocity = 0.0009
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4443, Velocity = 0.0019
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4416, Velocity = 0.0028
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4379, Velocity = 0.0037
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4334, Velocity = 0.0045
#
# Episode 3, Action: 0.9286
# New State: Position = -0.4281, Velocity = 0.0052
#
# Episode 3, Action: 0.7698
# New State: Position = -0.4224, Velocity = 0.0057
#
# Episode 3, Action: 0.6270
# New State: Position = -0.4165, Velocity = 0.0059
#
# Episode 3, Action: 0.3254
# New State: Position = -0.4110, Velocity = 0.0056
#
# Episode 3, Action: 0.0476
# New State: Position = -0.4061, Velocity = 0.0048
#
# Episode 3, Action: 0.0000
# New State: Position = -0.4022, Velocity = 0.0040
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3991, Velocity = 0.0031
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3969, Velocity = 0.0022
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3957, Velocity = 0.0012
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3954, Velocity = 0.0003
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3960, Velocity = -0.0006
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3976, Velocity = -0.0016
#
# Episode 3, Action: -0.0703
# New State: Position = -0.4002, Velocity = -0.0026
#
# Episode 3, Action: -0.2031
# New State: Position = -0.4040, Velocity = -0.0038
#
# Episode 3, Action: -0.3438
# New State: Position = -0.4092, Velocity = -0.0052
#
# Episode 3, Action: -0.4219
# New State: Position = -0.4159, Velocity = -0.0067
#
# Episode 3, Action: -0.5312
# New State: Position = -0.4241, Velocity = -0.0083
#
# Episode 3, Action: -0.6562
# New State: Position = -0.4341, Velocity = -0.0100
#
# Episode 3, Action: -0.8359
# New State: Position = -0.4460, Velocity = -0.0119
#
# Episode 3, Action: -0.9609
# New State: Position = -0.4600, Velocity = -0.0139
#
# Episode 3, Action: -1.0000
# New State: Position = -0.4759, Velocity = -0.0159
#
# Episode 3, Action: -1.0000
# New State: Position = -0.4936, Velocity = -0.0178
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5131, Velocity = -0.0195
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5341, Velocity = -0.0211
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5566, Velocity = -0.0225
#
# Episode 3, Action: -1.0000
# New State: Position = -0.5803, Velocity = -0.0237
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6052, Velocity = -0.0248
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6309, Velocity = -0.0257
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6573, Velocity = -0.0264
#
# Episode 3, Action: -1.0000
# New State: Position = -0.6842, Velocity = -0.0269
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7115, Velocity = -0.0273
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7389, Velocity = -0.0274
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7663, Velocity = -0.0274
#
# Episode 3, Action: -1.0000
# New State: Position = -0.7936, Velocity = -0.0273
#
# Episode 3, Action: -1.0000
# New State: Position = -0.8206, Velocity = -0.0270
#
# Episode 3, Action: -1.0000
# New State: Position = -0.8471, Velocity = -0.0265
#
# Episode 3, Action: -0.7344
# New State: Position = -0.8726, Velocity = -0.0256
#
# Episode 3, Action: -0.2812
# New State: Position = -0.8965, Velocity = -0.0238
#
# Episode 3, Action: -0.0078
# New State: Position = -0.9180, Velocity = -0.0216
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9373, Velocity = -0.0193
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9542, Velocity = -0.0169
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9687, Velocity = -0.0145
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9807, Velocity = -0.0121
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9904, Velocity = -0.0096
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9975, Velocity = -0.0071
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0022, Velocity = -0.0047
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0044, Velocity = -0.0022
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0041, Velocity = 0.0003
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0013, Velocity = 0.0028
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9961, Velocity = 0.0052
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0077
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9782, Velocity = 0.0102
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9656, Velocity = 0.0126
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9505, Velocity = 0.0150
#
# Episode 3, Action: 0.0714
# New State: Position = -0.9330, Velocity = 0.0175
#
# Episode 3, Action: 0.3730
# New State: Position = -0.9125, Velocity = 0.0205
#
# Episode 3, Action: 0.7698
# New State: Position = -0.8886, Velocity = 0.0239
#
# Episode 3, Action: 0.9920
# New State: Position = -0.8610, Velocity = 0.0276
#
# Episode 3, Action: 1.0000
# New State: Position = -0.8298, Velocity = 0.0312
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7950, Velocity = 0.0347
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7570, Velocity = 0.0380
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7158, Velocity = 0.0412
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6718, Velocity = 0.0440
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6252, Velocity = 0.0466
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5764, Velocity = 0.0488
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5256, Velocity = 0.0507
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4734, Velocity = 0.0523
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4200, Velocity = 0.0534
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3659, Velocity = 0.0541
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3114, Velocity = 0.0545
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2569, Velocity = 0.0545
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2027, Velocity = 0.0542
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1491, Velocity = 0.0536
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0962, Velocity = 0.0529
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0442, Velocity = 0.0520
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0068, Velocity = 0.0510
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0569, Velocity = 0.0500
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1059, Velocity = 0.0491
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1541, Velocity = 0.0482
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2015, Velocity = 0.0474
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2484, Velocity = 0.0469
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2950, Velocity = 0.0465
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3414, Velocity = 0.0465
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3881, Velocity = 0.0467
#
# Episode 3, Action: 1.0000
# New State: Position = 0.4353, Velocity = 0.0472
#
# Episode 3, Action: 1.0000
# New State: Position = 0.4833, Velocity = 0.0480
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5842, Velocity = 0.0020
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5803, Velocity = 0.0039
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5745, Velocity = 0.0058
#
# Episode 4, Action: 0.5476
# New State: Position = -0.5674, Velocity = 0.0070
#
# Episode 4, Action: 0.0635
# New State: Position = -0.5599, Velocity = 0.0075
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5522, Velocity = 0.0077
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5443, Velocity = 0.0080
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5361, Velocity = 0.0081
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5279, Velocity = 0.0082
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5197, Velocity = 0.0082
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5115, Velocity = 0.0082
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5034, Velocity = 0.0081
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4954, Velocity = 0.0080
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4877, Velocity = 0.0078
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4802, Velocity = 0.0075
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4730, Velocity = 0.0072
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4663, Velocity = 0.0068
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4599, Velocity = 0.0064
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4540, Velocity = 0.0059
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4487, Velocity = 0.0054
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4439, Velocity = 0.0048
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4397, Velocity = 0.0042
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4361, Velocity = 0.0036
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4331, Velocity = 0.0029
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4309, Velocity = 0.0023
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4293, Velocity = 0.0016
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4284, Velocity = 0.0009
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4282, Velocity = 0.0002
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4287, Velocity = -0.0005
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4300, Velocity = -0.0012
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4319, Velocity = -0.0019
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4345, Velocity = -0.0026
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4378, Velocity = -0.0033
#
# Episode 4, Action: 0.2460
# New State: Position = -0.4413, Velocity = -0.0035
#
# Episode 4, Action: 0.7301
# New State: Position = -0.4443, Velocity = -0.0030
#
# Episode 4, Action: 0.9920
# New State: Position = -0.4465, Velocity = -0.0021
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4477, Velocity = -0.0012
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4480, Velocity = -0.0003
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4473, Velocity = 0.0007
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4457, Velocity = 0.0016
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4432, Velocity = 0.0025
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4398, Velocity = 0.0034
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4355, Velocity = 0.0043
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4304, Velocity = 0.0051
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4244, Velocity = 0.0059
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4177, Velocity = 0.0067
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4103, Velocity = 0.0074
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4022, Velocity = 0.0081
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3935, Velocity = 0.0087
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3842, Velocity = 0.0093
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3745, Velocity = 0.0097
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3643, Velocity = 0.0102
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3538, Velocity = 0.0105
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3430, Velocity = 0.0108
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3320, Velocity = 0.0110
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3209, Velocity = 0.0111
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3097, Velocity = 0.0112
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2984, Velocity = 0.0112
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2873, Velocity = 0.0112
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2763, Velocity = 0.0110
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2654, Velocity = 0.0108
#
# Episode 4, Action: 0.9127
# New State: Position = -0.2550, Velocity = 0.0105
#
# Episode 4, Action: 0.4524
# New State: Position = -0.2456, Velocity = 0.0093
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2381, Velocity = 0.0075
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2325, Velocity = 0.0056
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2289, Velocity = 0.0037
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2271, Velocity = 0.0017
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2273, Velocity = -0.0002
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2295, Velocity = -0.0021
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2335, Velocity = -0.0041
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2395, Velocity = -0.0060
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2474, Velocity = -0.0079
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2571, Velocity = -0.0097
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2686, Velocity = -0.0115
#
# Episode 4, Action: -0.0078
# New State: Position = -0.2818, Velocity = -0.0132
#
# Episode 4, Action: -0.0938
# New State: Position = -0.2968, Velocity = -0.0150
#
# Episode 4, Action: -0.3984
# New State: Position = -0.3141, Velocity = -0.0172
#
# Episode 4, Action: -0.7031
# New State: Position = -0.3338, Velocity = -0.0197
#
# Episode 4, Action: -0.9609
# New State: Position = -0.3563, Velocity = -0.0225
#
# Episode 4, Action: -1.0000
# New State: Position = -0.3815, Velocity = -0.0252
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4093, Velocity = -0.0278
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4394, Velocity = -0.0301
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4716, Velocity = -0.0322
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5057, Velocity = -0.0341
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5415, Velocity = -0.0357
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5786, Velocity = -0.0371
#
# Episode 4, Action: -0.5859
# New State: Position = -0.6162, Velocity = -0.0376
#
# Episode 4, Action: -0.0312
# New State: Position = -0.6531, Velocity = -0.0369
#
# Episode 4, Action: 0.0000
# New State: Position = -0.6891, Velocity = -0.0360
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7239, Velocity = -0.0348
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7573, Velocity = -0.0334
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7891, Velocity = -0.0318
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8191, Velocity = -0.0300
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8471, Velocity = -0.0281
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8731, Velocity = -0.0260
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8970, Velocity = -0.0238
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9185, Velocity = -0.0216
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9378, Velocity = -0.0193
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9547, Velocity = -0.0169
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9692, Velocity = -0.0145
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9812, Velocity = -0.0121
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9908, Velocity = -0.0096
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9980, Velocity = -0.0071
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0026, Velocity = -0.0047
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0048, Velocity = -0.0022
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0045, Velocity = 0.0003
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0018, Velocity = 0.0028
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9965, Velocity = 0.0052
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9888, Velocity = 0.0077
#
# Episode 4, Action: 0.0080
# New State: Position = -0.9786, Velocity = 0.0102
#
# Episode 4, Action: 0.1508
# New State: Position = -0.9657, Velocity = 0.0129
#
# Episode 4, Action: 0.3968
# New State: Position = -0.9498, Velocity = 0.0159
#
# Episode 4, Action: 0.5079
# New State: Position = -0.9308, Velocity = 0.0190
#
# Episode 4, Action: 0.7540
# New State: Position = -0.9083, Velocity = 0.0225
#
# Episode 4, Action: 0.9444
# New State: Position = -0.8821, Velocity = 0.0262
#
# Episode 4, Action: 1.0000
# New State: Position = -0.8521, Velocity = 0.0299
#
# Episode 4, Action: 1.0000
# New State: Position = -0.8186, Velocity = 0.0335
#
# Episode 4, Action: 1.0000
# New State: Position = -0.7817, Velocity = 0.0369
#
# Episode 4, Action: 1.0000
# New State: Position = -0.7415, Velocity = 0.0402
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6983, Velocity = 0.0432
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6523, Velocity = 0.0460
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6039, Velocity = 0.0484
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5534, Velocity = 0.0505
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5012, Velocity = 0.0522
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4476, Velocity = 0.0536
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3931, Velocity = 0.0545
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3381, Velocity = 0.0550
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2829, Velocity = 0.0552
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2278, Velocity = 0.0551
#
# Episode 4, Action: 1.0000
# New State: Position = -0.1732, Velocity = 0.0546
#
# Episode 4, Action: 1.0000
# New State: Position = -0.1192, Velocity = 0.0540
#
# Episode 4, Action: 1.0000
# New State: Position = -0.0661, Velocity = 0.0531
#
# Episode 4, Action: 1.0000
# New State: Position = -0.0140, Velocity = 0.0522
#
# Episode 4, Action: 1.0000
# New State: Position = 0.0372, Velocity = 0.0512
#
# Episode 4, Action: 1.0000
# New State: Position = 0.0874, Velocity = 0.0502
#
# Episode 4, Action: 1.0000
# New State: Position = 0.1366, Velocity = 0.0493
#
# Episode 4, Action: 1.0000
# New State: Position = 0.1851, Velocity = 0.0485
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2330, Velocity = 0.0478
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2804, Velocity = 0.0474
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3277, Velocity = 0.0473
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3750, Velocity = 0.0474
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4229, Velocity = 0.0478
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4714, Velocity = 0.0486
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5491, Velocity = 0.0002
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5487, Velocity = 0.0004
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5482, Velocity = 0.0006
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5474, Velocity = 0.0008
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5465, Velocity = 0.0009
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5454, Velocity = 0.0011
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5441, Velocity = 0.0013
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5427, Velocity = 0.0014
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5411, Velocity = 0.0016
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5394, Velocity = 0.0017
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5376, Velocity = 0.0018
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5357, Velocity = 0.0019
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5337, Velocity = 0.0020
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5316, Velocity = 0.0021
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5294, Velocity = 0.0021
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5272, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5250, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5228, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5206, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5184, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5162, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5141, Velocity = 0.0021
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5121, Velocity = 0.0020
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5101, Velocity = 0.0019
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5083, Velocity = 0.0018
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5066, Velocity = 0.0017
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5050, Velocity = 0.0016
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5035, Velocity = 0.0015
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5022, Velocity = 0.0013
#
# Episode 5, Action: 0.0873
# New State: Position = -0.5009, Velocity = 0.0013
#
# Episode 5, Action: 0.5952
# New State: Position = -0.4989, Velocity = 0.0020
#
# Episode 5, Action: 0.9286
# New State: Position = -0.4957, Velocity = 0.0032
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4912, Velocity = 0.0045
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4854, Velocity = 0.0058
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4784, Velocity = 0.0070
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4703, Velocity = 0.0081
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4611, Velocity = 0.0092
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4508, Velocity = 0.0103
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4396, Velocity = 0.0112
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4274, Velocity = 0.0121
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4146, Velocity = 0.0129
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4010, Velocity = 0.0136
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3868, Velocity = 0.0142
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3721, Velocity = 0.0147
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3570, Velocity = 0.0151
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3416, Velocity = 0.0154
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3260, Velocity = 0.0156
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3103, Velocity = 0.0157
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2946, Velocity = 0.0157
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2789, Velocity = 0.0156
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2635, Velocity = 0.0155
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2483, Velocity = 0.0152
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2334, Velocity = 0.0149
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2190, Velocity = 0.0144
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2050, Velocity = 0.0140
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1916, Velocity = 0.0134
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1788, Velocity = 0.0128
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1666, Velocity = 0.0122
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1551, Velocity = 0.0115
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1444, Velocity = 0.0107
#
# Episode 5, Action: 0.8492
# New State: Position = -0.1346, Velocity = 0.0097
#
# Episode 5, Action: 0.5873
# New State: Position = -0.1263, Velocity = 0.0083
#
# Episode 5, Action: 0.1429
# New State: Position = -0.1201, Velocity = 0.0062
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1162, Velocity = 0.0039
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1147, Velocity = 0.0015
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1155, Velocity = -0.0008
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1186, Velocity = -0.0032
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1242, Velocity = -0.0055
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1320, Velocity = -0.0078
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1422, Velocity = -0.0101
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1546, Velocity = -0.0124
#
# Episode 5, Action: 0.0000
# New State: Position = -0.1692, Velocity = -0.0147
#
# Episode 5, Action: -0.0391
# New State: Position = -0.1861, Velocity = -0.0169
#
# Episode 5, Action: -0.2188
# New State: Position = -0.2055, Velocity = -0.0194
#
# Episode 5, Action: -0.4297
# New State: Position = -0.2275, Velocity = -0.0220
#
# Episode 5, Action: -0.6719
# New State: Position = -0.2525, Velocity = -0.0250
#
# Episode 5, Action: -0.9141
# New State: Position = -0.2807, Velocity = -0.0282
#
# Episode 5, Action: -1.0000
# New State: Position = -0.3120, Velocity = -0.0313
#
# Episode 5, Action: -1.0000
# New State: Position = -0.3463, Velocity = -0.0343
#
# Episode 5, Action: -1.0000
# New State: Position = -0.3834, Velocity = -0.0371
#
# Episode 5, Action: -1.0000
# New State: Position = -0.4230, Velocity = -0.0396
#
# Episode 5, Action: -1.0000
# New State: Position = -0.4649, Velocity = -0.0419
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5087, Velocity = -0.0438
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5541, Velocity = -0.0454
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6008, Velocity = -0.0467
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6483, Velocity = -0.0476
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6965, Velocity = -0.0482
#
# Episode 5, Action: -0.8125
# New State: Position = -0.7447, Velocity = -0.0482
#
# Episode 5, Action: -0.2344
# New State: Position = -0.7917, Velocity = -0.0470
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8368, Velocity = -0.0452
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8800, Velocity = -0.0432
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9210, Velocity = -0.0410
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9596, Velocity = -0.0386
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9958, Velocity = -0.0362
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0296, Velocity = -0.0338
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0609, Velocity = -0.0313
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0896, Velocity = -0.0288
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1159, Velocity = -0.0263
#
# Episode 5, Action: 0.2460
# New State: Position = -1.1394, Velocity = -0.0235
#
# Episode 5, Action: 0.7460
# New State: Position = -1.1593, Velocity = -0.0199
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1754, Velocity = -0.0161
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1877, Velocity = -0.0123
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1961, Velocity = -0.0085
#
# Episode 5, Action: 1.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1963, Velocity = 0.0037
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1888, Velocity = 0.0075
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1775, Velocity = 0.0113
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1624, Velocity = 0.0151
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1435, Velocity = 0.0189
#
# Episode 5, Action: 1.0000
# New State: Position = -1.1206, Velocity = 0.0228
#
# Episode 5, Action: 1.0000
# New State: Position = -1.0939, Velocity = 0.0268
#
# Episode 5, Action: 1.0000
# New State: Position = -1.0631, Velocity = 0.0307
#
# ...
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5574, Velocity = 0.0233
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5339, Velocity = 0.0235
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5103, Velocity = 0.0236
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4868, Velocity = 0.0235
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4636, Velocity = 0.0232
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4409, Velocity = 0.0228
#
# Episode 9, Action: 0.0000
# New State: Position = -0.4187, Velocity = 0.0222
#
# Episode 9, Action: 0.0000
# New State: Position = -0.3973, Velocity = 0.0214
#
# Episode 9, Action: 0.1191
# New State: Position = -0.3767, Velocity = 0.0206
#
# Episode 9, Action: 0.4762
# New State: Position = -0.3564, Velocity = 0.0203
#
# Episode 9, Action: 0.8412
# New State: Position = -0.3361, Velocity = 0.0203
#
# Episode 9, Action: 1.0000
# New State: Position = -0.3156, Velocity = 0.0205
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2950, Velocity = 0.0205
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2746, Velocity = 0.0205
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2543, Velocity = 0.0203
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2343, Velocity = 0.0200
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2148, Velocity = 0.0196
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1957, Velocity = 0.0191
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1773, Velocity = 0.0185
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1594, Velocity = 0.0178
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1423, Velocity = 0.0171
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1260, Velocity = 0.0163
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1105, Velocity = 0.0155
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0959, Velocity = 0.0146
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0822, Velocity = 0.0137
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0693, Velocity = 0.0128
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0575, Velocity = 0.0119
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0466, Velocity = 0.0109
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0366, Velocity = 0.0099
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0277, Velocity = 0.0089
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0198, Velocity = 0.0080
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0128, Velocity = 0.0070
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0068, Velocity = 0.0060
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0019, Velocity = 0.0050
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0021, Velocity = 0.0040
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0050, Velocity = 0.0030
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0070, Velocity = 0.0020
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0079, Velocity = 0.0010
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0079, Velocity = -0.0000
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0069, Velocity = -0.0010
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0048, Velocity = -0.0020
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0018, Velocity = -0.0030
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0023, Velocity = -0.0040
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0073, Velocity = -0.0050
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0133, Velocity = -0.0060
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0204, Velocity = -0.0070
#
# Episode 9, Action: 0.6825
# New State: Position = -0.0289, Velocity = -0.0085
#
# Episode 9, Action: 0.1429
# New State: Position = -0.0397, Velocity = -0.0108
#
# Episode 9, Action: 0.0000
# New State: Position = -0.0529, Velocity = -0.0133
#
# Episode 9, Action: 0.0000
# New State: Position = -0.0687, Velocity = -0.0157
#
# Episode 9, Action: -0.0156
# New State: Position = -0.0869, Velocity = -0.0182
#
# Episode 9, Action: -0.0938
# New State: Position = -0.1076, Velocity = -0.0208
#
# Episode 9, Action: -0.2812
# New State: Position = -0.1312, Velocity = -0.0236
#
# Episode 9, Action: -0.6484
# New State: Position = -0.1580, Velocity = -0.0268
#
# Episode 9, Action: -0.9141
# New State: Position = -0.1885, Velocity = -0.0304
#
# Episode 9, Action: -1.0000
# New State: Position = -0.2225, Velocity = -0.0340
#
# Episode 9, Action: -1.0000
# New State: Position = -0.2600, Velocity = -0.0375
#
# Episode 9, Action: -1.0000
# New State: Position = -0.3008, Velocity = -0.0408
#
# Episode 9, Action: -1.0000
# New State: Position = -0.3446, Velocity = -0.0438
#
# Episode 9, Action: -1.0000
# New State: Position = -0.3912, Velocity = -0.0466
#
# Episode 9, Action: -0.8906
# New State: Position = -0.4402, Velocity = -0.0489
#
# Episode 9, Action: -0.4922
# New State: Position = -0.4904, Velocity = -0.0503
#
# Episode 9, Action: -0.0469
# New State: Position = -0.5410, Velocity = -0.0506
#
# Episode 9, Action: 0.0000
# New State: Position = -0.5915, Velocity = -0.0505
#
# Episode 9, Action: 0.0000
# New State: Position = -0.6414, Velocity = -0.0500
#
# Episode 9, Action: 0.0000
# New State: Position = -0.6905, Velocity = -0.0491
#
# Episode 9, Action: 0.0000
# New State: Position = -0.7384, Velocity = -0.0479
#
# Episode 9, Action: 0.0000
# New State: Position = -0.7848, Velocity = -0.0464
#
# Episode 9, Action: 0.0000
# New State: Position = -0.8294, Velocity = -0.0446
#
# Episode 9, Action: 0.0000
# New State: Position = -0.8721, Velocity = -0.0426
#
# Episode 9, Action: 0.0000
# New State: Position = -0.9125, Velocity = -0.0405
#
# Episode 9, Action: 0.0000
# New State: Position = -0.9507, Velocity = -0.0382
#
# Episode 9, Action: 0.0000
# New State: Position = -0.9865, Velocity = -0.0358
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0198, Velocity = -0.0333
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0506, Velocity = -0.0308
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0790, Velocity = -0.0283
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1048, Velocity = -0.0258
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1282, Velocity = -0.0234
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1491, Velocity = -0.0210
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1677, Velocity = -0.0186
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1839, Velocity = -0.0162
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1979, Velocity = -0.0139
#
# Episode 9, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 9, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 9, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 9, Action: 0.1349
# New State: Position = -0.9882, Velocity = 0.0311
#
# Episode 9, Action: 0.6270
# New State: Position = -0.9537, Velocity = 0.0345
#
# Episode 9, Action: 0.9286
# New State: Position = -0.9154, Velocity = 0.0383
#
# Episode 9, Action: 1.0000
# New State: Position = -0.8733, Velocity = 0.0421
#
# Episode 9, Action: 1.0000
# New State: Position = -0.8276, Velocity = 0.0458
#
# Episode 9, Action: 1.0000
# New State: Position = -0.7784, Velocity = 0.0492
#
# Episode 9, Action: 1.0000
# New State: Position = -0.7259, Velocity = 0.0525
#
# Episode 9, Action: 1.0000
# New State: Position = -0.6705, Velocity = 0.0554
#
# Episode 9, Action: 1.0000
# New State: Position = -0.6125, Velocity = 0.0580
#
# Episode 9, Action: 1.0000
# New State: Position = -0.5524, Velocity = 0.0601
#
# Episode 9, Action: 1.0000
# New State: Position = -0.4906, Velocity = 0.0618
#
# Episode 9, Action: 1.0000
# New State: Position = -0.4275, Velocity = 0.0631
#
# Episode 9, Action: 1.0000
# New State: Position = -0.3637, Velocity = 0.0639
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2994, Velocity = 0.0642
#
# Episode 9, Action: 1.0000
# New State: Position = -0.2353, Velocity = 0.0642
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1715, Velocity = 0.0638
#
# Episode 9, Action: 1.0000
# New State: Position = -0.1084, Velocity = 0.0631
#
# Episode 9, Action: 1.0000
# New State: Position = -0.0462, Velocity = 0.0622
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0150, Velocity = 0.0612
#
# Episode 9, Action: 1.0000
# New State: Position = 0.0752, Velocity = 0.0602
#
# Episode 9, Action: 1.0000
# New State: Position = 0.1345, Velocity = 0.0593
#
# Episode 9, Action: 1.0000
# New State: Position = 0.1930, Velocity = 0.0585
#
# Episode 9, Action: 1.0000
# New State: Position = 0.2510, Velocity = 0.0579
#
# Episode 9, Action: 1.0000
# New State: Position = 0.3085, Velocity = 0.0576
#
# Episode 9, Action: 1.0000
# New State: Position = 0.3661, Velocity = 0.0576
#
# Episode 9, Action: 1.0000
# New State: Position = 0.4241, Velocity = 0.0579
#
# Episode 9, Action: 1.0000
# New State: Position = 0.4828, Velocity = 0.0587
#
# Episode 10, Action: 0.0159
# New State: Position = -0.4097, Velocity = -0.0008
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4114, Velocity = -0.0017
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4138, Velocity = -0.0025
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4171, Velocity = -0.0033
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4212, Velocity = -0.0041
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4260, Velocity = -0.0048
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4316, Velocity = -0.0056
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4378, Velocity = -0.0062
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4447, Velocity = -0.0069
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4522, Velocity = -0.0075
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4601, Velocity = -0.0080
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4686, Velocity = -0.0085
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4775, Velocity = -0.0089
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4867, Velocity = -0.0092
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4962, Velocity = -0.0095
#
# Episode 10, Action: 0.0000
# New State: Position = -0.5059, Velocity = -0.0097
#
# Episode 10, Action: -0.1406
# New State: Position = -0.5159, Velocity = -0.0100
#
# Episode 10, Action: -0.4688
# New State: Position = -0.5267, Velocity = -0.0108
#
# Episode 10, Action: -0.8984
# New State: Position = -0.5389, Velocity = -0.0121
#
# Episode 10, Action: -1.0000
# New State: Position = -0.5524, Velocity = -0.0135
#
# Episode 10, Action: -1.0000
# New State: Position = -0.5672, Velocity = -0.0148
#
# Episode 10, Action: -1.0000
# New State: Position = -0.5832, Velocity = -0.0160
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6002, Velocity = -0.0170
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6181, Velocity = -0.0180
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6369, Velocity = -0.0188
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6563, Velocity = -0.0194
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6763, Velocity = -0.0200
#
# Episode 10, Action: -1.0000
# New State: Position = -0.6966, Velocity = -0.0204
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7172, Velocity = -0.0206
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7380, Velocity = -0.0207
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7587, Velocity = -0.0207
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7793, Velocity = -0.0206
#
# Episode 10, Action: -1.0000
# New State: Position = -0.7997, Velocity = -0.0204
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8198, Velocity = -0.0200
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8394, Velocity = -0.0196
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8584, Velocity = -0.0191
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8769, Velocity = -0.0185
#
# Episode 10, Action: -1.0000
# New State: Position = -0.8947, Velocity = -0.0178
#
# Episode 10, Action: -0.7266
# New State: Position = -0.9113, Velocity = -0.0166
#
# Episode 10, Action: -0.1562
# New State: Position = -0.9259, Velocity = -0.0146
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9381, Velocity = -0.0122
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9480, Velocity = -0.0099
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9554, Velocity = -0.0075
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9605, Velocity = -0.0051
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9631, Velocity = -0.0027
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9634, Velocity = -0.0002
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9612, Velocity = 0.0022
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9566, Velocity = 0.0046
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9496, Velocity = 0.0070
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9402, Velocity = 0.0094
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9284, Velocity = 0.0118
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9142, Velocity = 0.0141
#
# Episode 10, Action: 0.0000
# New State: Position = -0.8978, Velocity = 0.0164
#
# Episode 10, Action: 0.0000
# New State: Position = -0.8791, Velocity = 0.0187
#
# Episode 10, Action: 0.1032
# New State: Position = -0.8581, Velocity = 0.0210
#
# Episode 10, Action: 0.4207
# New State: Position = -0.8343, Velocity = 0.0238
#
# Episode 10, Action: 0.8492
# New State: Position = -0.8073, Velocity = 0.0270
#
# Episode 10, Action: 0.9920
# New State: Position = -0.7769, Velocity = 0.0304
#
# Episode 10, Action: 1.0000
# New State: Position = -0.7433, Velocity = 0.0336
#
# Episode 10, Action: 1.0000
# New State: Position = -0.7066, Velocity = 0.0367
#
# Episode 10, Action: 1.0000
# New State: Position = -0.6671, Velocity = 0.0395
#
# Episode 10, Action: 1.0000
# New State: Position = -0.6251, Velocity = 0.0420
#
# Episode 10, Action: 1.0000
# New State: Position = -0.5808, Velocity = 0.0443
#
# Episode 10, Action: 1.0000
# New State: Position = -0.5346, Velocity = 0.0462
#
# Episode 10, Action: 1.0000
# New State: Position = -0.4869, Velocity = 0.0478
#
# Episode 10, Action: 1.0000
# New State: Position = -0.4379, Velocity = 0.0490
#
# Episode 10, Action: 1.0000
# New State: Position = -0.3880, Velocity = 0.0499
#
# Episode 10, Action: 1.0000
# New State: Position = -0.3376, Velocity = 0.0504
#
# Episode 10, Action: 1.0000
# New State: Position = -0.2871, Velocity = 0.0506
#
# Episode 10, Action: 1.0000
# New State: Position = -0.2367, Velocity = 0.0504
#
# Episode 10, Action: 1.0000
# New State: Position = -0.1866, Velocity = 0.0500
#
# Episode 10, Action: 1.0000
# New State: Position = -0.1372, Velocity = 0.0494
#
# Episode 10, Action: 1.0000
# New State: Position = -0.0886, Velocity = 0.0486
#
# Episode 10, Action: 1.0000
# New State: Position = -0.0409, Velocity = 0.0477
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0058, Velocity = 0.0467
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0515, Velocity = 0.0457
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0963, Velocity = 0.0448
#
# Episode 10, Action: 1.0000
# New State: Position = 0.1401, Velocity = 0.0439
#
# Episode 10, Action: 1.0000
# New State: Position = 0.1832, Velocity = 0.0431
#
# Episode 10, Action: 1.0000
# New State: Position = 0.2257, Velocity = 0.0424
#
# Episode 10, Action: 1.0000
# New State: Position = 0.2677, Velocity = 0.0420
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3094, Velocity = 0.0418
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3512, Velocity = 0.0418
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3932, Velocity = 0.0420
#
# Episode 10, Action: 1.0000
# New State: Position = 0.4358, Velocity = 0.0426
#
# Episode 10, Action: 1.0000
# New State: Position = 0.4792, Velocity = 0.0434

# %% [markdown]
# Random Inital Position and Speed, Robust for expert policy, 2 failed versions, cannot set initial state to the car and environment

# %% [markdown]
# To deal with this problem, 2 trials are proposed:
#
# ## delete some datas manually -- > failed ?
#
# ## find the set function in gymnasium mountain car continous --> found and success

# %% [markdown]
# this one good random, but not very big difference

# %%
def run_continuous_action_test_with_random_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()

    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 显示倒数和回合开始信息
            print("Episode {} start in: ".format(i+1), end="")
            for countdown in range(2, 0, -1):
                print("{} ".format(countdown), end="", flush=True)
                time.sleep(1)
            print("\nEpisode {} start!".format(i+1))

            # 随机设置小车的初始状态
            initial_position = np.random.uniform(-1.2, 0.6)
            initial_velocity = np.random.uniform(0.07,0.6)
            env.reset()
            # env.env.state = np.array([initial_position, initial_velocity])

            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_random_initial_state(50, render=True)
# Out:
# Initialized Joystick: Logicool Dual Action
# Number of axes: 4
# Episode 1 start in: 2 1
# Episode 1 start!
# Episode 1, Action: 0.0000
# New State: Position = -0.5329, Velocity = 0.0001
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5327, Velocity = 0.0001
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5325, Velocity = 0.0002
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5323, Velocity = 0.0003
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5319, Velocity = 0.0003
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5315, Velocity = 0.0004
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5311, Velocity = 0.0005
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5305, Velocity = 0.0005
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5300, Velocity = 0.0006
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5294, Velocity = 0.0006
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5287, Velocity = 0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5280, Velocity = 0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5273, Velocity = 0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5265, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5257, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5249, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5241, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5233, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5225, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5217, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5209, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5201, Velocity = 0.0008
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5194, Velocity = 0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5187, Velocity = 0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5180, Velocity = 0.0007
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5174, Velocity = 0.0006
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5168, Velocity = 0.0006
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5163, Velocity = 0.0005
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5158, Velocity = 0.0005
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5154, Velocity = 0.0004
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5150, Velocity = 0.0004
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5147, Velocity = 0.0003
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5145, Velocity = 0.0002
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5143, Velocity = 0.0002
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5143, Velocity = 0.0001
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5142, Velocity = 0.0000
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5143, Velocity = -0.0001
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5144, Velocity = -0.0001
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5146, Velocity = -0.0002
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5149, Velocity = -0.0003
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5152, Velocity = -0.0003
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5156, Velocity = -0.0004
#
# Episode 1, Action: 0.0714
# New State: Position = -0.5159, Velocity = -0.0003
#
# Episode 1, Action: 0.4683
# New State: Position = -0.5156, Velocity = 0.0003
#
# Episode 1, Action: 0.8333
# New State: Position = -0.5141, Velocity = 0.0015
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5112, Velocity = 0.0029
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5068, Velocity = 0.0043
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5011, Velocity = 0.0057
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4941, Velocity = 0.0070
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4858, Velocity = 0.0083
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4763, Velocity = 0.0095
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4656, Velocity = 0.0107
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4538, Velocity = 0.0117
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4411, Velocity = 0.0127
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4275, Velocity = 0.0136
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4131, Velocity = 0.0144
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3980, Velocity = 0.0151
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3823, Velocity = 0.0157
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3662, Velocity = 0.0161
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3497, Velocity = 0.0165
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3329, Velocity = 0.0168
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3160, Velocity = 0.0169
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2991, Velocity = 0.0169
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2822, Velocity = 0.0169
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2655, Velocity = 0.0167
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2490, Velocity = 0.0165
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2328, Velocity = 0.0161
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2171, Velocity = 0.0157
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2019, Velocity = 0.0152
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1872, Velocity = 0.0147
#
# Episode 1, Action: 0.8730
# New State: Position = -0.1733, Velocity = 0.0139
#
# Episode 1, Action: 0.6032
# New State: Position = -0.1607, Velocity = 0.0126
#
# Episode 1, Action: 0.3889
# New State: Position = -0.1497, Velocity = 0.0110
#
# Episode 1, Action: 0.3016
# New State: Position = -0.1405, Velocity = 0.0092
#
# Episode 1, Action: 0.0714
# New State: Position = -0.1335, Velocity = 0.0070
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1288, Velocity = 0.0047
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1264, Velocity = 0.0024
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1263, Velocity = 0.0001
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1286, Velocity = -0.0023
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1331, Velocity = -0.0046
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1400, Velocity = -0.0069
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1491, Velocity = -0.0092
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1606, Velocity = -0.0114
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1742, Velocity = -0.0136
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1900, Velocity = -0.0158
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2079, Velocity = -0.0179
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2278, Velocity = -0.0199
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2496, Velocity = -0.0219
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2733, Velocity = -0.0237
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2987, Velocity = -0.0254
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3257, Velocity = -0.0270
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3541, Velocity = -0.0284
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3836, Velocity = -0.0296
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4142, Velocity = -0.0306
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4456, Velocity = -0.0314
#
# Episode 1, Action: 0.0000
# New State: Position = -0.4776, Velocity = -0.0320
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5099, Velocity = -0.0323
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5424, Velocity = -0.0324
#
# Episode 1, Action: 0.0000
# New State: Position = -0.5746, Velocity = -0.0323
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6066, Velocity = -0.0319
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6378, Velocity = -0.0313
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6683, Velocity = -0.0304
#
# Episode 1, Action: 0.0000
# New State: Position = -0.6977, Velocity = -0.0294
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7258, Velocity = -0.0282
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7526, Velocity = -0.0267
#
# Episode 1, Action: 0.0000
# New State: Position = -0.7777, Velocity = -0.0251
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8011, Velocity = -0.0234
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8227, Velocity = -0.0216
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8423, Velocity = -0.0196
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8599, Velocity = -0.0176
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8753, Velocity = -0.0155
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8886, Velocity = -0.0133
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8996, Velocity = -0.0111
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9084, Velocity = -0.0088
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9149, Velocity = -0.0065
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9192, Velocity = -0.0042
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9210, Velocity = -0.0019
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9206, Velocity = 0.0004
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9178, Velocity = 0.0028
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9128, Velocity = 0.0051
#
# Episode 1, Action: 0.0000
# New State: Position = -0.9054, Velocity = 0.0074
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8957, Velocity = 0.0096
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8838, Velocity = 0.0119
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8697, Velocity = 0.0141
#
# Episode 1, Action: 0.0000
# New State: Position = -0.8535, Velocity = 0.0163
#
# Episode 1, Action: 0.2619
# New State: Position = -0.8348, Velocity = 0.0187
#
# Episode 1, Action: 0.6825
# New State: Position = -0.8130, Velocity = 0.0218
#
# Episode 1, Action: 0.9365
# New State: Position = -0.7879, Velocity = 0.0251
#
# Episode 1, Action: 1.0000
# New State: Position = -0.7595, Velocity = 0.0284
#
# Episode 1, Action: 1.0000
# New State: Position = -0.7280, Velocity = 0.0315
#
# Episode 1, Action: 1.0000
# New State: Position = -0.6936, Velocity = 0.0344
#
# Episode 1, Action: 1.0000
# New State: Position = -0.6565, Velocity = 0.0371
#
# Episode 1, Action: 1.0000
# New State: Position = -0.6168, Velocity = 0.0396
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5750, Velocity = 0.0418
#
# Episode 1, Action: 1.0000
# New State: Position = -0.5313, Velocity = 0.0437
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4861, Velocity = 0.0453
#
# Episode 1, Action: 1.0000
# New State: Position = -0.4396, Velocity = 0.0465
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3923, Velocity = 0.0473
#
# Episode 1, Action: 1.0000
# New State: Position = -0.3444, Velocity = 0.0479
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2963, Velocity = 0.0481
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2482, Velocity = 0.0480
#
# Episode 1, Action: 1.0000
# New State: Position = -0.2005, Velocity = 0.0477
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1534, Velocity = 0.0471
#
# Episode 1, Action: 1.0000
# New State: Position = -0.1070, Velocity = 0.0464
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0615, Velocity = 0.0455
#
# Episode 1, Action: 1.0000
# New State: Position = -0.0169, Velocity = 0.0446
#
# Episode 1, Action: 1.0000
# New State: Position = 0.0266, Velocity = 0.0436
#
# Episode 1, Action: 1.0000
# New State: Position = 0.0692, Velocity = 0.0426
#
# Episode 1, Action: 1.0000
# New State: Position = 0.1108, Velocity = 0.0416
#
# Episode 1, Action: 1.0000
# New State: Position = 0.1516, Velocity = 0.0408
#
# Episode 1, Action: 1.0000
# New State: Position = 0.1916, Velocity = 0.0400
#
# Episode 1, Action: 1.0000
# New State: Position = 0.2310, Velocity = 0.0394
#
# Episode 1, Action: 1.0000
# New State: Position = 0.2700, Velocity = 0.0390
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3088, Velocity = 0.0388
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3476, Velocity = 0.0388
#
# Episode 1, Action: 1.0000
# New State: Position = 0.3866, Velocity = 0.0390
#
# Episode 1, Action: 1.0000
# New State: Position = 0.4261, Velocity = 0.0395
#
# Episode 1, Action: 0.9365
# New State: Position = 0.4663, Velocity = 0.0402
#
# Episode 2 start in: 2 1
# Episode 2 start!
# Episode 2, Action: 0.0000
# New State: Position = -0.5275, Velocity = 0.0000
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5275, Velocity = 0.0001
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5274, Velocity = 0.0001
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5273, Velocity = 0.0001
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5271, Velocity = 0.0001
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5270, Velocity = 0.0002
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5268, Velocity = 0.0002
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5265, Velocity = 0.0002
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5263, Velocity = 0.0002
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5260, Velocity = 0.0003
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5258, Velocity = 0.0003
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5255, Velocity = 0.0003
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5252, Velocity = 0.0003
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5248, Velocity = 0.0003
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5245, Velocity = 0.0003
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5242, Velocity = 0.0003
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5238, Velocity = 0.0003
#
# Episode 2, Action: -0.1016
# New State: Position = -0.5236, Velocity = 0.0002
#
# Episode 2, Action: -0.5391
# New State: Position = -0.5242, Velocity = -0.0006
#
# Episode 2, Action: -0.9766
# New State: Position = -0.5263, Velocity = -0.0021
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5299, Velocity = -0.0036
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5349, Velocity = -0.0050
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5413, Velocity = -0.0064
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5491, Velocity = -0.0078
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5582, Velocity = -0.0091
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5685, Velocity = -0.0103
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5800, Velocity = -0.0115
#
# Episode 2, Action: -1.0000
# New State: Position = -0.5926, Velocity = -0.0126
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6062, Velocity = -0.0136
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6207, Velocity = -0.0145
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6359, Velocity = -0.0152
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6518, Velocity = -0.0159
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6683, Velocity = -0.0165
#
# Episode 2, Action: -1.0000
# New State: Position = -0.6852, Velocity = -0.0169
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7025, Velocity = -0.0173
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7199, Velocity = -0.0175
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7375, Velocity = -0.0176
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7551, Velocity = -0.0176
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7726, Velocity = -0.0175
#
# Episode 2, Action: -1.0000
# New State: Position = -0.7899, Velocity = -0.0173
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8069, Velocity = -0.0170
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8236, Velocity = -0.0166
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8397, Velocity = -0.0162
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8554, Velocity = -0.0156
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8704, Velocity = -0.0150
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8848, Velocity = -0.0144
#
# Episode 2, Action: -1.0000
# New State: Position = -0.8985, Velocity = -0.0137
#
# Episode 2, Action: -1.0000
# New State: Position = -0.9114, Velocity = -0.0129
#
# Episode 2, Action: -1.0000
# New State: Position = -0.9235, Velocity = -0.0121
#
# Episode 2, Action: -1.0000
# New State: Position = -0.9348, Velocity = -0.0113
#
# Episode 2, Action: -0.9375
# New State: Position = -0.9451, Velocity = -0.0103
#
# Episode 2, Action: -0.7812
# New State: Position = -0.9543, Velocity = -0.0091
#
# Episode 2, Action: -0.5469
# New State: Position = -0.9618, Velocity = -0.0075
#
# Episode 2, Action: -0.2812
# New State: Position = -0.9674, Velocity = -0.0055
#
# Episode 2, Action: -0.0625
# New State: Position = -0.9706, Velocity = -0.0032
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9713, Velocity = -0.0008
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9697, Velocity = 0.0017
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9656, Velocity = 0.0041
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9591, Velocity = 0.0065
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9502, Velocity = 0.0089
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9388, Velocity = 0.0113
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9252, Velocity = 0.0137
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9091, Velocity = 0.0160
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8908, Velocity = 0.0183
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8703, Velocity = 0.0205
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8476, Velocity = 0.0227
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8228, Velocity = 0.0248
#
# Episode 2, Action: 0.0000
# New State: Position = -0.7961, Velocity = 0.0267
#
# Episode 2, Action: 0.0318
# New State: Position = -0.7675, Velocity = 0.0286
#
# Episode 2, Action: 0.3175
# New State: Position = -0.7368, Velocity = 0.0307
#
# Episode 2, Action: 0.7698
# New State: Position = -0.7034, Velocity = 0.0334
#
# Episode 2, Action: 1.0000
# New State: Position = -0.6672, Velocity = 0.0362
#
# Episode 2, Action: 1.0000
# New State: Position = -0.6285, Velocity = 0.0387
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5875, Velocity = 0.0410
#
# Episode 2, Action: 1.0000
# New State: Position = -0.5445, Velocity = 0.0430
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4999, Velocity = 0.0446
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4540, Velocity = 0.0459
#
# Episode 2, Action: 1.0000
# New State: Position = -0.4071, Velocity = 0.0469
#
# Episode 2, Action: 1.0000
# New State: Position = -0.3595, Velocity = 0.0476
#
# Episode 2, Action: 1.0000
# New State: Position = -0.3116, Velocity = 0.0479
#
# Episode 2, Action: 1.0000
# New State: Position = -0.2637, Velocity = 0.0479
#
# Episode 2, Action: 1.0000
# New State: Position = -0.2161, Velocity = 0.0476
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1689, Velocity = 0.0471
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1225, Velocity = 0.0465
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0768, Velocity = 0.0456
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0321, Velocity = 0.0447
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0116, Velocity = 0.0437
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0543, Velocity = 0.0427
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0960, Velocity = 0.0417
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1369, Velocity = 0.0408
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1769, Velocity = 0.0401
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2163, Velocity = 0.0394
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2552, Velocity = 0.0389
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2938, Velocity = 0.0386
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3323, Velocity = 0.0385
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3710, Velocity = 0.0387
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4100, Velocity = 0.0391
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4498, Velocity = 0.0397
#
# Episode 2, Action: 0.6667
# New State: Position = 0.4899, Velocity = 0.0402
#
# Episode 3 start in: 2 1
# Episode 3 start!
# Episode 3, Action: 0.0000
# New State: Position = -0.5754, Velocity = 0.0004
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5747, Velocity = 0.0008
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5735, Velocity = 0.0012
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5720, Velocity = 0.0015
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5701, Velocity = 0.0019
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5678, Velocity = 0.0022
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5653, Velocity = 0.0026
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5624, Velocity = 0.0029
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5592, Velocity = 0.0032
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5558, Velocity = 0.0034
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5521, Velocity = 0.0037
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5482, Velocity = 0.0039
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5441, Velocity = 0.0041
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5399, Velocity = 0.0042
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5355, Velocity = 0.0044
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5311, Velocity = 0.0044
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5266, Velocity = 0.0045
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5221, Velocity = 0.0045
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5176, Velocity = 0.0045
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5131, Velocity = 0.0045
#
# Episode 3, Action: 0.1111
# New State: Position = -0.5085, Velocity = 0.0046
#
# Episode 3, Action: 0.6746
# New State: Position = -0.5031, Velocity = 0.0055
#
# Episode 3, Action: 0.9682
# New State: Position = -0.4963, Velocity = 0.0068
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4883, Velocity = 0.0080
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4790, Velocity = 0.0093
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4686, Velocity = 0.0104
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4570, Velocity = 0.0115
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4445, Velocity = 0.0125
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4310, Velocity = 0.0135
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4168, Velocity = 0.0143
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4018, Velocity = 0.0150
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3862, Velocity = 0.0156
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3701, Velocity = 0.0161
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3536, Velocity = 0.0165
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3369, Velocity = 0.0168
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3200, Velocity = 0.0169
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3030, Velocity = 0.0170
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2860, Velocity = 0.0170
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2692, Velocity = 0.0168
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2526, Velocity = 0.0166
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2363, Velocity = 0.0163
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2204, Velocity = 0.0159
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2050, Velocity = 0.0154
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1902, Velocity = 0.0149
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1759, Velocity = 0.0143
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1623, Velocity = 0.0136
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1494, Velocity = 0.0129
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1373, Velocity = 0.0121
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1259, Velocity = 0.0113
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1154, Velocity = 0.0105
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1058, Velocity = 0.0097
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0970, Velocity = 0.0088
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0891, Velocity = 0.0079
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0821, Velocity = 0.0070
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0760, Velocity = 0.0061
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0709, Velocity = 0.0051
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0667, Velocity = 0.0042
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0635, Velocity = 0.0032
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0612, Velocity = 0.0023
#
# Episode 3, Action: 0.9206
# New State: Position = -0.0600, Velocity = 0.0012
#
# Episode 3, Action: 0.7301
# New State: Position = -0.0601, Velocity = -0.0002
#
# Episode 3, Action: 0.4683
# New State: Position = -0.0621, Velocity = -0.0019
#
# Episode 3, Action: 0.1826
# New State: Position = -0.0662, Velocity = -0.0041
#
# Episode 3, Action: 0.0000
# New State: Position = -0.0727, Velocity = -0.0066
#
# Episode 3, Action: 0.0000
# New State: Position = -0.0817, Velocity = -0.0090
#
# Episode 3, Action: 0.0000
# New State: Position = -0.0931, Velocity = -0.0114
#
# Episode 3, Action: 0.0000
# New State: Position = -0.1069, Velocity = -0.0138
#
# Episode 3, Action: 0.0000
# New State: Position = -0.1231, Velocity = -0.0162
#
# Episode 3, Action: 0.0000
# New State: Position = -0.1417, Velocity = -0.0185
#
# Episode 3, Action: 0.0000
# New State: Position = -0.1625, Velocity = -0.0208
#
# Episode 3, Action: 0.0000
# New State: Position = -0.1855, Velocity = -0.0230
#
# Episode 3, Action: 0.0000
# New State: Position = -0.2106, Velocity = -0.0251
#
# Episode 3, Action: 0.0000
# New State: Position = -0.2378, Velocity = -0.0272
#
# Episode 3, Action: 0.0000
# New State: Position = -0.2668, Velocity = -0.0290
#
# Episode 3, Action: 0.0000
# New State: Position = -0.2976, Velocity = -0.0308
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3299, Velocity = -0.0324
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3637, Velocity = -0.0337
#
# Episode 3, Action: 0.0000
# New State: Position = -0.3985, Velocity = -0.0349
#
# Episode 3, Action: 0.0000
# New State: Position = -0.4343, Velocity = -0.0358
#
# Episode 3, Action: 0.0000
# New State: Position = -0.4708, Velocity = -0.0365
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5076, Velocity = -0.0368
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5446, Velocity = -0.0370
#
# Episode 3, Action: 0.0000
# New State: Position = -0.5814, Velocity = -0.0368
#
# Episode 3, Action: 0.0000
# New State: Position = -0.6178, Velocity = -0.0364
#
# Episode 3, Action: 0.0000
# New State: Position = -0.6535, Velocity = -0.0357
#
# Episode 3, Action: 0.0000
# New State: Position = -0.6882, Velocity = -0.0347
#
# Episode 3, Action: 0.0000
# New State: Position = -0.7218, Velocity = -0.0335
#
# Episode 3, Action: 0.0000
# New State: Position = -0.7539, Velocity = -0.0321
#
# Episode 3, Action: -0.0078
# New State: Position = -0.7845, Velocity = -0.0306
#
# Episode 3, Action: -0.1172
# New State: Position = -0.8135, Velocity = -0.0290
#
# Episode 3, Action: -0.3281
# New State: Position = -0.8410, Velocity = -0.0276
#
# Episode 3, Action: -0.4062
# New State: Position = -0.8672, Velocity = -0.0261
#
# Episode 3, Action: -0.4219
# New State: Position = -0.8918, Velocity = -0.0246
#
# Episode 3, Action: -0.3594
# New State: Position = -0.9147, Velocity = -0.0229
#
# Episode 3, Action: -0.2266
# New State: Position = -0.9357, Velocity = -0.0210
#
# Episode 3, Action: -0.1172
# New State: Position = -0.9545, Velocity = -0.0188
#
# Episode 3, Action: -0.1094
# New State: Position = -0.9710, Velocity = -0.0165
#
# Episode 3, Action: -0.1094
# New State: Position = -0.9853, Velocity = -0.0143
#
# Episode 3, Action: -0.1094
# New State: Position = -0.9972, Velocity = -0.0120
#
# Episode 3, Action: -0.0469
# New State: Position = -1.0068, Velocity = -0.0096
#
# Episode 3, Action: -0.0078
# New State: Position = -1.0139, Velocity = -0.0071
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0185, Velocity = -0.0046
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0206, Velocity = -0.0021
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0203, Velocity = 0.0004
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0174, Velocity = 0.0029
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0121, Velocity = 0.0054
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0042, Velocity = 0.0078
#
# Episode 3, Action: 0.0953
# New State: Position = -0.9938, Velocity = 0.0105
#
# Episode 3, Action: 0.4286
# New State: Position = -0.9802, Velocity = 0.0136
#
# Episode 3, Action: 0.8254
# New State: Position = -0.9629, Velocity = 0.0173
#
# Episode 3, Action: 1.0000
# New State: Position = -0.9418, Velocity = 0.0212
#
# Episode 3, Action: 1.0000
# New State: Position = -0.9167, Velocity = 0.0251
#
# Episode 3, Action: 1.0000
# New State: Position = -0.8879, Velocity = 0.0289
#
# Episode 3, Action: 1.0000
# New State: Position = -0.8553, Velocity = 0.0326
#
# Episode 3, Action: 1.0000
# New State: Position = -0.8191, Velocity = 0.0362
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7795, Velocity = 0.0396
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7366, Velocity = 0.0429
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6908, Velocity = 0.0458
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6422, Velocity = 0.0485
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5913, Velocity = 0.0509
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5384, Velocity = 0.0529
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4839, Velocity = 0.0545
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4281, Velocity = 0.0557
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3716, Velocity = 0.0565
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3147, Velocity = 0.0569
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2577, Velocity = 0.0570
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2010, Velocity = 0.0567
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1449, Velocity = 0.0561
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0896, Velocity = 0.0553
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0351, Velocity = 0.0544
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0183, Velocity = 0.0534
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0708, Velocity = 0.0525
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1223, Velocity = 0.0515
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1730, Velocity = 0.0507
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2230, Velocity = 0.0500
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2725, Velocity = 0.0495
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3218, Velocity = 0.0493
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3712, Velocity = 0.0494
#
# Episode 3, Action: 1.0000
# New State: Position = 0.4210, Velocity = 0.0498
#
# Episode 3, Action: 0.8492
# New State: Position = 0.4714, Velocity = 0.0503
#
# Episode 4 start in: 2 1
# Episode 4 start!
# Episode 4, Action: 0.0000
# New State: Position = -0.5770, Velocity = 0.0004
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5762, Velocity = 0.0008
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5751, Velocity = 0.0012
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5735, Velocity = 0.0016
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5715, Velocity = 0.0020
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5692, Velocity = 0.0023
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5666, Velocity = 0.0027
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5636, Velocity = 0.0030
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5603, Velocity = 0.0033
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5568, Velocity = 0.0035
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5530, Velocity = 0.0038
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5490, Velocity = 0.0040
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5448, Velocity = 0.0042
#
# Episode 4, Action: -0.0078
# New State: Position = -0.5404, Velocity = 0.0044
#
# Episode 4, Action: -0.0703
# New State: Position = -0.5360, Velocity = 0.0044
#
# Episode 4, Action: -0.1875
# New State: Position = -0.5319, Velocity = 0.0042
#
# Episode 4, Action: -0.3438
# New State: Position = -0.5281, Velocity = 0.0037
#
# Episode 4, Action: -0.4844
# New State: Position = -0.5251, Velocity = 0.0030
#
# Episode 4, Action: -0.5312
# New State: Position = -0.5228, Velocity = 0.0023
#
# Episode 4, Action: -0.5312
# New State: Position = -0.5214, Velocity = 0.0014
#
# Episode 4, Action: -0.2969
# New State: Position = -0.5204, Velocity = 0.0010
#
# Episode 4, Action: -0.0312
# New State: Position = -0.5195, Velocity = 0.0009
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5186, Velocity = 0.0009
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5177, Velocity = 0.0008
#
# Episode 4, Action: 0.0635
# New State: Position = -0.5168, Velocity = 0.0009
#
# Episode 4, Action: 0.3889
# New State: Position = -0.5154, Velocity = 0.0014
#
# Episode 4, Action: 0.8254
# New State: Position = -0.5128, Velocity = 0.0026
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5088, Velocity = 0.0040
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5034, Velocity = 0.0054
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4966, Velocity = 0.0068
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4885, Velocity = 0.0081
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4792, Velocity = 0.0093
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4688, Velocity = 0.0105
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4572, Velocity = 0.0116
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4446, Velocity = 0.0126
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4312, Velocity = 0.0135
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4169, Velocity = 0.0143
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4019, Velocity = 0.0150
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3863, Velocity = 0.0156
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3701, Velocity = 0.0161
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3536, Velocity = 0.0165
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3369, Velocity = 0.0168
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3199, Velocity = 0.0170
#
# Episode 4, Action: 0.7063
# New State: Position = -0.3033, Velocity = 0.0166
#
# Episode 4, Action: 0.2143
# New State: Position = -0.2880, Velocity = 0.0154
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2742, Velocity = 0.0137
#
# Episode 4, Action: -0.0156
# New State: Position = -0.2622, Velocity = 0.0120
#
# Episode 4, Action: -0.1484
# New State: Position = -0.2522, Velocity = 0.0100
#
# Episode 4, Action: -0.2812
# New State: Position = -0.2444, Velocity = 0.0078
#
# Episode 4, Action: -0.5078
# New State: Position = -0.2392, Velocity = 0.0052
#
# Episode 4, Action: -0.7891
# New State: Position = -0.2371, Velocity = 0.0021
#
# Episode 4, Action: -0.9688
# New State: Position = -0.2384, Velocity = -0.0012
#
# Episode 4, Action: -1.0000
# New State: Position = -0.2430, Velocity = -0.0046
#
# Episode 4, Action: -1.0000
# New State: Position = -0.2510, Velocity = -0.0080
#
# Episode 4, Action: -1.0000
# New State: Position = -0.2623, Velocity = -0.0113
#
# Episode 4, Action: -1.0000
# New State: Position = -0.2769, Velocity = -0.0146
#
# Episode 4, Action: -1.0000
# New State: Position = -0.2947, Velocity = -0.0178
#
# Episode 4, Action: -1.0000
# New State: Position = -0.3155, Velocity = -0.0209
#
# Episode 4, Action: -1.0000
# New State: Position = -0.3393, Velocity = -0.0238
#
# Episode 4, Action: -1.0000
# New State: Position = -0.3660, Velocity = -0.0266
#
# Episode 4, Action: -1.0000
# New State: Position = -0.3952, Velocity = -0.0293
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4270, Velocity = -0.0317
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4609, Velocity = -0.0339
#
# Episode 4, Action: -1.0000
# New State: Position = -0.4968, Velocity = -0.0359
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5344, Velocity = -0.0376
#
# Episode 4, Action: -1.0000
# New State: Position = -0.5734, Velocity = -0.0390
#
# Episode 4, Action: -1.0000
# New State: Position = -0.6135, Velocity = -0.0401
#
# Episode 4, Action: -0.4922
# New State: Position = -0.6537, Velocity = -0.0402
#
# Episode 4, Action: -0.0859
# New State: Position = -0.6931, Velocity = -0.0394
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7313, Velocity = -0.0382
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7680, Velocity = -0.0367
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8030, Velocity = -0.0350
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8362, Velocity = -0.0332
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8674, Velocity = -0.0312
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8964, Velocity = -0.0290
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9232, Velocity = -0.0268
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9476, Velocity = -0.0244
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9697, Velocity = -0.0221
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9893, Velocity = -0.0196
#
# Episode 4, Action: 0.2222
# New State: Position = -1.0061, Velocity = -0.0168
#
# Episode 4, Action: 0.5397
# New State: Position = -1.0196, Velocity = -0.0135
#
# Episode 4, Action: 0.8651
# New State: Position = -1.0294, Velocity = -0.0097
#
# Episode 4, Action: 0.9841
# New State: Position = -1.0352, Velocity = -0.0058
#
# Episode 4, Action: 1.0000
# New State: Position = -1.0369, Velocity = -0.0018
#
# Episode 4, Action: 1.0000
# New State: Position = -1.0347, Velocity = 0.0022
#
# Episode 4, Action: 1.0000
# New State: Position = -1.0285, Velocity = 0.0062
#
# Episode 4, Action: 1.0000
# New State: Position = -1.0183, Velocity = 0.0102
#
# Episode 4, Action: 1.0000
# New State: Position = -1.0041, Velocity = 0.0142
#
# Episode 4, Action: 1.0000
# New State: Position = -0.9859, Velocity = 0.0182
#
# Episode 4, Action: 1.0000
# New State: Position = -0.9637, Velocity = 0.0221
#
# Episode 4, Action: 1.0000
# New State: Position = -0.9377, Velocity = 0.0261
#
# Episode 4, Action: 1.0000
# New State: Position = -0.9077, Velocity = 0.0299
#
# Episode 4, Action: 1.0000
# New State: Position = -0.8740, Velocity = 0.0337
#
# Episode 4, Action: 1.0000
# New State: Position = -0.8366, Velocity = 0.0374
#
# Episode 4, Action: 1.0000
# New State: Position = -0.7957, Velocity = 0.0409
#
# Episode 4, Action: 1.0000
# New State: Position = -0.7515, Velocity = 0.0442
#
# Episode 4, Action: 1.0000
# New State: Position = -0.7042, Velocity = 0.0473
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6541, Velocity = 0.0501
#
# Episode 4, Action: 1.0000
# New State: Position = -0.6015, Velocity = 0.0525
#
# Episode 4, Action: 1.0000
# New State: Position = -0.5469, Velocity = 0.0546
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4906, Velocity = 0.0563
#
# Episode 4, Action: 1.0000
# New State: Position = -0.4331, Velocity = 0.0576
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3747, Velocity = 0.0584
#
# Episode 4, Action: 1.0000
# New State: Position = -0.3159, Velocity = 0.0588
#
# Episode 4, Action: 1.0000
# New State: Position = -0.2570, Velocity = 0.0588
#
# Episode 4, Action: 1.0000
# New State: Position = -0.1985, Velocity = 0.0586
#
# Episode 4, Action: 1.0000
# New State: Position = -0.1405, Velocity = 0.0580
#
# Episode 4, Action: 1.0000
# New State: Position = -0.0833, Velocity = 0.0572
#
# Episode 4, Action: 1.0000
# New State: Position = -0.0270, Velocity = 0.0563
#
# Episode 4, Action: 1.0000
# New State: Position = 0.0283, Velocity = 0.0553
#
# Episode 4, Action: 1.0000
# New State: Position = 0.0826, Velocity = 0.0543
#
# Episode 4, Action: 1.0000
# New State: Position = 0.1360, Velocity = 0.0534
#
# Episode 4, Action: 1.0000
# New State: Position = 0.1885, Velocity = 0.0526
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2405, Velocity = 0.0520
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2921, Velocity = 0.0516
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3436, Velocity = 0.0515
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3953, Velocity = 0.0517
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4476, Velocity = 0.0523
#
# Episode 4, Action: 1.0000
# New State: Position = 0.5008, Velocity = 0.0532
#
# Episode 5 start in: 2 1
# Episode 5 start!
# Episode 5, Action: 0.0000
# New State: Position = -0.5197, Velocity = -0.0000
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5197, Velocity = -0.0001
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5198, Velocity = -0.0001
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5199, Velocity = -0.0001
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5201, Velocity = -0.0001
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5203, Velocity = -0.0002
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5204, Velocity = -0.0002
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5207, Velocity = -0.0002
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5209, Velocity = -0.0002
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5212, Velocity = -0.0003
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5214, Velocity = -0.0003
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5217, Velocity = -0.0003
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5221, Velocity = -0.0003
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5224, Velocity = -0.0003
#
# Episode 5, Action: -0.0781
# New State: Position = -0.5228, Velocity = -0.0004
#
# Episode 5, Action: -0.4062
# New State: Position = -0.5239, Velocity = -0.0011
#
# Episode 5, Action: -0.6797
# New State: Position = -0.5260, Velocity = -0.0021
#
# Episode 5, Action: -0.8984
# New State: Position = -0.5294, Velocity = -0.0034
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5342, Velocity = -0.0049
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5405, Velocity = -0.0063
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5482, Velocity = -0.0077
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5572, Velocity = -0.0090
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5674, Velocity = -0.0102
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5788, Velocity = -0.0114
#
# Episode 5, Action: -1.0000
# New State: Position = -0.5913, Velocity = -0.0125
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6047, Velocity = -0.0135
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6191, Velocity = -0.0144
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6343, Velocity = -0.0152
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6502, Velocity = -0.0159
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6666, Velocity = -0.0164
#
# Episode 5, Action: -1.0000
# New State: Position = -0.6835, Velocity = -0.0169
#
# Episode 5, Action: -1.0000
# New State: Position = -0.7007, Velocity = -0.0172
#
# Episode 5, Action: -1.0000
# New State: Position = -0.7182, Velocity = -0.0175
#
# Episode 5, Action: -1.0000
# New State: Position = -0.7358, Velocity = -0.0176
#
# Episode 5, Action: -1.0000
# New State: Position = -0.7534, Velocity = -0.0176
#
# Episode 5, Action: -1.0000
# New State: Position = -0.7709, Velocity = -0.0175
#
# Episode 5, Action: -1.0000
# New State: Position = -0.7882, Velocity = -0.0173
#
# Episode 5, Action: -1.0000
# New State: Position = -0.8053, Velocity = -0.0170
#
# Episode 5, Action: -1.0000
# New State: Position = -0.8219, Velocity = -0.0167
#
# Episode 5, Action: -1.0000
# New State: Position = -0.8382, Velocity = -0.0162
#
# Episode 5, Action: -1.0000
# New State: Position = -0.8539, Velocity = -0.0157
#
# Episode 5, Action: -1.0000
# New State: Position = -0.8690, Velocity = -0.0151
#
# Episode 5, Action: -1.0000
# New State: Position = -0.8834, Velocity = -0.0145
#
# Episode 5, Action: -1.0000
# New State: Position = -0.8972, Velocity = -0.0138
#
# Episode 5, Action: -0.5781
# New State: Position = -0.9095, Velocity = -0.0124
#
# Episode 5, Action: -0.0938
# New State: Position = -0.9198, Velocity = -0.0102
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9277, Velocity = -0.0079
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9332, Velocity = -0.0056
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9364, Velocity = -0.0032
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9373, Velocity = -0.0008
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9357, Velocity = 0.0015
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9319, Velocity = 0.0039
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9256, Velocity = 0.0062
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9170, Velocity = 0.0086
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9062, Velocity = 0.0109
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8930, Velocity = 0.0132
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8776, Velocity = 0.0154
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8600, Velocity = 0.0176
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8403, Velocity = 0.0197
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8186, Velocity = 0.0217
#
# Episode 5, Action: 0.0000
# New State: Position = -0.7949, Velocity = 0.0237
#
# Episode 5, Action: 0.1270
# New State: Position = -0.7692, Velocity = 0.0257
#
# Episode 5, Action: 0.5317
# New State: Position = -0.7411, Velocity = 0.0282
#
# Episode 5, Action: 0.9444
# New State: Position = -0.7100, Velocity = 0.0311
#
# Episode 5, Action: 1.0000
# New State: Position = -0.6761, Velocity = 0.0339
#
# Episode 5, Action: 1.0000
# New State: Position = -0.6395, Velocity = 0.0365
#
# Episode 5, Action: 1.0000
# New State: Position = -0.6007, Velocity = 0.0389
#
# Episode 5, Action: 1.0000
# New State: Position = -0.5597, Velocity = 0.0409
#
# Episode 5, Action: 1.0000
# New State: Position = -0.5170, Velocity = 0.0427
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4728, Velocity = 0.0442
#
# Episode 5, Action: 1.0000
# New State: Position = -0.4276, Velocity = 0.0453
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3815, Velocity = 0.0461
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3349, Velocity = 0.0465
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2882, Velocity = 0.0467
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2417, Velocity = 0.0466
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1954, Velocity = 0.0462
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1498, Velocity = 0.0456
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1049, Velocity = 0.0449
#
# Episode 5, Action: 1.0000
# New State: Position = -0.0610, Velocity = 0.0440
#
# Episode 5, Action: 1.0000
# New State: Position = -0.0179, Velocity = 0.0430
#
# Episode 5, Action: 1.0000
# New State: Position = 0.0241, Velocity = 0.0420
#
# Episode 5, Action: 1.0000
# New State: Position = 0.0652, Velocity = 0.0410
#
# Episode 5, Action: 1.0000
# New State: Position = 0.1053, Velocity = 0.0401
#
# Episode 5, Action: 0.5555
# New State: Position = 0.1438, Velocity = 0.0386
#
# Episode 5, Action: 0.0635
# New State: Position = 0.1802, Velocity = 0.0364
#
# Episode 5, Action: 0.0000
# New State: Position = 0.2144, Velocity = 0.0342
#
# Episode 5, Action: 0.0000
# New State: Position = 0.2467, Velocity = 0.0322
#
# Episode 5, Action: 0.0000
# New State: Position = 0.2771, Velocity = 0.0304
#
# Episode 5, Action: 0.0000
# New State: Position = 0.3058, Velocity = 0.0287
#
# Episode 5, Action: 0.0000
# New State: Position = 0.3329, Velocity = 0.0272
#
# Episode 5, Action: 0.0000
# New State: Position = 0.3588, Velocity = 0.0258
#
# Episode 5, Action: 0.0000
# New State: Position = 0.3834, Velocity = 0.0246
#
# Episode 5, Action: 0.0000
# New State: Position = 0.4070, Velocity = 0.0236
#
# Episode 5, Action: 0.0000
# New State: Position = 0.4298, Velocity = 0.0228
#
# Episode 5, Action: 0.0000
# New State: Position = 0.4519, Velocity = 0.0221
#
# Episode 6 start in: 2 1
# Episode 6 start!
# Episode 6, Action: 0.0000
# New State: Position = -0.5425, Velocity = 0.0001
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5422, Velocity = 0.0003
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5418, Velocity = 0.0004
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5412, Velocity = 0.0006
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5406, Velocity = 0.0007
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5397, Velocity = 0.0008
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5388, Velocity = 0.0009
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5377, Velocity = 0.0011
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5366, Velocity = 0.0012
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5353, Velocity = 0.0013
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5340, Velocity = 0.0013
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5325, Velocity = 0.0014
#
# Episode 6, Action: 0.0000
# ...
#
# Episode 48, Action: 0.8730
# New State: Position = -0.0387, Velocity = 0.0395
#
# Episode 48, Action: 0.8730
# New State: Position = -0.0003, Velocity = 0.0383
#
# Episode 48, Action: 0.8730
# New State: Position = 0.0368, Velocity = 0.0371
#
# Episode 48, Action: 0.8730
# New State: Position = 0.0728, Velocity = 0.0360
#
# Episode 48, Action: 0.8730
# New State: Position = 0.1077, Velocity = 0.0348
#
# Episode 48, Action: 0.8730
# New State: Position = 0.1414, Velocity = 0.0338
#
# Episode 48, Action: 0.8730
# New State: Position = 0.1742, Velocity = 0.0328
#
# Episode 48, Action: 0.8730
# New State: Position = 0.2062, Velocity = 0.0320
#
# Episode 48, Action: 0.8730
# New State: Position = 0.2374, Velocity = 0.0312
#
# Episode 48, Action: 0.8730
# New State: Position = 0.2681, Velocity = 0.0306
#
# Episode 48, Action: 0.8730
# New State: Position = 0.2983, Velocity = 0.0302
#
# Episode 48, Action: 0.8730
# New State: Position = 0.3283, Velocity = 0.0300
#
# Episode 48, Action: 0.8730
# New State: Position = 0.3582, Velocity = 0.0299
#
# Episode 48, Action: 0.8730
# New State: Position = 0.3882, Velocity = 0.0300
#
# Episode 48, Action: 0.8730
# New State: Position = 0.4185, Velocity = 0.0303
#
# Episode 48, Action: 0.8730
# New State: Position = 0.4494, Velocity = 0.0309
#
# Episode 48, Action: 0.8730
# New State: Position = 0.4810, Velocity = 0.0316
#
# Episode 49 start in: 2 1
# Episode 49 start!
# Episode 49, Action: 0.0000
# New State: Position = -0.5605, Velocity = 0.0003
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5600, Velocity = 0.0006
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5591, Velocity = 0.0008
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5580, Velocity = 0.0011
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5567, Velocity = 0.0014
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5551, Velocity = 0.0016
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5533, Velocity = 0.0018
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5512, Velocity = 0.0021
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5489, Velocity = 0.0023
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5465, Velocity = 0.0025
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5439, Velocity = 0.0026
#
# Episode 49, Action: 0.0000
# New State: Position = -0.5411, Velocity = 0.0028
#
# Episode 49, Action: -0.0469
# New State: Position = -0.5382, Velocity = 0.0028
#
# Episode 49, Action: -0.2734
# New State: Position = -0.5357, Velocity = 0.0025
#
# Episode 49, Action: -0.5391
# New State: Position = -0.5339, Velocity = 0.0018
#
# Episode 49, Action: -0.8203
# New State: Position = -0.5332, Velocity = 0.0007
#
# Episode 49, Action: -0.9453
# New State: Position = -0.5339, Velocity = -0.0007
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5360, Velocity = -0.0021
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5395, Velocity = -0.0035
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5444, Velocity = -0.0049
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5506, Velocity = -0.0062
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5582, Velocity = -0.0075
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5669, Velocity = -0.0088
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5769, Velocity = -0.0099
#
# Episode 49, Action: -1.0000
# New State: Position = -0.5879, Velocity = -0.0111
#
# Episode 49, Action: -1.0000
# New State: Position = -0.6000, Velocity = -0.0121
#
# Episode 49, Action: -1.0000
# New State: Position = -0.6130, Velocity = -0.0130
#
# Episode 49, Action: -1.0000
# New State: Position = -0.6269, Velocity = -0.0138
#
# Episode 49, Action: -1.0000
# New State: Position = -0.6414, Velocity = -0.0146
#
# Episode 49, Action: -1.0000
# New State: Position = -0.6567, Velocity = -0.0152
#
# Episode 49, Action: -1.0000
# New State: Position = -0.6724, Velocity = -0.0157
#
# Episode 49, Action: -1.0000
# New State: Position = -0.6886, Velocity = -0.0162
#
# Episode 49, Action: -1.0000
# New State: Position = -0.7050, Velocity = -0.0165
#
# Episode 49, Action: -1.0000
# New State: Position = -0.7217, Velocity = -0.0167
#
# Episode 49, Action: -1.0000
# New State: Position = -0.7385, Velocity = -0.0168
#
# Episode 49, Action: -1.0000
# New State: Position = -0.7553, Velocity = -0.0168
#
# Episode 49, Action: -1.0000
# New State: Position = -0.7719, Velocity = -0.0167
#
# Episode 49, Action: -1.0000
# New State: Position = -0.7884, Velocity = -0.0165
#
# Episode 49, Action: -1.0000
# New State: Position = -0.8046, Velocity = -0.0162
#
# Episode 49, Action: -1.0000
# New State: Position = -0.8205, Velocity = -0.0158
#
# Episode 49, Action: -1.0000
# New State: Position = -0.8358, Velocity = -0.0154
#
# Episode 49, Action: -1.0000
# New State: Position = -0.8507, Velocity = -0.0149
#
# Episode 49, Action: -1.0000
# New State: Position = -0.8650, Velocity = -0.0143
#
# Episode 49, Action: -1.0000
# New State: Position = -0.8787, Velocity = -0.0137
#
# Episode 49, Action: -1.0000
# New State: Position = -0.8916, Velocity = -0.0130
#
# Episode 49, Action: -1.0000
# New State: Position = -0.9039, Velocity = -0.0122
#
# Episode 49, Action: -1.0000
# New State: Position = -0.9154, Velocity = -0.0115
#
# Episode 49, Action: -1.0000
# New State: Position = -0.9260, Velocity = -0.0107
#
# Episode 49, Action: -0.7969
# New State: Position = -0.9355, Velocity = -0.0095
#
# Episode 49, Action: -0.3281
# New State: Position = -0.9432, Velocity = -0.0077
#
# Episode 49, Action: -0.0547
# New State: Position = -0.9485, Velocity = -0.0054
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9515, Velocity = -0.0030
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9521, Velocity = -0.0006
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9502, Velocity = 0.0018
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9460, Velocity = 0.0042
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9394, Velocity = 0.0066
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9304, Velocity = 0.0090
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9191, Velocity = 0.0113
#
# Episode 49, Action: 0.0000
# New State: Position = -0.9054, Velocity = 0.0137
#
# Episode 49, Action: 0.0000
# New State: Position = -0.8895, Velocity = 0.0159
#
# Episode 49, Action: 0.0000
# New State: Position = -0.8713, Velocity = 0.0182
#
# Episode 49, Action: 0.0000
# New State: Position = -0.8510, Velocity = 0.0203
#
# Episode 49, Action: 0.0000
# New State: Position = -0.8286, Velocity = 0.0224
#
# Episode 49, Action: 0.0000
# New State: Position = -0.8042, Velocity = 0.0244
#
# Episode 49, Action: 0.0000
# New State: Position = -0.7780, Velocity = 0.0262
#
# Episode 49, Action: 0.0000
# New State: Position = -0.7500, Velocity = 0.0280
#
# Episode 49, Action: 0.0318
# New State: Position = -0.7205, Velocity = 0.0296
#
# Episode 49, Action: 0.2699
# New State: Position = -0.6891, Velocity = 0.0314
#
# Episode 49, Action: 0.5000
# New State: Position = -0.6557, Velocity = 0.0333
#
# Episode 49, Action: 0.6984
# New State: Position = -0.6204, Velocity = 0.0353
#
# Episode 49, Action: 0.8016
# New State: Position = -0.5832, Velocity = 0.0373
#
# Episode 49, Action: 0.8968
# New State: Position = -0.5441, Velocity = 0.0390
#
# Episode 49, Action: 0.9762
# New State: Position = -0.5034, Velocity = 0.0407
#
# Episode 49, Action: 0.9920
# New State: Position = -0.4614, Velocity = 0.0420
#
# Episode 49, Action: 1.0000
# New State: Position = -0.4184, Velocity = 0.0430
#
# Episode 49, Action: 1.0000
# New State: Position = -0.3747, Velocity = 0.0438
#
# Episode 49, Action: 1.0000
# New State: Position = -0.3305, Velocity = 0.0442
#
# Episode 49, Action: 1.0000
# New State: Position = -0.2862, Velocity = 0.0443
#
# Episode 49, Action: 1.0000
# New State: Position = -0.2420, Velocity = 0.0442
#
# Episode 49, Action: 1.0000
# New State: Position = -0.1982, Velocity = 0.0438
#
# Episode 49, Action: 1.0000
# New State: Position = -0.1549, Velocity = 0.0432
#
# Episode 49, Action: 1.0000
# New State: Position = -0.1124, Velocity = 0.0425
#
# Episode 49, Action: 1.0000
# New State: Position = -0.0708, Velocity = 0.0416
#
# Episode 49, Action: 1.0000
# New State: Position = -0.0301, Velocity = 0.0407
#
# Episode 49, Action: 1.0000
# New State: Position = 0.0096, Velocity = 0.0397
#
# Episode 49, Action: 1.0000
# New State: Position = 0.0483, Velocity = 0.0387
#
# Episode 49, Action: 1.0000
# New State: Position = 0.0861, Velocity = 0.0377
#
# Episode 49, Action: 1.0000
# New State: Position = 0.1229, Velocity = 0.0368
#
# Episode 49, Action: 1.0000
# New State: Position = 0.1589, Velocity = 0.0360
#
# Episode 49, Action: 0.8571
# New State: Position = 0.1939, Velocity = 0.0351
#
# Episode 49, Action: 0.6984
# New State: Position = 0.2279, Velocity = 0.0340
#
# Episode 49, Action: 0.6667
# New State: Position = 0.2610, Velocity = 0.0331
#
# Episode 49, Action: 0.6587
# New State: Position = 0.2933, Velocity = 0.0323
#
# Episode 49, Action: 0.6587
# New State: Position = 0.3250, Velocity = 0.0317
#
# Episode 49, Action: 0.6508
# New State: Position = 0.3562, Velocity = 0.0313
#
# Episode 49, Action: 0.6508
# New State: Position = 0.3872, Velocity = 0.0310
#
# Episode 49, Action: 0.6190
# New State: Position = 0.4182, Velocity = 0.0310
#
# Episode 49, Action: 0.5317
# New State: Position = 0.4492, Velocity = 0.0310
#
# Episode 49, Action: 0.1826
# New State: Position = 0.4799, Velocity = 0.0307
#
# Episode 50 start in: 2 1
# Episode 50 start!
# Episode 50, Action: 0.0000
# New State: Position = -0.4194, Velocity = -0.0008
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4210, Velocity = -0.0015
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4233, Velocity = -0.0023
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4263, Velocity = -0.0030
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4301, Velocity = -0.0038
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4345, Velocity = -0.0045
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4396, Velocity = -0.0051
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4454, Velocity = -0.0057
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4517, Velocity = -0.0063
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4585, Velocity = -0.0069
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4659, Velocity = -0.0073
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4736, Velocity = -0.0078
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4818, Velocity = -0.0081
#
# Episode 50, Action: 0.0000
# New State: Position = -0.4902, Velocity = -0.0085
#
# Episode 50, Action: -0.0469
# New State: Position = -0.4990, Velocity = -0.0088
#
# Episode 50, Action: -0.3281
# New State: Position = -0.5085, Velocity = -0.0095
#
# Episode 50, Action: -0.6172
# New State: Position = -0.5190, Velocity = -0.0105
#
# Episode 50, Action: -0.8828
# New State: Position = -0.5308, Velocity = -0.0118
#
# Episode 50, Action: -0.9844
# New State: Position = -0.5441, Velocity = -0.0133
#
# Episode 50, Action: -1.0000
# New State: Position = -0.5587, Velocity = -0.0146
#
# Episode 50, Action: -1.0000
# New State: Position = -0.5746, Velocity = -0.0159
#
# Episode 50, Action: -1.0000
# New State: Position = -0.5915, Velocity = -0.0170
#
# Episode 50, Action: -1.0000
# New State: Position = -0.6095, Velocity = -0.0180
#
# Episode 50, Action: -1.0000
# New State: Position = -0.6283, Velocity = -0.0188
#
# Episode 50, Action: -1.0000
# New State: Position = -0.6479, Velocity = -0.0196
#
# Episode 50, Action: -1.0000
# New State: Position = -0.6680, Velocity = -0.0201
#
# Episode 50, Action: -1.0000
# New State: Position = -0.6886, Velocity = -0.0206
#
# Episode 50, Action: -1.0000
# New State: Position = -0.7096, Velocity = -0.0209
#
# Episode 50, Action: -1.0000
# New State: Position = -0.7306, Velocity = -0.0211
#
# Episode 50, Action: -1.0000
# New State: Position = -0.7518, Velocity = -0.0211
#
# Episode 50, Action: -1.0000
# New State: Position = -0.7728, Velocity = -0.0211
#
# Episode 50, Action: -1.0000
# New State: Position = -0.7937, Velocity = -0.0209
#
# Episode 50, Action: -1.0000
# New State: Position = -0.8142, Velocity = -0.0205
#
# Episode 50, Action: -1.0000
# New State: Position = -0.8343, Velocity = -0.0201
#
# Episode 50, Action: -1.0000
# New State: Position = -0.8540, Velocity = -0.0196
#
# Episode 50, Action: -0.9062
# New State: Position = -0.8729, Velocity = -0.0189
#
# Episode 50, Action: -0.5781
# New State: Position = -0.8904, Velocity = -0.0176
#
# Episode 50, Action: -0.1016
# New State: Position = -0.9060, Velocity = -0.0155
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9192, Velocity = -0.0132
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9301, Velocity = -0.0109
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9387, Velocity = -0.0086
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9449, Velocity = -0.0062
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9487, Velocity = -0.0038
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9501, Velocity = -0.0014
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9491, Velocity = 0.0010
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9458, Velocity = 0.0034
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9400, Velocity = 0.0057
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9319, Velocity = 0.0081
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9214, Velocity = 0.0105
#
# Episode 50, Action: 0.0000
# New State: Position = -0.9087, Velocity = 0.0128
#
# Episode 50, Action: 0.0000
# New State: Position = -0.8936, Velocity = 0.0151
#
# Episode 50, Action: 0.0000
# New State: Position = -0.8762, Velocity = 0.0173
#
# Episode 50, Action: 0.0000
# New State: Position = -0.8567, Velocity = 0.0195
#
# Episode 50, Action: 0.0000
# New State: Position = -0.8351, Velocity = 0.0216
#
# Episode 50, Action: 0.0000
# New State: Position = -0.8115, Velocity = 0.0236
#
# Episode 50, Action: 0.0000
# New State: Position = -0.7860, Velocity = 0.0255
#
# Episode 50, Action: 0.0000
# New State: Position = -0.7587, Velocity = 0.0273
#
# Episode 50, Action: 0.0714
# New State: Position = -0.7297, Velocity = 0.0290
#
# Episode 50, Action: 0.2778
# New State: Position = -0.6988, Velocity = 0.0309
#
# Episode 50, Action: 0.5476
# New State: Position = -0.6659, Velocity = 0.0330
#
# Episode 50, Action: 0.6984
# New State: Position = -0.6308, Velocity = 0.0350
#
# Episode 50, Action: 0.8254
# New State: Position = -0.5938, Velocity = 0.0371
#
# Episode 50, Action: 0.9047
# New State: Position = -0.5548, Velocity = 0.0389
#
# Episode 50, Action: 0.9682
# New State: Position = -0.5142, Velocity = 0.0406
#
# Episode 50, Action: 0.9841
# New State: Position = -0.4722, Velocity = 0.0420
#
# Episode 50, Action: 0.9841
# New State: Position = -0.4290, Velocity = 0.0431
#
# Episode 50, Action: 0.9920
# New State: Position = -0.3851, Velocity = 0.0439
#
# Episode 50, Action: 1.0000
# New State: Position = -0.3407, Velocity = 0.0444
#
# Episode 50, Action: 1.0000
# New State: Position = -0.2961, Velocity = 0.0446
#
# Episode 50, Action: 1.0000
# New State: Position = -0.2516, Velocity = 0.0445
#
# Episode 50, Action: 1.0000
# New State: Position = -0.2074, Velocity = 0.0442
#
# Episode 50, Action: 1.0000
# New State: Position = -0.1637, Velocity = 0.0437
#
# Episode 50, Action: 1.0000
# New State: Position = -0.1207, Velocity = 0.0430
#
# Episode 50, Action: 1.0000
# New State: Position = -0.0786, Velocity = 0.0421
#
# Episode 50, Action: 1.0000
# New State: Position = -0.0374, Velocity = 0.0412
#
# Episode 50, Action: 1.0000
# New State: Position = 0.0028, Velocity = 0.0402
#
# Episode 50, Action: 1.0000
# New State: Position = 0.0421, Velocity = 0.0392
#
# Episode 50, Action: 1.0000
# New State: Position = 0.0803, Velocity = 0.0382
#
# Episode 50, Action: 1.0000
# New State: Position = 0.1176, Velocity = 0.0373
#
# Episode 50, Action: 1.0000
# New State: Position = 0.1541, Velocity = 0.0365
#
# Episode 50, Action: 1.0000
# New State: Position = 0.1898, Velocity = 0.0357
#
# Episode 50, Action: 1.0000
# New State: Position = 0.2249, Velocity = 0.0351
#
# Episode 50, Action: 1.0000
# New State: Position = 0.2596, Velocity = 0.0347
#
# Episode 50, Action: 1.0000
# New State: Position = 0.2940, Velocity = 0.0344
#
# Episode 50, Action: 1.0000
# New State: Position = 0.3283, Velocity = 0.0343
#
# Episode 50, Action: 1.0000
# New State: Position = 0.3627, Velocity = 0.0344
#
# Episode 50, Action: 1.0000
# New State: Position = 0.3974, Velocity = 0.0348
#
# Episode 50, Action: 1.0000
# New State: Position = 0.4328, Velocity = 0.0353
#
# Episode 50, Action: 1.0000
# New State: Position = 0.4689, Velocity = 0.0362

# %% [markdown]
# This script has not been verified, do not use

# %%
def run_continuous_action_test_with_random_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()

    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 显示倒数和回合开始信息
            print("Episode {} start in: ".format(i+1), end="")
            for countdown in range(2, 0, -1):
                print("{} ".format(countdown), end="", flush=True)
                time.sleep(1)
            print("\nEpisode {} start!".format(i+1))

            # 随机设置小车的初始状态
            initial_position = np.random.uniform(-1.2, 0.6)
            initial_velocity = np.random.uniform(-0.07, 0.07)  # 速度允许范围

            # 使用 reset 并传递随机初始化位置和速度
            env.reset(options={"state": [initial_position, initial_velocity]})

            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_random_initial_state(30, render=True)

# %% [markdown]
# ### Finally, the initial position and velocity can be set correctly, but need to be limited before the goal (before 0.45)

# %%
def run_continuous_action_test_with_random_initial_state(episodes, render=False):
    # 初始化环境
    env = gym.make('MountainCarContinuous-v0', render_mode='human' if render else None)

    # 初始化 pygame
    pygame.init()

    # 初始化手柄
    pygame.joystick.init()

    # 检查是否连接了手柄
    if pygame.joystick.get_count() > 0:
        joystick = pygame.joystick.Joystick(0)
        joystick.init()
        print(f"Initialized Joystick: {joystick.get_name()}")

        # 获取手柄的轴数量
        num_axes = joystick.get_numaxes()
        print(f"Number of axes: {num_axes}")

        for i in range(episodes):
            # 显示倒数和回合开始信息
            print("Episode {} start in: ".format(i+1), end="")
            for countdown in range(2, 0, -1):
                print("{} ".format(countdown), end="", flush=True)
                time.sleep(1)
            print("\nEpisode {} start!".format(i+1))

            # 随机设置小车的初始状态
            initial_position = np.random.uniform(-1.2, 0.44)
            initial_velocity = np.random.uniform(-0.07, 0.07)  # 速度允许范围

            # 重置环境，并手动设置小车的初始状态
            env.reset()  # 重置环境
            env.unwrapped.state = np.array([initial_position, initial_velocity])  # 手动修改状态

            terminated = False  # True when reached goal

            # 为每个 episode 创建一个 CSV 文件
            filename = f"episode_{i+1}.csv"
            with open(filename, mode='w', newline='') as file:
                writer = csv.writer(file)
                # 写入 CSV 文件的头部
                writer.writerow(["timestamp", "action", "position", "velocity"])

                while not terminated:
                    for event in pygame.event.get():
                        if event.type == pygame.QUIT:
                            terminated = True
                            break

                    # 读取手柄第一个轴的数值作为动作
                    axis_values = [joystick.get_axis(i) for i in range(num_axes)]
                    action = axis_values[0]  # 使用第一个轴的值作为动作 [-1.0, 1.0]

                    # 获取当前时间戳
                    timestamp = time.time()

                    # 应用动作并观察小车的运动
                    new_state, reward, terminated, _, _ = env.step([action])

                    # 打印小车的新状态
                    print(f"Episode {i+1}, Action: {action:.4f}")
                    print(f"New State: Position = {new_state[0]:.4f}, Velocity = {new_state[1]:.4f}\n")

                    # 将数据写入 CSV 文件
                    writer.writerow([timestamp, action, new_state[0], new_state[1]])

                    # 如果小车达到目标或者回到起始位置，终止循环
                    if terminated:
                        break

        env.close()
    else:
        print("No joystick found.")

    # 退出 pygame
    pygame.quit()

if __name__ == '__main__':
    run_continuous_action_test_with_random_initial_state(50, render=True)
# Out:
# Initialized Joystick: Logicool Dual Action
# Number of axes: 4
# Episode 1 start in: 2 1
# Episode 1 start!
# Episode 1, Action: 0.0000
# New State: Position = -0.4361, Velocity = 0.0655
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3713, Velocity = 0.0648
#
# Episode 1, Action: 0.0000
# New State: Position = -0.3076, Velocity = 0.0637
#
# Episode 1, Action: 0.0000
# New State: Position = -0.2454, Velocity = 0.0622
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1851, Velocity = 0.0603
#
# Episode 1, Action: 0.0000
# New State: Position = -0.1268, Velocity = 0.0582
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0709, Velocity = 0.0559
#
# Episode 1, Action: 0.0000
# New State: Position = -0.0175, Velocity = 0.0535
#
# Episode 1, Action: 0.0000
# New State: Position = 0.0335, Velocity = 0.0510
#
# Episode 1, Action: 0.0000
# New State: Position = 0.0819, Velocity = 0.0485
#
# Episode 1, Action: 0.0000
# New State: Position = 0.1280, Velocity = 0.0460
#
# Episode 1, Action: 0.0000
# New State: Position = 0.1717, Velocity = 0.0437
#
# Episode 1, Action: 0.0000
# New State: Position = 0.2132, Velocity = 0.0415
#
# Episode 1, Action: 0.0000
# New State: Position = 0.2528, Velocity = 0.0395
#
# Episode 1, Action: 0.0000
# New State: Position = 0.2905, Velocity = 0.0377
#
# Episode 1, Action: 0.0000
# New State: Position = 0.3266, Velocity = 0.0361
#
# Episode 1, Action: 0.0000
# New State: Position = 0.3614, Velocity = 0.0347
#
# Episode 1, Action: 0.0000
# New State: Position = 0.3949, Velocity = 0.0336
#
# Episode 1, Action: 0.0000
# New State: Position = 0.4275, Velocity = 0.0326
#
# Episode 1, Action: 0.0000
# New State: Position = 0.4594, Velocity = 0.0319
#
# Episode 2 start in: 2 1
# Episode 2 start!
# Episode 2, Action: 0.0000
# New State: Position = -0.9814, Velocity = 0.0098
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9692, Velocity = 0.0122
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9545, Velocity = 0.0147
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9374, Velocity = 0.0171
#
# Episode 2, Action: 0.0000
# New State: Position = -0.9180, Velocity = 0.0194
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8962, Velocity = 0.0218
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8722, Velocity = 0.0240
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8460, Velocity = 0.0262
#
# Episode 2, Action: 0.0000
# New State: Position = -0.8178, Velocity = 0.0282
#
# Episode 2, Action: 0.0000
# New State: Position = -0.7876, Velocity = 0.0302
#
# Episode 2, Action: 0.0000
# New State: Position = -0.7557, Velocity = 0.0319
#
# Episode 2, Action: 0.0000
# New State: Position = -0.7222, Velocity = 0.0335
#
# Episode 2, Action: 0.0000
# New State: Position = -0.6872, Velocity = 0.0349
#
# Episode 2, Action: 0.0000
# New State: Position = -0.6511, Velocity = 0.0361
#
# Episode 2, Action: 0.0000
# New State: Position = -0.6140, Velocity = 0.0371
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5763, Velocity = 0.0377
#
# Episode 2, Action: 0.0000
# New State: Position = -0.5382, Velocity = 0.0381
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4999, Velocity = 0.0382
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4619, Velocity = 0.0381
#
# Episode 2, Action: 0.0000
# New State: Position = -0.4243, Velocity = 0.0376
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3874, Velocity = 0.0369
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3516, Velocity = 0.0359
#
# Episode 2, Action: 0.0000
# New State: Position = -0.3169, Velocity = 0.0346
#
# Episode 2, Action: 0.0000
# New State: Position = -0.2838, Velocity = 0.0332
#
# Episode 2, Action: 0.1111
# New State: Position = -0.2521, Velocity = 0.0317
#
# Episode 2, Action: 0.3968
# New State: Position = -0.2216, Velocity = 0.0305
#
# Episode 2, Action: 0.7460
# New State: Position = -0.1920, Velocity = 0.0296
#
# Episode 2, Action: 0.9365
# New State: Position = -0.1630, Velocity = 0.0289
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1348, Velocity = 0.0282
#
# Episode 2, Action: 1.0000
# New State: Position = -0.1074, Velocity = 0.0274
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0808, Velocity = 0.0266
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0552, Velocity = 0.0256
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0305, Velocity = 0.0247
#
# Episode 2, Action: 1.0000
# New State: Position = -0.0068, Velocity = 0.0237
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0158, Velocity = 0.0227
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0375, Velocity = 0.0217
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0582, Velocity = 0.0207
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0779, Velocity = 0.0197
#
# Episode 2, Action: 1.0000
# New State: Position = 0.0968, Velocity = 0.0188
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1147, Velocity = 0.0179
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1317, Velocity = 0.0171
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1480, Velocity = 0.0162
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1634, Velocity = 0.0155
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1782, Velocity = 0.0148
#
# Episode 2, Action: 1.0000
# New State: Position = 0.1924, Velocity = 0.0141
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2059, Velocity = 0.0135
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2189, Velocity = 0.0130
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2314, Velocity = 0.0125
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2435, Velocity = 0.0121
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2552, Velocity = 0.0117
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2667, Velocity = 0.0114
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2778, Velocity = 0.0112
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2889, Velocity = 0.0110
#
# Episode 2, Action: 1.0000
# New State: Position = 0.2997, Velocity = 0.0109
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3106, Velocity = 0.0108
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3214, Velocity = 0.0108
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3323, Velocity = 0.0109
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3434, Velocity = 0.0111
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3547, Velocity = 0.0113
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3662, Velocity = 0.0116
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3782, Velocity = 0.0119
#
# Episode 2, Action: 1.0000
# New State: Position = 0.3905, Velocity = 0.0124
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4034, Velocity = 0.0129
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4169, Velocity = 0.0135
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4312, Velocity = 0.0142
#
# Episode 2, Action: 1.0000
# New State: Position = 0.4462, Velocity = 0.0150
#
# Episode 2, Action: 0.5793
# New State: Position = 0.4615, Velocity = 0.0153
#
# Episode 3 start in: 2 1
# Episode 3 start!
# Episode 3, Action: -0.0156
# New State: Position = -0.4278, Velocity = 0.0262
#
# Episode 3, Action: -0.0156
# New State: Position = -0.4023, Velocity = 0.0255
#
# Episode 3, Action: -0.0156
# New State: Position = -0.3778, Velocity = 0.0246
#
# Episode 3, Action: -0.0156
# New State: Position = -0.3542, Velocity = 0.0235
#
# Episode 3, Action: -0.0156
# New State: Position = -0.3320, Velocity = 0.0223
#
# Episode 3, Action: -0.0156
# New State: Position = -0.3111, Velocity = 0.0209
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2917, Velocity = 0.0194
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2740, Velocity = 0.0177
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2579, Velocity = 0.0160
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2437, Velocity = 0.0142
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2314, Velocity = 0.0123
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2210, Velocity = 0.0104
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2126, Velocity = 0.0084
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2063, Velocity = 0.0064
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2020, Velocity = 0.0043
#
# Episode 3, Action: -0.0156
# New State: Position = -0.1998, Velocity = 0.0022
#
# Episode 3, Action: -0.0156
# New State: Position = -0.1996, Velocity = 0.0001
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2016, Velocity = -0.0020
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2056, Velocity = -0.0040
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2117, Velocity = -0.0061
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2199, Velocity = -0.0081
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2300, Velocity = -0.0101
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2421, Velocity = -0.0121
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2561, Velocity = -0.0140
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2719, Velocity = -0.0158
#
# Episode 3, Action: -0.0156
# New State: Position = -0.2894, Velocity = -0.0175
#
# Episode 3, Action: -0.0156
# New State: Position = -0.3086, Velocity = -0.0192
#
# Episode 3, Action: -0.0391
# New State: Position = -0.3293, Velocity = -0.0207
#
# Episode 3, Action: -0.2031
# New State: Position = -0.3517, Velocity = -0.0224
#
# Episode 3, Action: -0.3828
# New State: Position = -0.3760, Velocity = -0.0242
#
# Episode 3, Action: -0.5312
# New State: Position = -0.4021, Velocity = -0.0261
#
# Episode 3, Action: -0.6016
# New State: Position = -0.4300, Velocity = -0.0279
#
# Episode 3, Action: -0.6172
# New State: Position = -0.4595, Velocity = -0.0295
#
# Episode 3, Action: -0.6250
# New State: Position = -0.4904, Velocity = -0.0309
#
# Episode 3, Action: -0.6250
# New State: Position = -0.5225, Velocity = -0.0321
#
# Episode 3, Action: -0.6250
# New State: Position = -0.5555, Velocity = -0.0331
#
# Episode 3, Action: -0.6250
# New State: Position = -0.5893, Velocity = -0.0338
#
# Episode 3, Action: -0.6406
# New State: Position = -0.6235, Velocity = -0.0342
#
# Episode 3, Action: -0.6406
# New State: Position = -0.6580, Velocity = -0.0344
#
# Episode 3, Action: -0.6406
# New State: Position = -0.6924, Velocity = -0.0344
#
# Episode 3, Action: -0.6406
# New State: Position = -0.7266, Velocity = -0.0342
#
# Episode 3, Action: -0.6406
# New State: Position = -0.7603, Velocity = -0.0337
#
# Episode 3, Action: -0.6406
# New State: Position = -0.7933, Velocity = -0.0330
#
# Episode 3, Action: -0.6406
# New State: Position = -0.8255, Velocity = -0.0322
#
# Episode 3, Action: -0.6406
# New State: Position = -0.8567, Velocity = -0.0312
#
# Episode 3, Action: -0.6406
# New State: Position = -0.8867, Velocity = -0.0300
#
# Episode 3, Action: -0.5312
# New State: Position = -0.9153, Velocity = -0.0286
#
# Episode 3, Action: -0.3047
# New State: Position = -0.9421, Velocity = -0.0268
#
# Episode 3, Action: -0.0234
# New State: Position = -0.9666, Velocity = -0.0244
#
# Episode 3, Action: 0.0000
# New State: Position = -0.9886, Velocity = -0.0220
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0081, Velocity = -0.0195
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0252, Velocity = -0.0171
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0397, Velocity = -0.0146
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0518, Velocity = -0.0121
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0614, Velocity = -0.0096
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0684, Velocity = -0.0071
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0730, Velocity = -0.0046
#
# Episode 3, Action: 0.0000
# New State: Position = -1.0751, Velocity = -0.0021
#
# Episode 3, Action: 0.0476
# New State: Position = -1.0746, Velocity = 0.0005
#
# Episode 3, Action: 0.3016
# New State: Position = -1.0712, Velocity = 0.0034
#
# Episode 3, Action: 0.7063
# New State: Position = -1.0642, Velocity = 0.0070
#
# Episode 3, Action: 0.9047
# New State: Position = -1.0534, Velocity = 0.0108
#
# Episode 3, Action: 0.9841
# New State: Position = -1.0385, Velocity = 0.0148
#
# Episode 3, Action: 1.0000
# New State: Position = -1.0197, Velocity = 0.0188
#
# Episode 3, Action: 1.0000
# New State: Position = -0.9969, Velocity = 0.0228
#
# Episode 3, Action: 1.0000
# New State: Position = -0.9702, Velocity = 0.0268
#
# Episode 3, Action: 1.0000
# New State: Position = -0.9395, Velocity = 0.0307
#
# Episode 3, Action: 1.0000
# New State: Position = -0.9049, Velocity = 0.0346
#
# Episode 3, Action: 1.0000
# New State: Position = -0.8665, Velocity = 0.0384
#
# Episode 3, Action: 1.0000
# New State: Position = -0.8245, Velocity = 0.0420
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7791, Velocity = 0.0455
#
# Episode 3, Action: 1.0000
# New State: Position = -0.7304, Velocity = 0.0487
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6788, Velocity = 0.0516
#
# Episode 3, Action: 1.0000
# New State: Position = -0.6245, Velocity = 0.0543
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5680, Velocity = 0.0565
#
# Episode 3, Action: 1.0000
# New State: Position = -0.5096, Velocity = 0.0583
#
# Episode 3, Action: 1.0000
# New State: Position = -0.4499, Velocity = 0.0597
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3892, Velocity = 0.0607
#
# Episode 3, Action: 1.0000
# New State: Position = -0.3280, Velocity = 0.0612
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2667, Velocity = 0.0613
#
# Episode 3, Action: 1.0000
# New State: Position = -0.2056, Velocity = 0.0611
#
# Episode 3, Action: 1.0000
# New State: Position = -0.1451, Velocity = 0.0605
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0853, Velocity = 0.0598
#
# Episode 3, Action: 1.0000
# New State: Position = -0.0264, Velocity = 0.0589
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0314, Velocity = 0.0579
#
# Episode 3, Action: 1.0000
# New State: Position = 0.0883, Velocity = 0.0569
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1443, Velocity = 0.0560
#
# Episode 3, Action: 1.0000
# New State: Position = 0.1995, Velocity = 0.0552
#
# Episode 3, Action: 1.0000
# New State: Position = 0.2541, Velocity = 0.0546
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3084, Velocity = 0.0543
#
# Episode 3, Action: 1.0000
# New State: Position = 0.3627, Velocity = 0.0543
#
# Episode 3, Action: 1.0000
# New State: Position = 0.4174, Velocity = 0.0547
#
# Episode 3, Action: 1.0000
# New State: Position = 0.4728, Velocity = 0.0554
#
# Episode 4 start in: 2 1
# Episode 4 start!
# Episode 4, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 4, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 4, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0309
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9550, Velocity = 0.0333
#
# Episode 4, Action: 0.0000
# New State: Position = -0.9193, Velocity = 0.0357
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8812, Velocity = 0.0381
#
# Episode 4, Action: 0.0000
# New State: Position = -0.8410, Velocity = 0.0403
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7987, Velocity = 0.0423
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7545, Velocity = 0.0441
#
# Episode 4, Action: 0.0000
# New State: Position = -0.7088, Velocity = 0.0457
#
# Episode 4, Action: 0.0000
# New State: Position = -0.6618, Velocity = 0.0471
#
# Episode 4, Action: 0.0000
# New State: Position = -0.6137, Velocity = 0.0481
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5650, Velocity = 0.0487
#
# Episode 4, Action: 0.0000
# New State: Position = -0.5159, Velocity = 0.0490
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4670, Velocity = 0.0490
#
# Episode 4, Action: 0.0000
# New State: Position = -0.4184, Velocity = 0.0486
#
# Episode 4, Action: 0.0000
# New State: Position = -0.3706, Velocity = 0.0478
#
# Episode 4, Action: 0.0000
# New State: Position = -0.3240, Velocity = 0.0467
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2787, Velocity = 0.0453
#
# Episode 4, Action: 0.0000
# New State: Position = -0.2351, Velocity = 0.0436
#
# Episode 4, Action: 0.0000
# New State: Position = -0.1934, Velocity = 0.0417
#
# Episode 4, Action: 0.0000
# New State: Position = -0.1538, Velocity = 0.0396
#
# Episode 4, Action: 0.0000
# New State: Position = -0.1165, Velocity = 0.0374
#
# Episode 4, Action: 0.0000
# New State: Position = -0.0815, Velocity = 0.0350
#
# Episode 4, Action: 0.0000
# New State: Position = -0.0489, Velocity = 0.0326
#
# Episode 4, Action: 0.0000
# New State: Position = -0.0188, Velocity = 0.0301
#
# Episode 4, Action: 0.0000
# New State: Position = 0.0088, Velocity = 0.0276
#
# Episode 4, Action: 0.0000
# New State: Position = 0.0339, Velocity = 0.0251
#
# Episode 4, Action: 0.1270
# New State: Position = 0.0567, Velocity = 0.0228
#
# Episode 4, Action: 0.2937
# New State: Position = 0.0775, Velocity = 0.0208
#
# Episode 4, Action: 0.5238
# New State: Position = 0.0967, Velocity = 0.0191
#
# Episode 4, Action: 0.6587
# New State: Position = 0.1144, Velocity = 0.0177
#
# Episode 4, Action: 0.7540
# New State: Position = 0.1309, Velocity = 0.0165
#
# Episode 4, Action: 0.8571
# New State: Position = 0.1464, Velocity = 0.0155
#
# Episode 4, Action: 0.9127
# New State: Position = 0.1610, Velocity = 0.0146
#
# Episode 4, Action: 0.9524
# New State: Position = 0.1748, Velocity = 0.0138
#
# Episode 4, Action: 0.9841
# New State: Position = 0.1879, Velocity = 0.0131
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2004, Velocity = 0.0125
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2124, Velocity = 0.0119
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2238, Velocity = 0.0114
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2348, Velocity = 0.0110
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2454, Velocity = 0.0106
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2556, Velocity = 0.0102
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2655, Velocity = 0.0099
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2752, Velocity = 0.0097
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2847, Velocity = 0.0095
#
# Episode 4, Action: 1.0000
# New State: Position = 0.2940, Velocity = 0.0093
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3033, Velocity = 0.0092
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3125, Velocity = 0.0092
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3217, Velocity = 0.0092
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3310, Velocity = 0.0093
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3405, Velocity = 0.0094
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3501, Velocity = 0.0096
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3600, Velocity = 0.0099
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3702, Velocity = 0.0102
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3808, Velocity = 0.0106
#
# Episode 4, Action: 1.0000
# New State: Position = 0.3919, Velocity = 0.0111
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4035, Velocity = 0.0116
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4157, Velocity = 0.0122
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4287, Velocity = 0.0129
#
# Episode 4, Action: 1.0000
# New State: Position = 0.4424, Velocity = 0.0137
#
# Episode 4, Action: 0.7540
# New State: Position = 0.4566, Velocity = 0.0143
#
# Episode 5 start in: 2 1
# Episode 5 start!
# Episode 5, Action: 0.0000
# New State: Position = -0.4919, Velocity = -0.0518
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5439, Velocity = -0.0520
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5958, Velocity = -0.0519
#
# Episode 5, Action: 0.0000
# New State: Position = -0.6471, Velocity = -0.0513
#
# Episode 5, Action: 0.0000
# New State: Position = -0.6975, Velocity = -0.0504
#
# Episode 5, Action: 0.0000
# New State: Position = -0.7467, Velocity = -0.0492
#
# Episode 5, Action: 0.0000
# New State: Position = -0.7943, Velocity = -0.0476
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8401, Velocity = -0.0458
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8839, Velocity = -0.0438
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9255, Velocity = -0.0416
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9647, Velocity = -0.0392
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0015, Velocity = -0.0368
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0359, Velocity = -0.0343
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0677, Velocity = -0.0318
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0971, Velocity = -0.0293
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1239, Velocity = -0.0269
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1484, Velocity = -0.0244
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1704, Velocity = -0.0220
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1901, Velocity = -0.0197
#
# Episode 5, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 5, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 5, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0309
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9550, Velocity = 0.0333
#
# Episode 5, Action: 0.0000
# New State: Position = -0.9193, Velocity = 0.0357
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8812, Velocity = 0.0381
#
# Episode 5, Action: 0.0000
# New State: Position = -0.8410, Velocity = 0.0403
#
# Episode 5, Action: 0.0000
# New State: Position = -0.7987, Velocity = 0.0423
#
# Episode 5, Action: 0.0000
# New State: Position = -0.7545, Velocity = 0.0441
#
# Episode 5, Action: 0.0000
# New State: Position = -0.7088, Velocity = 0.0457
#
# Episode 5, Action: 0.0000
# New State: Position = -0.6618, Velocity = 0.0471
#
# Episode 5, Action: 0.0000
# New State: Position = -0.6137, Velocity = 0.0481
#
# Episode 5, Action: 0.0000
# New State: Position = -0.5650, Velocity = 0.0487
#
# Episode 5, Action: 0.2699
# New State: Position = -0.5155, Velocity = 0.0494
#
# Episode 5, Action: 0.6667
# New State: Position = -0.4652, Velocity = 0.0504
#
# Episode 5, Action: 0.8968
# New State: Position = -0.4139, Velocity = 0.0513
#
# Episode 5, Action: 0.9920
# New State: Position = -0.3619, Velocity = 0.0520
#
# Episode 5, Action: 1.0000
# New State: Position = -0.3096, Velocity = 0.0523
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2573, Velocity = 0.0523
#
# Episode 5, Action: 1.0000
# New State: Position = -0.2053, Velocity = 0.0520
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1538, Velocity = 0.0515
#
# Episode 5, Action: 1.0000
# New State: Position = -0.1031, Velocity = 0.0507
#
# Episode 5, Action: 1.0000
# New State: Position = -0.0532, Velocity = 0.0499
#
# Episode 5, Action: 1.0000
# New State: Position = -0.0043, Velocity = 0.0489
#
# Episode 5, Action: 1.0000
# New State: Position = 0.0436, Velocity = 0.0479
#
# Episode 5, Action: 1.0000
# New State: Position = 0.0905, Velocity = 0.0469
#
# Episode 5, Action: 1.0000
# New State: Position = 0.1365, Velocity = 0.0460
#
# Episode 5, Action: 1.0000
# New State: Position = 0.1817, Velocity = 0.0452
#
# Episode 5, Action: 1.0000
# New State: Position = 0.2262, Velocity = 0.0446
#
# Episode 5, Action: 1.0000
# New State: Position = 0.2703, Velocity = 0.0441
#
# Episode 5, Action: 1.0000
# New State: Position = 0.3142, Velocity = 0.0439
#
# Episode 5, Action: 1.0000
# New State: Position = 0.3582, Velocity = 0.0439
#
# Episode 5, Action: 0.7619
# New State: Position = 0.4021, Velocity = 0.0439
#
# Episode 5, Action: 0.2619
# New State: Position = 0.4454, Velocity = 0.0434
#
# Episode 5, Action: 0.0000
# New State: Position = 0.4882, Velocity = 0.0428
#
# Episode 6 start in: 2 1
# Episode 6 start!
# Episode 6, Action: 0.0000
# New State: Position = -1.0859, Velocity = 0.0582
#
# Episode 6, Action: 0.0000
# New State: Position = -1.0252, Velocity = 0.0607
#
# Episode 6, Action: 0.0000
# New State: Position = -0.9620, Velocity = 0.0632
#
# Episode 6, Action: 0.0000
# New State: Position = -0.8964, Velocity = 0.0656
#
# Episode 6, Action: 0.0000
# New State: Position = -0.8286, Velocity = 0.0678
#
# Episode 6, Action: 0.0000
# New State: Position = -0.7588, Velocity = 0.0698
#
# Episode 6, Action: 0.0000
# New State: Position = -0.6888, Velocity = 0.0700
#
# Episode 6, Action: 0.0000
# New State: Position = -0.6188, Velocity = 0.0700
#
# Episode 6, Action: 0.0000
# New State: Position = -0.5488, Velocity = 0.0700
#
# Episode 6, Action: 0.0000
# New State: Position = -0.4788, Velocity = 0.0700
#
# Episode 6, Action: 0.0000
# New State: Position = -0.4091, Velocity = 0.0697
#
# Episode 6, Action: 0.0000
# New State: Position = -0.3403, Velocity = 0.0688
#
# Episode 6, Action: 0.0000
# New State: Position = -0.2728, Velocity = 0.0675
#
# Episode 6, Action: 0.0000
# New State: Position = -0.2070, Velocity = 0.0658
#
# Episode 6, Action: 0.0000
# New State: Position = -0.1432, Velocity = 0.0638
#
# Episode 6, Action: 0.0000
# New State: Position = -0.0817, Velocity = 0.0615
#
# Episode 6, Action: 0.0000
# New State: Position = -0.0226, Velocity = 0.0591
#
# Episode 6, Action: 0.0000
# New State: Position = 0.0340, Velocity = 0.0566
#
# Episode 6, Action: 0.0000
# New State: Position = 0.0881, Velocity = 0.0541
#
# Episode 6, Action: 0.0000
# New State: Position = 0.1398, Velocity = 0.0517
#
# Episode 6, Action: 0.0000
# New State: Position = 0.1891, Velocity = 0.0494
#
# Episode 6, Action: 0.0000
# New State: Position = 0.2364, Velocity = 0.0473
#
# Episode 6, Action: 0.0000
# New State: Position = 0.2818, Velocity = 0.0454
#
# Episode 6, Action: 0.0000
# New State: Position = 0.3256, Velocity = 0.0437
#
# Episode 6, Action: 0.0000
# New State: Position = 0.3679, Velocity = 0.0423
#
# Episode 6, Action: 0.0000
# New State: Position = 0.4091, Velocity = 0.0412
#
# Episode 6, Action: 0.0000
# New State: Position = 0.4495, Velocity = 0.0404
#
# Episode 6, Action: 0.0000
# New State: Position = 0.4893, Velocity = 0.0398
#
# Episode 7 start in: 2 1
# Episode 7 start!
# Episode 7, Action: 0.0000
# New State: Position = -0.2422, Velocity = -0.0607
#
# Episode 7, Action: 0.0000
# New State: Position = -0.3047, Velocity = -0.0625
#
# Episode 7, Action: 0.0000
# New State: Position = -0.3688, Velocity = -0.0641
#
# Episode 7, Action: 0.0000
# New State: Position = -0.4340, Velocity = -0.0652
#
# Episode 7, Action: 0.0000
# New State: Position = -0.4998, Velocity = -0.0659
#
# Episode 7, Action: 0.0000
# New State: Position = -0.5659, Velocity = -0.0660
#
# Episode 7, Action: 0.0000
# New State: Position = -0.6316, Velocity = -0.0657
#
# Episode 7, Action: 0.0000
# New State: Position = -0.6965, Velocity = -0.0649
#
# Episode 7, Action: 0.0000
# New State: Position = -0.7602, Velocity = -0.0637
#
# Episode 7, Action: 0.0000
# New State: Position = -0.8223, Velocity = -0.0621
#
# Episode 7, Action: 0.0000
# New State: Position = -0.8824, Velocity = -0.0601
#
# Episode 7, Action: 0.0000
# New State: Position = -0.9403, Velocity = -0.0579
#
# Episode 7, Action: 0.0000
# New State: Position = -0.9958, Velocity = -0.0555
#
# Episode 7, Action: 0.0000
# New State: Position = -1.0489, Velocity = -0.0531
#
# Episode 7, Action: 0.0000
# New State: Position = -1.0994, Velocity = -0.0506
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1475, Velocity = -0.0481
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1932, Velocity = -0.0457
#
# Episode 7, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 7, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 7, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 7, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 7, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 7, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 7, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0309
#
# Episode 7, Action: 0.0000
# New State: Position = -0.9550, Velocity = 0.0333
#
# Episode 7, Action: 0.0000
# New State: Position = -0.9193, Velocity = 0.0357
#
# Episode 7, Action: 0.0000
# New State: Position = -0.8812, Velocity = 0.0381
#
# Episode 7, Action: 0.0000
# New State: Position = -0.8410, Velocity = 0.0403
#
# Episode 7, Action: 0.0000
# New State: Position = -0.7987, Velocity = 0.0423
#
# Episode 7, Action: 0.0000
# New State: Position = -0.7545, Velocity = 0.0441
#
# Episode 7, Action: 0.0000
# New State: Position = -0.7088, Velocity = 0.0457
#
# Episode 7, Action: 0.0000
# New State: Position = -0.6618, Velocity = 0.0471
#
# Episode 7, Action: 0.0000
# New State: Position = -0.6137, Velocity = 0.0481
#
# Episode 7, Action: 0.0000
# New State: Position = -0.5650, Velocity = 0.0487
#
# Episode 7, Action: 0.1588
# New State: Position = -0.5157, Velocity = 0.0493
#
# Episode 7, Action: 0.3730
# New State: Position = -0.4659, Velocity = 0.0498
#
# Episode 7, Action: 0.4921
# New State: Position = -0.4158, Velocity = 0.0501
#
# Episode 7, Action: 0.5238
# New State: Position = -0.3658, Velocity = 0.0501
#
# Episode 7, Action: 0.5317
# New State: Position = -0.3160, Velocity = 0.0497
#
# Episode 7, Action: 0.5317
# New State: Position = -0.2670, Velocity = 0.0491
#
# Episode 7, Action: 0.5555
# New State: Position = -0.2188, Velocity = 0.0482
#
# Episode 7, Action: 0.6270
# New State: Position = -0.1717, Velocity = 0.0471
#
# Episode 7, Action: 0.7301
# New State: Position = -0.1256, Velocity = 0.0460
#
# Episode 7, Action: 0.8412
# New State: Position = -0.0807, Velocity = 0.0450
#
# Episode 7, Action: 0.9286
# New State: Position = -0.0367, Velocity = 0.0439
#
# Episode 7, Action: 0.9841
# New State: Position = 0.0062, Velocity = 0.0429
#
# Episode 7, Action: 1.0000
# New State: Position = 0.0482, Velocity = 0.0419
#
# Episode 7, Action: 1.0000
# New State: Position = 0.0891, Velocity = 0.0410
#
# Episode 7, Action: 1.0000
# New State: Position = 0.1292, Velocity = 0.0401
#
# Episode 7, Action: 1.0000
# New State: Position = 0.1684, Velocity = 0.0392
#
# Episode 7, Action: 1.0000
# New State: Position = 0.2070, Velocity = 0.0385
#
# Episode 7, Action: 1.0000
# New State: Position = 0.2450, Velocity = 0.0380
#
# Episode 7, Action: 1.0000
# New State: Position = 0.2826, Velocity = 0.0377
#
# Episode 7, Action: 1.0000
# New State: Position = 0.3201, Velocity = 0.0375
#
# Episode 7, Action: 0.8412
# New State: Position = 0.3575, Velocity = 0.0373
#
# Episode 7, Action: 0.5714
# New State: Position = 0.3945, Velocity = 0.0370
#
# Episode 7, Action: 0.3016
# New State: Position = 0.4310, Velocity = 0.0365
#
# Episode 7, Action: 0.1429
# New State: Position = 0.4670, Velocity = 0.0360
#
# Episode 8 start in: 2 1
# Episode 8 start!
# Episode 8, Action: 0.0000
# New State: Position = -0.1973, Velocity = 0.0261
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1733, Velocity = 0.0240
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1515, Velocity = 0.0218
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1319, Velocity = 0.0196
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1146, Velocity = 0.0173
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0997, Velocity = 0.0149
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0872, Velocity = 0.0125
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0771, Velocity = 0.0101
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0694, Velocity = 0.0077
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0641, Velocity = 0.0052
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0613, Velocity = 0.0028
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0610, Velocity = 0.0003
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0631, Velocity = -0.0021
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0677, Velocity = -0.0046
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0748, Velocity = -0.0070
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0842, Velocity = -0.0095
#
# Episode 8, Action: 0.0000
# New State: Position = -0.0961, Velocity = -0.0119
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1104, Velocity = -0.0143
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1271, Velocity = -0.0167
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1460, Velocity = -0.0190
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1673, Velocity = -0.0212
#
# Episode 8, Action: 0.0000
# New State: Position = -0.1907, Velocity = -0.0234
#
# Episode 8, Action: 0.0000
# New State: Position = -0.2162, Velocity = -0.0255
#
# Episode 8, Action: 0.0000
# New State: Position = -0.2437, Velocity = -0.0275
#
# Episode 8, Action: 0.0000
# New State: Position = -0.2731, Velocity = -0.0294
#
# Episode 8, Action: 0.0000
# New State: Position = -0.3042, Velocity = -0.0311
#
# Episode 8, Action: 0.0000
# New State: Position = -0.3368, Velocity = -0.0326
#
# Episode 8, Action: 0.0000
# New State: Position = -0.3708, Velocity = -0.0339
#
# Episode 8, Action: 0.0000
# New State: Position = -0.4058, Velocity = -0.0351
#
# Episode 8, Action: 0.0000
# New State: Position = -0.4417, Velocity = -0.0359
#
# Episode 8, Action: 0.0000
# New State: Position = -0.4783, Velocity = -0.0365
#
# Episode 8, Action: 0.0000
# New State: Position = -0.5151, Velocity = -0.0369
#
# Episode 8, Action: -0.0078
# New State: Position = -0.5521, Velocity = -0.0369
#
# Episode 8, Action: -0.1328
# New State: Position = -0.5890, Velocity = -0.0369
#
# Episode 8, Action: -0.3438
# New State: Position = -0.6260, Velocity = -0.0370
#
# Episode 8, Action: -0.4766
# New State: Position = -0.6629, Velocity = -0.0369
#
# Episode 8, Action: -0.5000
# New State: Position = -0.6995, Velocity = -0.0366
#
# Episode 8, Action: -0.5000
# New State: Position = -0.7357, Velocity = -0.0361
#
# Episode 8, Action: -0.5000
# New State: Position = -0.7711, Velocity = -0.0354
#
# Episode 8, Action: -0.5000
# New State: Position = -0.8055, Velocity = -0.0345
#
# Episode 8, Action: -0.5000
# New State: Position = -0.8389, Velocity = -0.0333
#
# Episode 8, Action: -0.5000
# New State: Position = -0.8709, Velocity = -0.0321
#
# Episode 8, Action: -0.5156
# New State: Position = -0.9016, Velocity = -0.0307
#
# Episode 8, Action: -0.5312
# New State: Position = -0.9308, Velocity = -0.0292
#
# Episode 8, Action: -0.5312
# New State: Position = -0.9585, Velocity = -0.0277
#
# Episode 8, Action: -0.5312
# New State: Position = -0.9845, Velocity = -0.0260
#
# Episode 8, Action: -0.3984
# New State: Position = -1.0087, Velocity = -0.0242
#
# Episode 8, Action: -0.1172
# New State: Position = -1.0306, Velocity = -0.0219
#
# Episode 8, Action: -0.0078
# New State: Position = -1.0500, Velocity = -0.0194
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0669, Velocity = -0.0169
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0813, Velocity = -0.0144
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0932, Velocity = -0.0119
#
# Episode 8, Action: 0.0000
# New State: Position = -1.1026, Velocity = -0.0094
#
# Episode 8, Action: 0.0000
# New State: Position = -1.1096, Velocity = -0.0070
#
# Episode 8, Action: 0.0000
# New State: Position = -1.1141, Velocity = -0.0045
#
# Episode 8, Action: 0.0000
# New State: Position = -1.1162, Velocity = -0.0021
#
# Episode 8, Action: 0.0000
# New State: Position = -1.1158, Velocity = 0.0004
#
# Episode 8, Action: 0.0000
# New State: Position = -1.1130, Velocity = 0.0028
#
# Episode 8, Action: 0.0000
# New State: Position = -1.1077, Velocity = 0.0053
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0999, Velocity = 0.0077
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0897, Velocity = 0.0102
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0770, Velocity = 0.0127
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0619, Velocity = 0.0152
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0442, Velocity = 0.0177
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0240, Velocity = 0.0202
#
# Episode 8, Action: 0.0000
# New State: Position = -1.0013, Velocity = 0.0227
#
# Episode 8, Action: 0.0000
# New State: Position = -0.9762, Velocity = 0.0251
#
# Episode 8, Action: 0.0000
# New State: Position = -0.9486, Velocity = 0.0276
#
# Episode 8, Action: 0.0080
# New State: Position = -0.9186, Velocity = 0.0300
#
# Episode 8, Action: 0.0794
# New State: Position = -0.8862, Velocity = 0.0324
#
# Episode 8, Action: 0.1746
# New State: Position = -0.8513, Velocity = 0.0349
#
# Episode 8, Action: 0.2778
# New State: Position = -0.8139, Velocity = 0.0374
#
# Episode 8, Action: 0.3492
# New State: Position = -0.7740, Velocity = 0.0398
#
# Episode 8, Action: 0.4127
# New State: Position = -0.7319, Velocity = 0.0422
#
# Episode 8, Action: 0.4683
# New State: Position = -0.6875, Velocity = 0.0443
#
# Episode 8, Action: 0.5159
# New State: Position = -0.6413, Velocity = 0.0463
#
# Episode 8, Action: 0.5555
# New State: Position = -0.5933, Velocity = 0.0480
#
# Episode 8, Action: 0.5714
# New State: Position = -0.5439, Velocity = 0.0494
#
# Episode 8, Action: 0.5873
# New State: Position = -0.4935, Velocity = 0.0504
#
# Episode 8, Action: 0.6190
# New State: Position = -0.4424, Velocity = 0.0511
#
# Episode 8, Action: 0.6508
# New State: Position = -0.3910, Velocity = 0.0515
#
# Episode 8, Action: 0.6587
# New State: Position = -0.3395, Velocity = 0.0515
#
# Episode 8, Action: 0.6587
# New State: Position = -0.2883, Velocity = 0.0512
#
# Episode 8, Action: 0.6667
# New State: Position = -0.2378, Velocity = 0.0505
#
# Episode 8, Action: 0.6667
# New State: Position = -0.1881, Velocity = 0.0497
#
# Episode 8, Action: 0.6667
# New State: Position = -0.1396, Velocity = 0.0485
#
# Episode 8, Action: 0.6667
# New State: Position = -0.0923, Velocity = 0.0473
#
# Episode 8, Action: 0.6667
# New State: Position = -0.0465, Velocity = 0.0458
#
# Episode 8, Action: 0.6667
# New State: Position = -0.0021, Velocity = 0.0444
#
# Episode 8, Action: 0.6667
# New State: Position = 0.0408, Velocity = 0.0429
#
# Episode 8, Action: 0.6667
# New State: Position = 0.0821, Velocity = 0.0414
#
# Episode 8, Action: 0.6667
# New State: Position = 0.1221, Velocity = 0.0400
#
# Episode 8, Action: 0.6667
# New State: Position = 0.1607, Velocity = 0.0386
#
# Episode 8, Action: 0.6667
# New State: Position = 0.1982, Velocity = 0.0374
#
# Episode 8, Action: 0.6667
# New State: Position = 0.2345, Velocity = 0.0363
#
# Episode 8, Action: 0.6667
# New State: Position = 0.2700, Velocity = 0.0354
#
# Episode 8, Action: 0.6667
# New State: Position = 0.3047, Velocity = 0.0347
#
# Episode 8, Action: 0.6667
# New State: Position = 0.3389, Velocity = 0.0342
#
# Episode 8, Action: 0.6667
# New State: Position = 0.3727, Velocity = 0.0339
#
# Episode 8, Action: 0.5476
# New State: Position = 0.4063, Velocity = 0.0336
#
# Episode 8, Action: 0.3968
# New State: Position = 0.4397, Velocity = 0.0333
#
# Episode 8, Action: 0.2302
# New State: Position = 0.4727, Velocity = 0.0331
#
# Episode 9 start in: 2 1
# Episode 9 start!
# Episode 9, Action: 0.0000
# New State: Position = -0.0552, Velocity = 0.0652
#
# Episode 9, Action: 0.0000
# New State: Position = 0.0075, Velocity = 0.0627
#
# Episode 9, Action: 0.0000
# New State: Position = 0.0677, Velocity = 0.0602
#
# Episode 9, Action: 0.0000
# New State: Position = 0.1255, Velocity = 0.0578
#
# Episode 9, Action: 0.0000
# New State: Position = 0.1809, Velocity = 0.0554
#
# Episode 9, Action: 0.0000
# New State: Position = 0.2342, Velocity = 0.0533
#
# Episode 9, Action: 0.0000
# New State: Position = 0.2856, Velocity = 0.0514
#
# Episode 9, Action: 0.0000
# New State: Position = 0.3353, Velocity = 0.0497
#
# Episode 9, Action: 0.0000
# New State: Position = 0.3837, Velocity = 0.0484
#
# Episode 9, Action: 0.0000
# New State: Position = 0.4311, Velocity = 0.0474
#
# Episode 9, Action: 0.0000
# New State: Position = 0.4778, Velocity = 0.0467
#
# Episode 10 start in: 2 1
# Episode 10 start!
# Episode 10, Action: 0.0000
# New State: Position = -0.3561, Velocity = -0.0614
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4186, Velocity = -0.0626
#
# Episode 10, Action: 0.0000
# New State: Position = -0.4820, Velocity = -0.0633
#
# Episode 10, Action: 0.0000
# New State: Position = -0.5456, Velocity = -0.0637
#
# Episode 10, Action: 0.0000
# New State: Position = -0.6091, Velocity = -0.0635
#
# Episode 10, Action: 0.0000
# New State: Position = -0.6719, Velocity = -0.0629
#
# Episode 10, Action: 0.0000
# New State: Position = -0.7337, Velocity = -0.0618
#
# Episode 10, Action: 0.0000
# New State: Position = -0.7940, Velocity = -0.0603
#
# Episode 10, Action: 0.0000
# New State: Position = -0.8525, Velocity = -0.0585
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9089, Velocity = -0.0564
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9630, Velocity = -0.0541
#
# Episode 10, Action: 0.0000
# New State: Position = -1.0147, Velocity = -0.0517
#
# Episode 10, Action: 0.0000
# New State: Position = -1.0639, Velocity = -0.0492
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1106, Velocity = -0.0467
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1549, Velocity = -0.0443
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1968, Velocity = -0.0419
#
# Episode 10, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 10, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 10, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 10, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 10, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 10, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0309
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9550, Velocity = 0.0333
#
# Episode 10, Action: 0.0000
# New State: Position = -0.9193, Velocity = 0.0357
#
# Episode 10, Action: 0.0000
# New State: Position = -0.8812, Velocity = 0.0381
#
# Episode 10, Action: 0.0000
# New State: Position = -0.8410, Velocity = 0.0403
#
# Episode 10, Action: 0.0000
# New State: Position = -0.7987, Velocity = 0.0423
#
# Episode 10, Action: 0.0000
# New State: Position = -0.7545, Velocity = 0.0441
#
# Episode 10, Action: 0.0000
# New State: Position = -0.7088, Velocity = 0.0457
#
# Episode 10, Action: 0.0000
# New State: Position = -0.6618, Velocity = 0.0471
#
# Episode 10, Action: 0.0556
# New State: Position = -0.6136, Velocity = 0.0481
#
# Episode 10, Action: 0.2381
# New State: Position = -0.5645, Velocity = 0.0492
#
# Episode 10, Action: 0.4524
# New State: Position = -0.5143, Velocity = 0.0501
#
# Episode 10, Action: 0.6508
# New State: Position = -0.4632, Velocity = 0.0511
#
# Episode 10, Action: 0.7778
# New State: Position = -0.4115, Velocity = 0.0518
#
# Episode 10, Action: 0.8730
# New State: Position = -0.3592, Velocity = 0.0523
#
# Episode 10, Action: 0.9047
# New State: Position = -0.3068, Velocity = 0.0524
#
# Episode 10, Action: 0.9206
# New State: Position = -0.2545, Velocity = 0.0523
#
# Episode 10, Action: 0.9286
# New State: Position = -0.2026, Velocity = 0.0519
#
# Episode 10, Action: 0.9365
# New State: Position = -0.1514, Velocity = 0.0512
#
# Episode 10, Action: 0.9524
# New State: Position = -0.1010, Velocity = 0.0504
#
# Episode 10, Action: 0.9762
# New State: Position = -0.0515, Velocity = 0.0495
#
# Episode 10, Action: 0.9920
# New State: Position = -0.0029, Velocity = 0.0485
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0446, Velocity = 0.0475
#
# Episode 10, Action: 1.0000
# New State: Position = 0.0911, Velocity = 0.0465
#
# Episode 10, Action: 1.0000
# New State: Position = 0.1367, Velocity = 0.0456
#
# Episode 10, Action: 1.0000
# New State: Position = 0.1816, Velocity = 0.0448
#
# Episode 10, Action: 1.0000
# New State: Position = 0.2258, Velocity = 0.0442
#
# Episode 10, Action: 1.0000
# New State: Position = 0.2695, Velocity = 0.0438
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3130, Velocity = 0.0435
#
# Episode 10, Action: 1.0000
# New State: Position = 0.3566, Velocity = 0.0435
#
# Episode 10, Action: 1.0000
# New State: Position = 0.4004, Velocity = 0.0438
#
# Episode 10, Action: 1.0000
# New State: Position = 0.4449, Velocity = 0.0444
#
# Episode 10, Action: 1.0000
# New State: Position = 0.4902, Velocity = 0.0454
#
# Episode 11 start in: 2 1
# Episode 11 start!
# Episode 11, Action: 0.0000
# New State: Position = -0.3750, Velocity = -0.0656
#
# Episode 11, Action: 0.0000
# New State: Position = -0.4417, Velocity = -0.0667
#
# Episode 11, Action: 0.0000
# New State: Position = -0.5090, Velocity = -0.0673
#
# Episode 11, Action: 0.0000
# New State: Position = -0.5764, Velocity = -0.0674
#
# Episode 11, Action: 0.0000
# New State: Position = -0.6434, Velocity = -0.0670
#
# Episode 11, Action: 0.0000
# New State: Position = -0.7095, Velocity = -0.0661
#
# Episode 11, Action: 0.0000
# New State: Position = -0.7743, Velocity = -0.0648
#
# Episode 11, Action: 0.0000
# New State: Position = -0.8374, Velocity = -0.0631
#
# Episode 11, Action: 0.0000
# New State: Position = -0.8984, Velocity = -0.0611
#
# Episode 11, Action: 0.0000
# New State: Position = -0.9573, Velocity = -0.0588
#
# Episode 11, Action: 0.0000
# New State: Position = -1.0137, Velocity = -0.0564
#
# Episode 11, Action: 0.0000
# New State: Position = -1.0676, Velocity = -0.0539
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1190, Velocity = -0.0514
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1680, Velocity = -0.0490
#
# Episode 11, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 11, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 11, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 11, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 11, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 11, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 11, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0309
#
# Episode 11, Action: 0.0000
# New State: Position = -0.9550, Velocity = 0.0333
#
# Episode 11, Action: 0.0000
# New State: Position = -0.9193, Velocity = 0.0357
#
# Episode 11, Action: 0.0000
# New State: Position = -0.8812, Velocity = 0.0381
#
# Episode 11, Action: 0.0000
# New State: Position = -0.8410, Velocity = 0.0403
#
# Episode 11, Action: 0.0000
# New State: Position = -0.7987, Velocity = 0.0423
#
# Episode 11, Action: 0.0000
# New State: Position = -0.7545, Velocity = 0.0441
#
# Episode 11, Action: 0.0000
# New State: Position = -0.7088, Velocity = 0.0457
#
# Episode 11, Action: 0.0000
# New State: Position = -0.6618, Velocity = 0.0471
#
# Episode 11, Action: 0.1667
# ...
#
# Episode 46, Action: 0.8809
# New State: Position = -0.3130, Velocity = 0.0597
#
# Episode 46, Action: 0.8968
# New State: Position = -0.2534, Velocity = 0.0596
#
# Episode 46, Action: 0.9127
# New State: Position = -0.1943, Velocity = 0.0592
#
# Episode 46, Action: 0.9444
# New State: Position = -0.1358, Velocity = 0.0585
#
# Episode 46, Action: 0.9682
# New State: Position = -0.0781, Velocity = 0.0576
#
# Episode 46, Action: 0.9841
# New State: Position = -0.0214, Velocity = 0.0567
#
# Episode 46, Action: 0.9920
# New State: Position = 0.0342, Velocity = 0.0557
#
# Episode 46, Action: 1.0000
# New State: Position = 0.0889, Velocity = 0.0547
#
# Episode 46, Action: 1.0000
# New State: Position = 0.1427, Velocity = 0.0538
#
# Episode 46, Action: 1.0000
# New State: Position = 0.1957, Velocity = 0.0530
#
# Episode 46, Action: 1.0000
# New State: Position = 0.2481, Velocity = 0.0524
#
# Episode 46, Action: 1.0000
# New State: Position = 0.3002, Velocity = 0.0521
#
# Episode 46, Action: 1.0000
# New State: Position = 0.3523, Velocity = 0.0520
#
# Episode 46, Action: 1.0000
# New State: Position = 0.4046, Velocity = 0.0523
#
# Episode 46, Action: 1.0000
# New State: Position = 0.4575, Velocity = 0.0529
#
# Episode 47 start in: 2 1
# Episode 47 start!
# Episode 47, Action: 0.0000
# New State: Position = 0.3371, Velocity = 0.0065
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3423, Velocity = 0.0052
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3462, Velocity = 0.0039
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3488, Velocity = 0.0026
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3502, Velocity = 0.0014
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3504, Velocity = 0.0001
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3492, Velocity = -0.0011
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3469, Velocity = -0.0024
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3433, Velocity = -0.0036
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3383, Velocity = -0.0049
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3321, Velocity = -0.0062
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3245, Velocity = -0.0076
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3155, Velocity = -0.0090
#
# Episode 47, Action: 0.0000
# New State: Position = 0.3051, Velocity = -0.0105
#
# Episode 47, Action: 0.0000
# New State: Position = 0.2931, Velocity = -0.0120
#
# Episode 47, Action: 0.0000
# New State: Position = 0.2795, Velocity = -0.0136
#
# Episode 47, Action: 0.0000
# New State: Position = 0.2643, Velocity = -0.0152
#
# Episode 47, Action: 0.0000
# New State: Position = 0.2473, Velocity = -0.0170
#
# Episode 47, Action: 0.0000
# New State: Position = 0.2284, Velocity = -0.0188
#
# Episode 47, Action: 0.0000
# New State: Position = 0.2076, Velocity = -0.0208
#
# Episode 47, Action: 0.0000
# New State: Position = 0.1848, Velocity = -0.0228
#
# Episode 47, Action: 0.0000
# New State: Position = 0.1599, Velocity = -0.0249
#
# Episode 47, Action: 0.0000
# New State: Position = 0.1327, Velocity = -0.0272
#
# Episode 47, Action: 0.0000
# New State: Position = 0.1033, Velocity = -0.0295
#
# Episode 47, Action: 0.0000
# New State: Position = 0.0714, Velocity = -0.0318
#
# Episode 47, Action: 0.0000
# New State: Position = 0.0371, Velocity = -0.0343
#
# Episode 47, Action: 0.0000
# New State: Position = 0.0004, Velocity = -0.0368
#
# Episode 47, Action: 0.0000
# New State: Position = -0.0389, Velocity = -0.0393
#
# Episode 47, Action: 0.0000
# New State: Position = -0.0806, Velocity = -0.0418
#
# Episode 47, Action: 0.0000
# New State: Position = -0.1248, Velocity = -0.0442
#
# Episode 47, Action: 0.0000
# New State: Position = -0.1713, Velocity = -0.0465
#
# Episode 47, Action: 0.0000
# New State: Position = -0.2200, Velocity = -0.0487
#
# Episode 47, Action: 0.0000
# New State: Position = -0.2707, Velocity = -0.0507
#
# Episode 47, Action: 0.0000
# New State: Position = -0.3230, Velocity = -0.0524
#
# Episode 47, Action: 0.0000
# New State: Position = -0.3768, Velocity = -0.0538
#
# Episode 47, Action: 0.0000
# New State: Position = -0.4317, Velocity = -0.0549
#
# Episode 47, Action: 0.0000
# New State: Position = -0.4872, Velocity = -0.0555
#
# Episode 47, Action: 0.0000
# New State: Position = -0.5430, Velocity = -0.0558
#
# Episode 47, Action: 0.0000
# New State: Position = -0.5987, Velocity = -0.0557
#
# Episode 47, Action: 0.0000
# New State: Position = -0.6538, Velocity = -0.0551
#
# Episode 47, Action: 0.0000
# New State: Position = -0.7080, Velocity = -0.0542
#
# Episode 47, Action: 0.0000
# New State: Position = -0.7608, Velocity = -0.0528
#
# Episode 47, Action: 0.0000
# New State: Position = -0.8120, Velocity = -0.0512
#
# Episode 47, Action: 0.0000
# New State: Position = -0.8613, Velocity = -0.0493
#
# Episode 47, Action: 0.0000
# New State: Position = -0.9085, Velocity = -0.0472
#
# Episode 47, Action: 0.0000
# New State: Position = -0.9534, Velocity = -0.0449
#
# Episode 47, Action: 0.0000
# New State: Position = -0.9959, Velocity = -0.0425
#
# Episode 47, Action: 0.0000
# New State: Position = -1.0359, Velocity = -0.0400
#
# Episode 47, Action: 0.0000
# New State: Position = -1.0734, Velocity = -0.0375
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1085, Velocity = -0.0350
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1410, Velocity = -0.0326
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1712, Velocity = -0.0302
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1991, Velocity = -0.0278
#
# Episode 47, Action: 0.0000
# New State: Position = -1.2000, Velocity = 0.0000
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1978, Velocity = 0.0022
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1933, Velocity = 0.0045
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1865, Velocity = 0.0068
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1775, Velocity = 0.0090
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1661, Velocity = 0.0114
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1524, Velocity = 0.0137
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1364, Velocity = 0.0161
#
# Episode 47, Action: 0.0000
# New State: Position = -1.1179, Velocity = 0.0185
#
# Episode 47, Action: 0.0000
# New State: Position = -1.0970, Velocity = 0.0209
#
# Episode 47, Action: 0.0000
# New State: Position = -1.0736, Velocity = 0.0234
#
# Episode 47, Action: 0.0000
# New State: Position = -1.0477, Velocity = 0.0259
#
# Episode 47, Action: 0.0000
# New State: Position = -1.0193, Velocity = 0.0284
#
# Episode 47, Action: 0.0000
# New State: Position = -0.9884, Velocity = 0.0309
#
# Episode 47, Action: 0.0000
# New State: Position = -0.9550, Velocity = 0.0333
#
# Episode 47, Action: 0.1508
# New State: Position = -0.9191, Velocity = 0.0360
#
# Episode 47, Action: 0.3730
# New State: Position = -0.8802, Velocity = 0.0389
#
# Episode 47, Action: 0.6508
# New State: Position = -0.8382, Velocity = 0.0420
#
# Episode 47, Action: 0.8333
# New State: Position = -0.7929, Velocity = 0.0453
#
# Episode 47, Action: 0.9524
# New State: Position = -0.7444, Velocity = 0.0485
#
# Episode 47, Action: 0.9920
# New State: Position = -0.6928, Velocity = 0.0516
#
# Episode 47, Action: 1.0000
# New State: Position = -0.6386, Velocity = 0.0543
#
# Episode 47, Action: 1.0000
# New State: Position = -0.5819, Velocity = 0.0566
#
# Episode 47, Action: 1.0000
# New State: Position = -0.5234, Velocity = 0.0586
#
# Episode 47, Action: 1.0000
# New State: Position = -0.4633, Velocity = 0.0600
#
# Episode 47, Action: 1.0000
# New State: Position = -0.4022, Velocity = 0.0611
#
# Episode 47, Action: 1.0000
# New State: Position = -0.3405, Velocity = 0.0617
#
# Episode 47, Action: 1.0000
# New State: Position = -0.2786, Velocity = 0.0619
#
# Episode 47, Action: 1.0000
# New State: Position = -0.2169, Velocity = 0.0617
#
# Episode 47, Action: 1.0000
# New State: Position = -0.1557, Velocity = 0.0612
#
# Episode 47, Action: 1.0000
# New State: Position = -0.0952, Velocity = 0.0605
#
# Episode 47, Action: 1.0000
# New State: Position = -0.0355, Velocity = 0.0596
#
# Episode 47, Action: 1.0000
# New State: Position = 0.0231, Velocity = 0.0586
#
# Episode 47, Action: 1.0000
# New State: Position = 0.0807, Velocity = 0.0576
#
# Episode 47, Action: 1.0000
# New State: Position = 0.1374, Velocity = 0.0567
#
# Episode 47, Action: 1.0000
# New State: Position = 0.1933, Velocity = 0.0559
#
# Episode 47, Action: 1.0000
# New State: Position = 0.2486, Velocity = 0.0553
#
# Episode 47, Action: 1.0000
# New State: Position = 0.3036, Velocity = 0.0550
#
# Episode 47, Action: 1.0000
# New State: Position = 0.3586, Velocity = 0.0549
#
# Episode 47, Action: 1.0000
# New State: Position = 0.4138, Velocity = 0.0553
#
# Episode 47, Action: 0.7222
# New State: Position = 0.4694, Velocity = 0.0555
#
# Episode 48 start in: 2 1
# Episode 48 start!
# Episode 48, Action: 0.0000
# New State: Position = -0.2324, Velocity = -0.0028
#
# Episode 48, Action: 0.0000
# New State: Position = -0.2371, Velocity = -0.0047
#
# Episode 48, Action: 0.0000
# New State: Position = -0.2437, Velocity = -0.0066
#
# Episode 48, Action: 0.0000
# New State: Position = -0.2522, Velocity = -0.0084
#
# Episode 48, Action: 0.0000
# New State: Position = -0.2624, Velocity = -0.0103
#
# Episode 48, Action: 0.0000
# New State: Position = -0.2745, Velocity = -0.0120
#
# Episode 48, Action: 0.0000
# New State: Position = -0.2882, Velocity = -0.0137
#
# Episode 48, Action: 0.0000
# New State: Position = -0.3036, Velocity = -0.0154
#
# Episode 48, Action: 0.0000
# New State: Position = -0.3205, Velocity = -0.0169
#
# Episode 48, Action: 0.0000
# New State: Position = -0.3388, Velocity = -0.0183
#
# Episode 48, Action: 0.0000
# New State: Position = -0.3584, Velocity = -0.0196
#
# Episode 48, Action: 0.0000
# New State: Position = -0.3792, Velocity = -0.0208
#
# Episode 48, Action: 0.0000
# New State: Position = -0.4011, Velocity = -0.0219
#
# Episode 48, Action: 0.0000
# New State: Position = -0.4239, Velocity = -0.0228
#
# Episode 48, Action: 0.0000
# New State: Position = -0.4474, Velocity = -0.0235
#
# Episode 48, Action: 0.0000
# New State: Position = -0.4714, Velocity = -0.0241
#
# Episode 48, Action: 0.0000
# New State: Position = -0.4959, Velocity = -0.0245
#
# Episode 48, Action: 0.0000
# New State: Position = -0.5206, Velocity = -0.0247
#
# Episode 48, Action: 0.0000
# New State: Position = -0.5453, Velocity = -0.0247
#
# Episode 48, Action: 0.0000
# New State: Position = -0.5698, Velocity = -0.0245
#
# Episode 48, Action: 0.0000
# New State: Position = -0.5940, Velocity = -0.0242
#
# Episode 48, Action: 0.0000
# New State: Position = -0.6177, Velocity = -0.0237
#
# Episode 48, Action: 0.0000
# New State: Position = -0.6406, Velocity = -0.0230
#
# Episode 48, Action: 0.0000
# New State: Position = -0.6627, Velocity = -0.0221
#
# Episode 48, Action: 0.0000
# New State: Position = -0.6838, Velocity = -0.0211
#
# Episode 48, Action: 0.0000
# New State: Position = -0.7038, Velocity = -0.0199
#
# Episode 48, Action: -0.0078
# New State: Position = -0.7224, Velocity = -0.0187
#
# Episode 48, Action: -0.1484
# New State: Position = -0.7399, Velocity = -0.0175
#
# Episode 48, Action: -0.5312
# New State: Position = -0.7567, Velocity = -0.0168
#
# Episode 48, Action: -0.8125
# New State: Position = -0.7730, Velocity = -0.0164
#
# Episode 48, Action: -0.9688
# New State: Position = -0.7892, Velocity = -0.0161
#
# Episode 48, Action: -1.0000
# New State: Position = -0.8050, Velocity = -0.0158
#
# Episode 48, Action: -1.0000
# New State: Position = -0.8205, Velocity = -0.0155
#
# Episode 48, Action: -1.0000
# New State: Position = -0.8355, Velocity = -0.0150
#
# Episode 48, Action: -1.0000
# New State: Position = -0.8500, Velocity = -0.0145
#
# Episode 48, Action: -1.0000
# New State: Position = -0.8640, Velocity = -0.0139
#
# Episode 48, Action: -0.8594
# New State: Position = -0.8771, Velocity = -0.0131
#
# Episode 48, Action: -0.5312
# New State: Position = -0.8888, Velocity = -0.0117
#
# Episode 48, Action: -0.1406
# New State: Position = -0.8985, Velocity = -0.0097
#
# Episode 48, Action: 0.0000
# New State: Position = -0.9059, Velocity = -0.0074
#
# Episode 48, Action: 0.0000
# New State: Position = -0.9111, Velocity = -0.0052
#
# Episode 48, Action: 0.0000
# New State: Position = -0.9140, Velocity = -0.0029
#
# Episode 48, Action: 0.0000
# New State: Position = -0.9145, Velocity = -0.0006
#
# Episode 48, Action: 0.0000
# New State: Position = -0.9128, Velocity = 0.0017
#
# Episode 48, Action: 0.0000
# New State: Position = -0.9088, Velocity = 0.0040
#
# Episode 48, Action: 0.0000
# New State: Position = -0.9024, Velocity = 0.0063
#
# Episode 48, Action: 0.0000
# New State: Position = -0.8938, Velocity = 0.0086
#
# Episode 48, Action: 0.0000
# New State: Position = -0.8830, Velocity = 0.0108
#
# Episode 48, Action: 0.0000
# New State: Position = -0.8700, Velocity = 0.0130
#
# Episode 48, Action: 0.0000
# New State: Position = -0.8548, Velocity = 0.0152
#
# Episode 48, Action: 0.0000
# New State: Position = -0.8375, Velocity = 0.0173
#
# Episode 48, Action: 0.0159
# New State: Position = -0.8182, Velocity = 0.0193
#
# Episode 48, Action: 0.2460
# New State: Position = -0.7966, Velocity = 0.0216
#
# Episode 48, Action: 0.6190
# New State: Position = -0.7722, Velocity = 0.0244
#
# Episode 48, Action: 0.9047
# New State: Position = -0.7447, Velocity = 0.0274
#
# Episode 48, Action: 0.9920
# New State: Position = -0.7143, Velocity = 0.0305
#
# Episode 48, Action: 1.0000
# New State: Position = -0.6810, Velocity = 0.0333
#
# Episode 48, Action: 1.0000
# New State: Position = -0.6450, Velocity = 0.0360
#
# Episode 48, Action: 1.0000
# New State: Position = -0.6067, Velocity = 0.0383
#
# Episode 48, Action: 1.0000
# New State: Position = -0.5662, Velocity = 0.0405
#
# Episode 48, Action: 1.0000
# New State: Position = -0.5239, Velocity = 0.0423
#
# Episode 48, Action: 1.0000
# New State: Position = -0.4801, Velocity = 0.0438
#
# Episode 48, Action: 1.0000
# New State: Position = -0.4352, Velocity = 0.0450
#
# Episode 48, Action: 1.0000
# New State: Position = -0.3894, Velocity = 0.0458
#
# Episode 48, Action: 1.0000
# New State: Position = -0.3430, Velocity = 0.0463
#
# Episode 48, Action: 1.0000
# New State: Position = -0.2965, Velocity = 0.0465
#
# Episode 48, Action: 1.0000
# New State: Position = -0.2500, Velocity = 0.0465
#
# Episode 48, Action: 1.0000
# New State: Position = -0.2039, Velocity = 0.0461
#
# Episode 48, Action: 1.0000
# New State: Position = -0.1583, Velocity = 0.0456
#
# Episode 48, Action: 1.0000
# New State: Position = -0.1135, Velocity = 0.0449
#
# Episode 48, Action: 1.0000
# New State: Position = -0.0695, Velocity = 0.0440
#
# Episode 48, Action: 1.0000
# New State: Position = -0.0264, Velocity = 0.0431
#
# Episode 48, Action: 1.0000
# New State: Position = 0.0157, Velocity = 0.0421
#
# Episode 48, Action: 1.0000
# New State: Position = 0.0567, Velocity = 0.0411
#
# Episode 48, Action: 1.0000
# New State: Position = 0.0968, Velocity = 0.0401
#
# Episode 48, Action: 1.0000
# New State: Position = 0.1360, Velocity = 0.0392
#
# Episode 48, Action: 1.0000
# New State: Position = 0.1744, Velocity = 0.0384
#
# Episode 48, Action: 1.0000
# New State: Position = 0.2122, Velocity = 0.0377
#
# Episode 48, Action: 1.0000
# New State: Position = 0.2494, Velocity = 0.0372
#
# Episode 48, Action: 1.0000
# New State: Position = 0.2863, Velocity = 0.0369
#
# Episode 48, Action: 1.0000
# New State: Position = 0.3231, Velocity = 0.0368
#
# Episode 48, Action: 1.0000
# New State: Position = 0.3600, Velocity = 0.0369
#
# Episode 48, Action: 1.0000
# New State: Position = 0.3972, Velocity = 0.0372
#
# Episode 48, Action: 1.0000
# New State: Position = 0.4349, Velocity = 0.0378
#
# Episode 48, Action: 1.0000
# New State: Position = 0.4735, Velocity = 0.0386
#
# Episode 49 start in: 2 1
# Episode 49 start!
# Episode 49, Action: 0.0000
# New State: Position = 0.3285, Velocity = 0.0462
#
# Episode 49, Action: 0.0000
# New State: Position = 0.3733, Velocity = 0.0449
#
# Episode 49, Action: 0.0000
# New State: Position = 0.4171, Velocity = 0.0438
#
# Episode 49, Action: 0.0000
# New State: Position = 0.4601, Velocity = 0.0430
#
# Episode 50 start in: 2 1
# Episode 50 start!
# Episode 50, Action: 0.0000
# New State: Position = 0.1768, Velocity = 0.0544
#
# Episode 50, Action: 0.0000
# New State: Position = 0.2291, Velocity = 0.0523
#
# Episode 50, Action: 0.0000
# New State: Position = 0.2795, Velocity = 0.0504
#
# Episode 50, Action: 0.0000
# New State: Position = 0.3281, Velocity = 0.0487
#
# Episode 50, Action: 0.0000
# New State: Position = 0.3754, Velocity = 0.0473
#
# Episode 50, Action: 0.0000
# New State: Position = 0.4217, Velocity = 0.0462
#
# Episode 50, Action: 0.0000
# New State: Position = 0.4671, Velocity = 0.0455
